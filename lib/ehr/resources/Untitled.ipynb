# %%
import pandas as pd

# %%
df = pd.read_csv("mimic4_obs_codes.csv.gz", index_col=[0])

# %%
df
# Out:
#                  label           group code
# 0                aado2       blood_gas  o00
# 1           aado2_calc       blood_gas  o01
# 2                  po2       blood_gas  o02
# 3              lactate       blood_gas  o03
# 4                   ph       blood_gas  o04
# 5           baseexcess       blood_gas  o05
# 6                 pco2       blood_gas  o06
# 7        pao2fio2ratio       blood_gas  o07
# 8             totalco2       blood_gas  o08
# 9    carboxyhemoglobin       blood_gas  o09
# 10       methemoglobin       blood_gas  o10
# 11    fio2_chartevents       blood_gas  o11
# 12                fio2       blood_gas  o12
# 13                 so2       blood_gas  o13
# 14               ck_mb  cardiac_marker  o14
# 15            ntprobnp  cardiac_marker  o15
# 16          troponin_t  cardiac_marker  o16
# 17                 mch             cbc  o17
# 18                 mcv             cbc  o18
# 19          hematocrit             cbc  o19
# ...

# %%
df = df.set_index(['group', 'label', 'code']).sort_index()
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df.to_latex('tab.tex',longtable=True)
