# %% [markdown]
# # Table of Content
#
# <a name="outline"></a>
#
# ## Setup
#
# - [A](#seca) External Imports
# - [B](#secb) Internal Imports
# - [C](#secd) Configurations and Paths
# - [D](#sece) Patient Interface and Train/Val/Test Partitioning
#
#
# ## Evaluations
#
# - [1](#sec1) Snooping/Selecting Best Models from the Validation Set
# - [2](#sec2) Predictive Performance: MIMIC-III (Test Set)
# - [3](#sec3) Predictive Performance: MIMIC-IV (Test Set)
# - [4](#sec4) Predictive Performance: from MIMIC-IV (Training Set) to MIMIC-III (All)

# %% [markdown]
# <a name="seca"></a>
#
# ### A External Imports [^](#outline)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
from IPython.display import display
from upsetplot import from_contents, plot, UpSet, from_indicators

# %% [markdown]
# <a name="secb"></a>
#
# ### B Internal Imports [^](#outline)

# %%
HOME = os.environ.get('HOME')

# %load_ext autoreload
# %autoreload 2

import analysis as A
import common as C
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <a name="secc"></a>
#
# ### C Configurations and Paths [^](#outline)

# %%
mimic_dir = {
    'M3': f'{HOME}/GP/ehr-data/mimic3-transforms',
    'M4': f'{HOME}/GP/ehr-data/mimic4-transforms'
}

train_dir = {
    'GM3': f'{HOME}/GP/ehr-data/icenode-m3-exp/train_config_v0.2.25_G_M3',
    'M3': f'{HOME}/GP/ehr-data/icenode-m3-exp/train_config_v0.2.25_M3',
    'M4': f'{HOME}/GP/ehr-data/icenode-m4-exp/train_config_v0.2.25_M4',
    'GM4': f'{HOME}/GP/ehr-data/icenode-m4-exp/train_config_v0.2.25_G_M4'
}

model_dir = {
    'ICE-NODE': 'icenode_2lr',
    'ICE-NODE_UNIFORM': 'icenode_uniform2lr',
    'GRU': 'gru',
    'RETAIN': 'retain',
    'LogReg': 'window_logreg'
}


clfs = list(model_dir.keys())

relative_auc_config = {
    'pvalue': 0.01, 
    'min_auc': 0.9
}
top_k_list=[1, 2, 3, 5, 7, 10, 15, 20]
percentiles=20 
n_percentiles=int(100/percentiles)


import matplotlib.font_manager as font_manager

plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({'font.family': 'sans-serif',
                     'font.sans-serif': 'Helvetica',
                     'font.weight':  'normal'})

# %%
output_dir = 'artefacts'
Path(output_dir).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# <a name="secd"></a>
#
# ### D Patient Interface and Train/Val/Test Patitioning [^](#outline)

# %%
m4_interface = C.create_patient_interface(mimic_dir['M4'])
m3_interface = C.create_patient_interface(mimic_dir['M3'])

m4_train_ids, m4_valid_ids, m4_test_ids = m4_interface.random_splits(split1=0.7, split2=0.85, random_seed=42)
m3_train_ids, m3_valid_ids, m3_test_ids = m3_interface.random_splits(split1=0.7, split2=0.85, random_seed=42)

# %%
m4_percentiles = m4_interface.dx_flatccs_by_percentiles(percentiles)
m3_percentiles = m3_interface.dx_flatccs_by_percentiles(percentiles)

m4_train_percentiles = m4_interface.dx_flatccs_by_percentiles(percentiles, m4_train_ids)
m3_train_percentiles = m3_interface.dx_flatccs_by_percentiles(percentiles, m3_train_ids)

# %% [markdown]
# <a name="sec1"></a>
#
# ## 1 Snooping/Selecting Best Models from the Validation Set [^](#outline)

# %%
# Classifiers with Linear Embeddings
clfs = (
    'ICE-NODE', 
    'ICE-NODE_UNIFORM',
    'GRU',
    'RETAIN',
    'LogReg'
)


# Classifiers with GRAM Embeddings
clfsG = (
    'ICE-NODE', 
    'ICE-NODE_UNIFORM',
    'GRU'
)

# %%
m4_traces = A.performance_traces(data_tag='M4', 
                                 clfs=clfs, 
                                 train_dir=train_dir, 
                                 model_dir=model_dir)
gm4_traces =  A.performance_traces(data_tag='GM4', 
                                   clfs=clfsG, 
                                   train_dir=train_dir, 
                                   model_dir=model_dir)

gm3_traces =  A.performance_traces(data_tag='GM3', 
                                   clfs=clfsG, 
                                   train_dir=train_dir, 
                                   model_dir=model_dir)
m3_traces = A.performance_traces(data_tag='M3', 
                                 clfs=clfs, 
                                 train_dir=train_dir, 
                                 model_dir=model_dir)

plt_ctx = lambda : sns.plotting_context("poster", font_scale=2, rc={"lines.linewidth": 2.5,  'grid.linestyle': '--'})

# %%
with sns.axes_style("whitegrid"), plt_ctx():
    g = sns.FacetGrid(data=m4_traces, row='clf', col='loss',  height=10, aspect=2, sharey=False, despine=True)
    g.map_dataframe(sns.lineplot, 'index', 'value', 'metric', **dict(linewidth=5))
    g.set_titles(col_template="{col_name}", fontweight='bold', size=18)
    g.add_legend()

    current_figure = plt.gcf()
    current_figure.savefig(f"{output_dir}/M4_performance_trace.pdf")

# %%
with sns.axes_style("whitegrid"), plt_ctx():
    g = sns.FacetGrid(data=m3_traces, row='clf', col='loss',  height=10, aspect=2, sharey=False, despine=True)
    g.map_dataframe(sns.lineplot, 'index', 'value', 'metric', **dict(linewidth=5))
    g.set_titles(col_template="{col_name}", fontweight='bold', size=18)
    g.add_legend()
    
    current_figure = plt.gcf()
    current_figure.savefig(f"{output_dir}/M3_performance_trace.pdf")

# %%
with sns.axes_style("whitegrid"), plt_ctx():
    g = sns.FacetGrid(data=gm3_traces, row='clf', col='loss',  height=10, aspect=2, sharey=False, despine=True)
    g.map_dataframe(sns.lineplot, 'index', 'value', 'metric', **dict(linewidth=5))
    g.set_titles(col_template="{col_name}", fontweight='bold', size=18)
    g.add_legend()
    
    current_figure = plt.gcf()
    current_figure.savefig(f"{output_dir}/GM3_performance_trace.pdf")

# %%
with sns.axes_style("whitegrid"), plt_ctx():
    g = sns.FacetGrid(data=gm4_traces, row='clf', col='loss',  height=10, aspect=2, sharey=False, despine=True)
    g.map_dataframe(sns.lineplot, 'index', 'value', 'metric', **dict(linewidth=5))
    g.set_titles(col_template="{col_name}", fontweight='bold', size=18)
    g.add_legend()
    
    current_figure = plt.gcf()
    current_figure.savefig(f"{output_dir}/GM4_performance_trace.pdf")

# %%
print('> Models trained on MIMIC-III')
m3_uAUC = A.get_trained_models(clfs=clfs, train_dir=train_dir, model_dir=model_dir, data_tag='M3', 
                               criterion='MICRO-AUC',  comp=max)
display(m3_uAUC['summary'])

print('> Models trained on MIMIC-IV')
m4_uAUC = A.get_trained_models(clfs=clfs, train_dir=train_dir, model_dir=model_dir, data_tag='M4', 
                               criterion='MICRO-AUC',  comp=max)
display(m4_uAUC['summary'])


print('> Models (GRAM) trained on MIMIC-III')
gm3_uAUC = A.get_trained_models(clfs=clfsG, train_dir=train_dir, model_dir=model_dir, data_tag='GM3',  
                                criterion='MICRO-AUC', comp=max)
display(gm3_uAUC['summary'])

print('> Models (GRAM) trained on MIMIC-IV')
gm4_uAUC = A.get_trained_models(clfs=clfsG, train_dir=train_dir, model_dir=model_dir, data_tag='GM4', 
                                criterion='MICRO-AUC', comp=max)
display(gm4_uAUC['summary'])
# Out:
# > Models trained on MIMIC-III
#                 Clf  Best_i  MICRO-AUC
# 0          ICE-NODE      57   0.925790
# 1  ICE-NODE_UNIFORM      44   0.925757
# 2               GRU      32   0.923570
# 3            RETAIN      20   0.927307
# 4            LogReg       0   0.912001
# > Models trained on MIMIC-IV
#                 Clf  Best_i  MICRO-AUC
# 0          ICE-NODE      38   0.933961
# 1  ICE-NODE_UNIFORM      66   0.932462
# 2               GRU      15   0.936528
# 3            RETAIN      17   0.936482
# 4            LogReg       0   0.891420
# > Models (GRAM) trained on MIMIC-III
#                 Clf  Best_i  MICRO-AUC
# 0          ICE-NODE      58   0.924722
# 1  ICE-NODE_UNIFORM      58   0.924760
# 2               GRU      32   0.923149
# > Models (GRAM) trained on MIMIC-IV
#                 Clf  Best_i  MICRO-AUC
# 0          ICE-NODE      41   0.934028
# 1  ICE-NODE_UNIFORM      29   0.932499
# 2               GRU      17   0.936749

# %%
print('> Models trained on MIMIC-III')
m3_loss =  A.get_trained_models(clfs=clfs, train_dir=train_dir, model_dir=model_dir, data_tag='M3', 
                                criterion='loss', comp=min)
display(m3_loss['summary'])

print('> Models trained on MIMIC-IV')
m4_loss = A.get_trained_models(clfs=clfs, train_dir=train_dir, model_dir=model_dir, data_tag='M4',
                             criterion='loss',  comp=min)
display(m4_loss['summary'])

print('> Models (GRAM) trained on MIMIC-III')
gm3_loss = A.get_trained_models(clfs=clfsG, train_dir=train_dir, model_dir=model_dir, data_tag='GM3',
                                criterion='loss', comp=min)
display(gm3_loss['summary'])

print('> Models (GRAM) trained on MIMIC-IV')
gm4_loss = A.get_trained_models(clfs=clfsG, train_dir=train_dir, model_dir=model_dir, data_tag='GM4',
                                criterion='loss', comp=min)
display(gm4_loss['summary'])

# %%
def combine_acc(row):
    return 1 / (1 / row.loc[list(f'ACC-P{i}' for i in range(5))]).sum()

print('> Models trained on MIMIC-III')
m3_comb = A.get_trained_models(clfs=clfs, train_dir=train_dir, model_dir=model_dir, data_tag='M3', 
                             criterion=combine_acc, comp=max)
display(m3_comb['summary'])


print('> Models trained on MIMIC-IV')
m4_comb = A.get_trained_models(clfs=clfs, train_dir=train_dir, model_dir=model_dir, data_tag='M4', 
                             criterion=combine_acc, comp=max)
display(m4_comb['summary'])


print('> Models (GRAM) trained on MIMIC-III')
gm3_comb = A.get_trained_models(clfs=clfsG, train_dir=train_dir, model_dir=model_dir, data_tag='GM3', 
                              criterion=combine_acc, comp=max)
display(gm3_comb['summary'])


print('> Models (GRAM) trained on MIMIC-IV')
gm4_comb = A.get_trained_models(clfs=clfsG, train_dir=train_dir, model_dir=model_dir, data_tag='GM4', 
                               criterion=combine_acc, comp=max)
display(gm4_comb['summary'])
# Out:
# > Models trained on MIMIC-III
#                 Clf  Best_i  <function combine_acc at 0x7fd4bf9679d0>
# 0          ICE-NODE      90                                  0.109711
# 1  ICE-NODE_UNIFORM      94                                  0.109345
# 2               GRU      39                                  0.107409
# 3            RETAIN      40                                  0.109896
# 4            LogReg       0                                  0.089477
# > Models trained on MIMIC-IV
#                 Clf  Best_i  <function combine_acc at 0x7fd4bf9679d0>
# 0          ICE-NODE      88                                  0.126702
# 1  ICE-NODE_UNIFORM      88                                  0.125716
# 2               GRU      19                                  0.127814
# 3            RETAIN      23                                  0.127869
# 4            LogReg       0                                  0.031255
# > Models (GRAM) trained on MIMIC-III
#                 Clf  Best_i  <function combine_acc at 0x7fd4bf9679d0>
# 0          ICE-NODE      88                                  0.107542
# 1  ICE-NODE_UNIFORM      90                                  0.107439
# 2               GRU      44                                  0.106158
# > Models (GRAM) trained on MIMIC-IV
#                 Clf  Best_i  <function combine_acc at 0x7fd4bf9679d0>
# 0          ICE-NODE      88                                  0.126651
# 1  ICE-NODE_UNIFORM      88                                  0.125798
# 2               GRU      27                                  0.127750

# %%
m3_models_uAUC = C.get_models(clfs, m3_uAUC["config"], m3_uAUC["params"], m3_interface)
gm3_models_uAUC = C.get_models(clfsG, gm3_uAUC["config"], gm3_uAUC["params"], m3_interface)

m4_models_uAUC = C.get_models(clfs, m4_uAUC["config"], m4_uAUC["params"], m4_interface)
gm4_models_uAUC = C.get_models(clfsG, gm4_uAUC["config"], gm4_uAUC["params"], m4_interface)

# %%
m3_models_loss = C.get_models(clfs, m3_loss["config"], m3_loss["params"], m3_interface)
gm3_models_loss = C.get_models(clfsG, gm3_loss["config"], gm3_loss["params"], m3_interface)

m4_models_loss = C.get_models(clfs, m4_loss["config"], m4_loss["params"], m4_interface)
gm4_models_loss = C.get_models(clfsG, gm4_loss["config"], gm4_loss["params"], m4_interface)

# %%
m3_models_comb = C.get_models(clfs, m3_comb["config"], m3_comb["params"], m3_interface)
gm3_models_comb = C.get_models(clfsG, gm3_comb["config"], gm3_comb["params"], m3_interface)

m4_models_comb = C.get_models(clfs, m4_comb["config"], m4_comb["params"], m4_interface)
gm4_models_comb = C.get_models(clfsG, gm4_comb["config"], gm4_comb["params"], m4_interface)

# %% [markdown]
# ### Snooping on MIMIC-III Validation Set

# %%
m3_val_res_uAUC = {clf: C.eval_(model, m3_valid_ids) for clf, model in m3_models_uAUC.items()} 
m3_val_res_comb = {clf: C.eval_(model, m3_valid_ids) for clf, model in m3_models_comb.items()} 
m3_val_res_loss = {clf: C.eval_(model, m3_valid_ids) for clf, model in m3_models_loss.items()} 

m3_val_res_all = {
    **{f'{clf}_uAUC': res for clf, res in m3_val_res_uAUC.items()},
    **{f'{clf}_comb': res for clf, res in m3_val_res_comb.items()},
    **{f'{clf}_loss': res for clf, res in m3_val_res_loss.items()}
}

# %%
m3_val_auctests_all = A.codes_auc_pairwise_tests(m3_val_res_all, fast=True)

# %%
selected_clfs = tuple(sorted(m3_val_res_all.keys()))
content_set, indicator_df, data, common_codes, dichotomous_codes = A.relative_performance_upset(m3_val_auctests_all, selected_clfs, 
                                                                                              **relative_auc_config)
upset_format = from_indicators(indicator_df, data=data)

upset_object.plot()
plt.show()

# %% [markdown]
# ### Snooping on MIMIC-IV Validation Set

# %%
m4_val_res_uAUC = {clf: C.eval_(model, m4_valid_ids) for clf, model in m4_models_uAUC.items()} 
m4_val_res_comb = {clf: C.eval_(model, m4_valid_ids) for clf, model in m4_models_comb.items()} 
m4_val_res_loss = {clf: C.eval_(model, m4_valid_ids) for clf, model in m4_models_loss.items()} 

m4_val_res_all = {
    **{f'{clf}_uAUC': res for clf, res in m4_val_res_uAUC.items()},
    **{f'{clf}_comb': res for clf, res in m4_val_res_comb.items()},
    **{f'{clf}_loss': res for clf, res in m4_val_res_loss.items()}
}

# %%
m4_val_auctests_all = A.codes_auc_pairwise_tests(m4_val_res_all, fast=True)

# %%
selected_clfs = tuple(sorted(m4_val_res_all.keys()))
content_set, indicator_df, data, common_codes, dichotomous_codes = A.relative_performance_upset(m4_val_auctests_all,
                                                                                              selected_clfs, 
                                                                                              **relative_auc_config)
upset_format = from_indicators(indicator_df, data=data)
upset_object = UpSet(upset_format, subset_size='count', show_counts=True)

upset_object.plot()
plt.show()

# %% [markdown]
# ### Snooping Conclusion
#
# In the cells above, we evaluate the model competency by the number of codes
# predicted competently compared to the other models.
# It is realized that for `GRU`, `RETAIN`, and `ICENODE_UNIFORM`, the competency is maximized by picking the
# model with minimum validation loss throughout the training iterations.
# However, `ICENODE` competency is maximized by picking the model with maximum average validation AUC throughout the training iterations. Therefore, subsequent evaluations will consider only the most competent models on the validation set, as we select in the next cell.

# %%
m4_models = {}
m3_models = {}
gm4_models = {}
gm3_models = {}

selection_dicts = (m4_models, 
                   m3_models, 
                   gm4_models,
                   gm3_models)

uAUC_dicts = (m4_uAUC,
              m3_uAUC,
              gm4_uAUC,
              gm3_uAUC)

comb_dicts = (m4_comb,
              m3_comb,
              gm4_comb,
              gm3_comb)


# loss_dicts = (m4_loss,
#               m3_loss,
#               gm4_loss,
#               gm3_loss)

for dict_a, dict_b in zip(selection_dicts, uAUC_dicts):
    for k in dict_b.keys():
        dict_a[k] = dict_b[k]

# %%
def cross_predictor(clf, source_tag, target_tag):
    if '/G' in clf:
        clf = clf.replace('/G', '')
        _params = {'M3': gm3_models['params'][clf], 
                   'M4': gm4_models['params'][clf]}
        _config = {'M3': gm3_models['config'][clf], 
                   'M4': gm4_models['config'][clf]}
    else:
        _params = {'M3': m3_models['params'][clf], 
                   'M4': m4_models['params'][clf]}
        _config = {'M3': m3_models['config'][clf], 
                   'M4': m3_models['config'][clf]}
    _interface = {'M3': m3_interface, 'M4': m4_interface}

    return C.get_model(clf=clf, 
                       config=_config[source_tag], 
                       params=_params[source_tag],
                       interface = _interface[target_tag])

# %% [markdown]
# <a name="sec2"></a>
#
# ## 2 Predictive Performance on MIMIC-III (Test Set) [^](#outline)

# %%
m3_clfs =  ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg',
            'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G')

m3_predictors = {clf: cross_predictor(clf, 'M3', 'M3') for clf in m3_clfs}

# %%
test_res_m3 = {clf: C.eval2_(model, m3_test_ids) for clf, model in m3_predictors.items()}

# %%
auctests_m3 = A.codes_auc_pairwise_tests({k: v['risk_prediction'] for k, v in test_res_m3.items()}, fast=True)
# Out:
#  55%|██████████████████████▎                  | 132/242 [00:16<00:13,  8.23it/s]WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
#  56%|██████████████████████▊                  | 135/242 [00:16<00:13,  8.12it/s]WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
#  77%|███████████████████████████████▌         | 186/242 [00:22<00:06,  8.49it/s]WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# 100%|█████████████████████████████████████████| 242/242 [00:31<00:00,  7.77it/s]

# %%
test_cols = [col for col in auctests_m3.columns if col[:2] == 'P0']
auctests_m3.loc[:, test_cols].isnull().max(axis=1).sum()
# Out:
# 3

# %%
upset_clfs = ['ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', #'LogReg', 
              'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G']
upsetcontents_m3, upsetindicator_m3, data_m3,  _, compete_codesm3 = A.relative_performance_upset(auctests_m3, 
                                                                                               upset_clfs, 
                                                                                               **relative_auc_config)

upset_ctx = lambda : sns.plotting_context("paper", font_scale=1.5, rc={"font.family": "sans-serif", 
                                                                        'axes.labelsize': 'medium',
                                                                       'ytick.labelsize': 'medium'})



with sns.axes_style("darkgrid"), upset_ctx():
    upset_format = from_indicators(upsetindicator_m3, data=data_m3)
    upset_object = UpSet(upset_format, subset_size='count', show_counts=True)
    upset_object.style_subsets(max_subset_size=1,
                               facecolor="red",
                               edgecolor="red", linewidth=3)
    g = upset_object.plot()
    current_figure = plt.gcf()
    w, h = 3.5, 3
    wi, hi = current_figure.get_size_inches()
    current_figure.set_size_inches(hi*(w/h), hi)
    current_figure.savefig(f"upset_M3.pdf", bbox_inches='tight')
# Out:
# 28 codes predicted an AUC higher than 0.9 by at least one model.
# 25 codes predicted an AUC higher than 0.9 by at least one model, with valid tests.

# %%
results_m3_eval,_ = A.evaluation_table(test_res_m3, m3_train_percentiles, top_k_list=top_k_list)

# %%
table_clfs = ('LogReg', 
              'RETAIN',
              'GRU',
              'GRU/G',
              'ICE-NODE', 
              'ICE-NODE/G',
              'ICE-NODE_UNIFORM',
              'ICE-NODE_UNIFORM/G'
              )
results_m3_tables = A.top_k_tables(table_clfs, results_m3_eval, top_k_list=top_k_list,
                                   n_percentiles=n_percentiles, out_prefix=f'{output_dir}/M3')
# Out:
# <style type="text/css">
# #T_7e9cd_row0_col0, #T_7e9cd_row0_col1, #T_7e9cd_row0_col3, #T_7e9cd_row5_col2, #T_7e9cd_row6_col4, #T_7e9cd_row7_col2 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_7e9cd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k1</th>
#       <th class="col_heading level0 col1" >ACC-P1-k1</th>
#       <th class="col_heading level0 col2" >ACC-P2-k1</th>
#       <th class="col_heading level0 col3" >ACC-P3-k1</th>
#       <th class="col_heading level0 col4" >ACC-P4-k1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e9cd_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_7e9cd_row0_col0" class="data row0 col0" >0.043</td>
#       <td id="T_7e9cd_row0_col1" class="data row0 col1" >0.097</td>
#       <td id="T_7e9cd_row0_col2" class="data row0 col2" >0.048</td>
#       <td id="T_7e9cd_row0_col3" class="data row0 col3" >0.070</td>
#       <td id="T_7e9cd_row0_col4" class="data row0 col4" >0.102</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_7e9cd_row1_col0" class="data row1 col0" >0.033</td>
#       <td id="T_7e9cd_row1_col1" class="data row1 col1" >0.075</td>
#       <td id="T_7e9cd_row1_col2" class="data row1 col2" >0.068</td>
#       <td id="T_7e9cd_row1_col3" class="data row1 col3" >0.063</td>
#       <td id="T_7e9cd_row1_col4" class="data row1 col4" >0.153</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_7e9cd_row2_col0" class="data row2 col0" >0.040</td>
#       <td id="T_7e9cd_row2_col1" class="data row2 col1" >0.071</td>
#       <td id="T_7e9cd_row2_col2" class="data row2 col2" >0.059</td>
#       <td id="T_7e9cd_row2_col3" class="data row2 col3" >0.067</td>
#       <td id="T_7e9cd_row2_col4" class="data row2 col4" >0.138</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_7e9cd_row3_col0" class="data row3 col0" >0.037</td>
#       <td id="T_7e9cd_row3_col1" class="data row3 col1" >0.069</td>
#       <td id="T_7e9cd_row3_col2" class="data row3 col2" >0.064</td>
#       <td id="T_7e9cd_row3_col3" class="data row3 col3" >0.059</td>
#       <td id="T_7e9cd_row3_col4" class="data row3 col4" >0.148</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_7e9cd_row4_col0" class="data row4 col0" >0.031</td>
#       <td id="T_7e9cd_row4_col1" class="data row4 col1" >0.073</td>
#       <td id="T_7e9cd_row4_col2" class="data row4 col2" >0.068</td>
#       <td id="T_7e9cd_row4_col3" class="data row4 col3" >0.048</td>
#       <td id="T_7e9cd_row4_col4" class="data row4 col4" >0.174</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_7e9cd_row5_col0" class="data row5 col0" >0.032</td>
#       <td id="T_7e9cd_row5_col1" class="data row5 col1" >0.071</td>
#       <td id="T_7e9cd_row5_col2" class="data row5 col2" >0.071</td>
#       <td id="T_7e9cd_row5_col3" class="data row5 col3" >0.049</td>
#       <td id="T_7e9cd_row5_col4" class="data row5 col4" >0.175</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_7e9cd_row6_col0" class="data row6 col0" >0.028</td>
#       <td id="T_7e9cd_row6_col1" class="data row6 col1" >0.076</td>
#       <td id="T_7e9cd_row6_col2" class="data row6 col2" >0.062</td>
#       <td id="T_7e9cd_row6_col3" class="data row6 col3" >0.052</td>
#       <td id="T_7e9cd_row6_col4" class="data row6 col4" >0.180</td>
#     </tr>
#     <tr>
#       <th id="T_7e9cd_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_7e9cd_row7_col0" class="data row7 col0" >0.032</td>
#       <td id="T_7e9cd_row7_col1" class="data row7 col1" >0.072</td>
#       <td id="T_7e9cd_row7_col2" class="data row7 col2" >0.071</td>
#       <td id="T_7e9cd_row7_col3" class="data row7 col3" >0.050</td>
#       <td id="T_7e9cd_row7_col4" class="data row7 col4" >0.173</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k1} & {ACC-P1-k1} & {ACC-P2-k1} & {ACC-P3-k1} & {ACC-P4-k1} \\
# \texttt{LogReg} & \color{white} {\cellcolor{darkblue}} 0.043 & \color{white} {\cellcolor{darkblue}} 0.097 & 0.048 & \color{white} {\cellcolor{darkblue}} 0.070 & 0.102 \\
# \texttt{RETAIN} & 0.033 & 0.075 & 0.068 & 0.063 & 0.153 \\
# \texttt{GRU} & 0.040 & 0.071 & 0.059 & 0.067 & 0.138 \\
# \texttt{GRU/G} & 0.037 & 0.069 & 0.064 & 0.059 & 0.148 \\
# \texttt{ICE-NODE} & 0.031 & 0.073 & 0.068 & 0.048 & 0.174 \\
# \texttt{ICE-NODE/G} & 0.032 & 0.071 & \color{white} {\cellcolor{darkblue}} 0.071 & 0.049 & 0.175 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.028 & 0.076 & 0.062 & 0.052 & \color{white} {\cellcolor{darkblue}} 0.180 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.032 & 0.072 & \color{white} {\cellcolor{darkblue}} 0.071 & 0.050 & 0.173 \\
# \end{tabular}
# <style type="text/css">
# #T_c6dee_row0_col1, #T_c6dee_row0_col3, #T_c6dee_row1_col2, #T_c6dee_row2_col0, #T_c6dee_row5_col4 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_c6dee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k2</th>
#       <th class="col_heading level0 col1" >ACC-P1-k2</th>
#       <th class="col_heading level0 col2" >ACC-P2-k2</th>
#       <th class="col_heading level0 col3" >ACC-P3-k2</th>
#       <th class="col_heading level0 col4" >ACC-P4-k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6dee_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_c6dee_row0_col0" class="data row0 col0" >0.064</td>
#       <td id="T_c6dee_row0_col1" class="data row0 col1" >0.155</td>
#       <td id="T_c6dee_row0_col2" class="data row0 col2" >0.104</td>
#       <td id="T_c6dee_row0_col3" class="data row0 col3" >0.162</td>
#       <td id="T_c6dee_row0_col4" class="data row0 col4" >0.198</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_c6dee_row1_col0" class="data row1 col0" >0.052</td>
#       <td id="T_c6dee_row1_col1" class="data row1 col1" >0.131</td>
#       <td id="T_c6dee_row1_col2" class="data row1 col2" >0.128</td>
#       <td id="T_c6dee_row1_col3" class="data row1 col3" >0.127</td>
#       <td id="T_c6dee_row1_col4" class="data row1 col4" >0.288</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_c6dee_row2_col0" class="data row2 col0" >0.067</td>
#       <td id="T_c6dee_row2_col1" class="data row2 col1" >0.123</td>
#       <td id="T_c6dee_row2_col2" class="data row2 col2" >0.114</td>
#       <td id="T_c6dee_row2_col3" class="data row2 col3" >0.128</td>
#       <td id="T_c6dee_row2_col4" class="data row2 col4" >0.265</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_c6dee_row3_col0" class="data row3 col0" >0.056</td>
#       <td id="T_c6dee_row3_col1" class="data row3 col1" >0.125</td>
#       <td id="T_c6dee_row3_col2" class="data row3 col2" >0.120</td>
#       <td id="T_c6dee_row3_col3" class="data row3 col3" >0.125</td>
#       <td id="T_c6dee_row3_col4" class="data row3 col4" >0.282</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_c6dee_row4_col0" class="data row4 col0" >0.054</td>
#       <td id="T_c6dee_row4_col1" class="data row4 col1" >0.127</td>
#       <td id="T_c6dee_row4_col2" class="data row4 col2" >0.122</td>
#       <td id="T_c6dee_row4_col3" class="data row4 col3" >0.124</td>
#       <td id="T_c6dee_row4_col4" class="data row4 col4" >0.311</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_c6dee_row5_col0" class="data row5 col0" >0.056</td>
#       <td id="T_c6dee_row5_col1" class="data row5 col1" >0.127</td>
#       <td id="T_c6dee_row5_col2" class="data row5 col2" >0.123</td>
#       <td id="T_c6dee_row5_col3" class="data row5 col3" >0.124</td>
#       <td id="T_c6dee_row5_col4" class="data row5 col4" >0.317</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_c6dee_row6_col0" class="data row6 col0" >0.053</td>
#       <td id="T_c6dee_row6_col1" class="data row6 col1" >0.126</td>
#       <td id="T_c6dee_row6_col2" class="data row6 col2" >0.111</td>
#       <td id="T_c6dee_row6_col3" class="data row6 col3" >0.134</td>
#       <td id="T_c6dee_row6_col4" class="data row6 col4" >0.316</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_c6dee_row7_col0" class="data row7 col0" >0.057</td>
#       <td id="T_c6dee_row7_col1" class="data row7 col1" >0.128</td>
#       <td id="T_c6dee_row7_col2" class="data row7 col2" >0.124</td>
#       <td id="T_c6dee_row7_col3" class="data row7 col3" >0.124</td>
#       <td id="T_c6dee_row7_col4" class="data row7 col4" >0.315</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k2} & {ACC-P1-k2} & {ACC-P2-k2} & {ACC-P3-k2} & {ACC-P4-k2} \\
# \texttt{LogReg} & 0.064 & \color{white} {\cellcolor{darkblue}} 0.155 & 0.104 & \color{white} {\cellcolor{darkblue}} 0.162 & 0.198 \\
# \texttt{RETAIN} & 0.052 & 0.131 & \color{white} {\cellcolor{darkblue}} 0.128 & 0.127 & 0.288 \\
# \texttt{GRU} & \color{white} {\cellcolor{darkblue}} 0.067 & 0.123 & 0.114 & 0.128 & 0.265 \\
# \texttt{GRU/G} & 0.056 & 0.125 & 0.120 & 0.125 & 0.282 \\
# \texttt{ICE-NODE} & 0.054 & 0.127 & 0.122 & 0.124 & 0.311 \\
# \texttt{ICE-NODE/G} & 0.056 & 0.127 & 0.123 & 0.124 & \color{white} {\cellcolor{darkblue}} 0.317 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.053 & 0.126 & 0.111 & 0.134 & 0.316 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.057 & 0.128 & 0.124 & 0.124 & 0.315 \\
# \end{tabular}
# <style type="text/css">
# #T_6b42c_row0_col1, #T_6b42c_row0_col3, #T_6b42c_row2_col0, #T_6b42c_row5_col2, #T_6b42c_row6_col4 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_6b42c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k3</th>
#       <th class="col_heading level0 col1" >ACC-P1-k3</th>
#       <th class="col_heading level0 col2" >ACC-P2-k3</th>
#       <th class="col_heading level0 col3" >ACC-P3-k3</th>
#       <th class="col_heading level0 col4" >ACC-P4-k3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b42c_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_6b42c_row0_col0" class="data row0 col0" >0.081</td>
#       <td id="T_6b42c_row0_col1" class="data row0 col1" >0.198</td>
#       <td id="T_6b42c_row0_col2" class="data row0 col2" >0.162</td>
#       <td id="T_6b42c_row0_col3" class="data row0 col3" >0.214</td>
#       <td id="T_6b42c_row0_col4" class="data row0 col4" >0.291</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_6b42c_row1_col0" class="data row1 col0" >0.072</td>
#       <td id="T_6b42c_row1_col1" class="data row1 col1" >0.168</td>
#       <td id="T_6b42c_row1_col2" class="data row1 col2" >0.173</td>
#       <td id="T_6b42c_row1_col3" class="data row1 col3" >0.197</td>
#       <td id="T_6b42c_row1_col4" class="data row1 col4" >0.411</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_6b42c_row2_col0" class="data row2 col0" >0.087</td>
#       <td id="T_6b42c_row2_col1" class="data row2 col1" >0.155</td>
#       <td id="T_6b42c_row2_col2" class="data row2 col2" >0.166</td>
#       <td id="T_6b42c_row2_col3" class="data row2 col3" >0.195</td>
#       <td id="T_6b42c_row2_col4" class="data row2 col4" >0.378</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_6b42c_row3_col0" class="data row3 col0" >0.076</td>
#       <td id="T_6b42c_row3_col1" class="data row3 col1" >0.163</td>
#       <td id="T_6b42c_row3_col2" class="data row3 col2" >0.166</td>
#       <td id="T_6b42c_row3_col3" class="data row3 col3" >0.201</td>
#       <td id="T_6b42c_row3_col4" class="data row3 col4" >0.395</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_6b42c_row4_col0" class="data row4 col0" >0.075</td>
#       <td id="T_6b42c_row4_col1" class="data row4 col1" >0.167</td>
#       <td id="T_6b42c_row4_col2" class="data row4 col2" >0.175</td>
#       <td id="T_6b42c_row4_col3" class="data row4 col3" >0.200</td>
#       <td id="T_6b42c_row4_col4" class="data row4 col4" >0.439</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_6b42c_row5_col0" class="data row5 col0" >0.073</td>
#       <td id="T_6b42c_row5_col1" class="data row5 col1" >0.164</td>
#       <td id="T_6b42c_row5_col2" class="data row5 col2" >0.176</td>
#       <td id="T_6b42c_row5_col3" class="data row5 col3" >0.198</td>
#       <td id="T_6b42c_row5_col4" class="data row5 col4" >0.433</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_6b42c_row6_col0" class="data row6 col0" >0.074</td>
#       <td id="T_6b42c_row6_col1" class="data row6 col1" >0.163</td>
#       <td id="T_6b42c_row6_col2" class="data row6 col2" >0.168</td>
#       <td id="T_6b42c_row6_col3" class="data row6 col3" >0.208</td>
#       <td id="T_6b42c_row6_col4" class="data row6 col4" >0.442</td>
#     </tr>
#     <tr>
#       <th id="T_6b42c_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_6b42c_row7_col0" class="data row7 col0" >0.071</td>
#       <td id="T_6b42c_row7_col1" class="data row7 col1" >0.164</td>
#       <td id="T_6b42c_row7_col2" class="data row7 col2" >0.171</td>
#       <td id="T_6b42c_row7_col3" class="data row7 col3" >0.202</td>
#       <td id="T_6b42c_row7_col4" class="data row7 col4" >0.438</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k3} & {ACC-P1-k3} & {ACC-P2-k3} & {ACC-P3-k3} & {ACC-P4-k3} \\
# \texttt{LogReg} & 0.081 & \color{white} {\cellcolor{darkblue}} 0.198 & 0.162 & \color{white} {\cellcolor{darkblue}} 0.214 & 0.291 \\
# \texttt{RETAIN} & 0.072 & 0.168 & 0.173 & 0.197 & 0.411 \\
# \texttt{GRU} & \color{white} {\cellcolor{darkblue}} 0.087 & 0.155 & 0.166 & 0.195 & 0.378 \\
# \texttt{GRU/G} & 0.076 & 0.163 & 0.166 & 0.201 & 0.395 \\
# \texttt{ICE-NODE} & 0.075 & 0.167 & 0.175 & 0.200 & 0.439 \\
# \texttt{ICE-NODE/G} & 0.073 & 0.164 & \color{white} {\cellcolor{darkblue}} 0.176 & 0.198 & 0.433 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.074 & 0.163 & 0.168 & 0.208 & \color{white} {\cellcolor{darkblue}} 0.442 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.071 & 0.164 & 0.171 & 0.202 & 0.438 \\
# \end{tabular}
# <style type="text/css">
# #T_de4c0_row0_col1, #T_de4c0_row1_col2, #T_de4c0_row2_col0, #T_de4c0_row3_col3, #T_de4c0_row6_col4 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_de4c0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k5</th>
#       <th class="col_heading level0 col1" >ACC-P1-k5</th>
#       <th class="col_heading level0 col2" >ACC-P2-k5</th>
#       <th class="col_heading level0 col3" >ACC-P3-k5</th>
#       <th class="col_heading level0 col4" >ACC-P4-k5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de4c0_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_de4c0_row0_col0" class="data row0 col0" >0.103</td>
#       <td id="T_de4c0_row0_col1" class="data row0 col1" >0.263</td>
#       <td id="T_de4c0_row0_col2" class="data row0 col2" >0.248</td>
#       <td id="T_de4c0_row0_col3" class="data row0 col3" >0.322</td>
#       <td id="T_de4c0_row0_col4" class="data row0 col4" >0.437</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_de4c0_row1_col0" class="data row1 col0" >0.109</td>
#       <td id="T_de4c0_row1_col1" class="data row1 col1" >0.225</td>
#       <td id="T_de4c0_row1_col2" class="data row1 col2" >0.282</td>
#       <td id="T_de4c0_row1_col3" class="data row1 col3" >0.320</td>
#       <td id="T_de4c0_row1_col4" class="data row1 col4" >0.584</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_de4c0_row2_col0" class="data row2 col0" >0.116</td>
#       <td id="T_de4c0_row2_col1" class="data row2 col1" >0.215</td>
#       <td id="T_de4c0_row2_col2" class="data row2 col2" >0.244</td>
#       <td id="T_de4c0_row2_col3" class="data row2 col3" >0.346</td>
#       <td id="T_de4c0_row2_col4" class="data row2 col4" >0.556</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_de4c0_row3_col0" class="data row3 col0" >0.107</td>
#       <td id="T_de4c0_row3_col1" class="data row3 col1" >0.217</td>
#       <td id="T_de4c0_row3_col2" class="data row3 col2" >0.251</td>
#       <td id="T_de4c0_row3_col3" class="data row3 col3" >0.350</td>
#       <td id="T_de4c0_row3_col4" class="data row3 col4" >0.571</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_de4c0_row4_col0" class="data row4 col0" >0.104</td>
#       <td id="T_de4c0_row4_col1" class="data row4 col1" >0.226</td>
#       <td id="T_de4c0_row4_col2" class="data row4 col2" >0.268</td>
#       <td id="T_de4c0_row4_col3" class="data row4 col3" >0.337</td>
#       <td id="T_de4c0_row4_col4" class="data row4 col4" >0.601</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_de4c0_row5_col0" class="data row5 col0" >0.102</td>
#       <td id="T_de4c0_row5_col1" class="data row5 col1" >0.219</td>
#       <td id="T_de4c0_row5_col2" class="data row5 col2" >0.262</td>
#       <td id="T_de4c0_row5_col3" class="data row5 col3" >0.339</td>
#       <td id="T_de4c0_row5_col4" class="data row5 col4" >0.604</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_de4c0_row6_col0" class="data row6 col0" >0.102</td>
#       <td id="T_de4c0_row6_col1" class="data row6 col1" >0.221</td>
#       <td id="T_de4c0_row6_col2" class="data row6 col2" >0.259</td>
#       <td id="T_de4c0_row6_col3" class="data row6 col3" >0.345</td>
#       <td id="T_de4c0_row6_col4" class="data row6 col4" >0.608</td>
#     </tr>
#     <tr>
#       <th id="T_de4c0_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_de4c0_row7_col0" class="data row7 col0" >0.103</td>
#       <td id="T_de4c0_row7_col1" class="data row7 col1" >0.221</td>
#       <td id="T_de4c0_row7_col2" class="data row7 col2" >0.263</td>
#       <td id="T_de4c0_row7_col3" class="data row7 col3" >0.338</td>
#       <td id="T_de4c0_row7_col4" class="data row7 col4" >0.603</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k5} & {ACC-P1-k5} & {ACC-P2-k5} & {ACC-P3-k5} & {ACC-P4-k5} \\
# \texttt{LogReg} & 0.103 & \color{white} {\cellcolor{darkblue}} 0.263 & 0.248 & 0.322 & 0.437 \\
# \texttt{RETAIN} & 0.109 & 0.225 & \color{white} {\cellcolor{darkblue}} 0.282 & 0.320 & 0.584 \\
# \texttt{GRU} & \color{white} {\cellcolor{darkblue}} 0.116 & 0.215 & 0.244 & 0.346 & 0.556 \\
# \texttt{GRU/G} & 0.107 & 0.217 & 0.251 & \color{white} {\cellcolor{darkblue}} 0.350 & 0.571 \\
# \texttt{ICE-NODE} & 0.104 & 0.226 & 0.268 & 0.337 & 0.601 \\
# \texttt{ICE-NODE/G} & 0.102 & 0.219 & 0.262 & 0.339 & 0.604 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.102 & 0.221 & 0.259 & 0.345 & \color{white} {\cellcolor{darkblue}} 0.608 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.103 & 0.221 & 0.263 & 0.338 & 0.603 \\
# \end{tabular}
# <style type="text/css">
# #T_7fe61_row0_col1, #T_7fe61_row1_col0, #T_7fe61_row1_col2, #T_7fe61_row3_col3, #T_7fe61_row6_col4 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_7fe61_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k7</th>
#       <th class="col_heading level0 col1" >ACC-P1-k7</th>
#       <th class="col_heading level0 col2" >ACC-P2-k7</th>
#       <th class="col_heading level0 col3" >ACC-P3-k7</th>
#       <th class="col_heading level0 col4" >ACC-P4-k7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fe61_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_7fe61_row0_col0" class="data row0 col0" >0.119</td>
#       <td id="T_7fe61_row0_col1" class="data row0 col1" >0.312</td>
#       <td id="T_7fe61_row0_col2" class="data row0 col2" >0.330</td>
#       <td id="T_7fe61_row0_col3" class="data row0 col3" >0.403</td>
#       <td id="T_7fe61_row0_col4" class="data row0 col4" >0.547</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_7fe61_row1_col0" class="data row1 col0" >0.142</td>
#       <td id="T_7fe61_row1_col1" class="data row1 col1" >0.267</td>
#       <td id="T_7fe61_row1_col2" class="data row1 col2" >0.353</td>
#       <td id="T_7fe61_row1_col3" class="data row1 col3" >0.450</td>
#       <td id="T_7fe61_row1_col4" class="data row1 col4" >0.709</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_7fe61_row2_col0" class="data row2 col0" >0.141</td>
#       <td id="T_7fe61_row2_col1" class="data row2 col1" >0.265</td>
#       <td id="T_7fe61_row2_col2" class="data row2 col2" >0.318</td>
#       <td id="T_7fe61_row2_col3" class="data row2 col3" >0.470</td>
#       <td id="T_7fe61_row2_col4" class="data row2 col4" >0.673</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_7fe61_row3_col0" class="data row3 col0" >0.125</td>
#       <td id="T_7fe61_row3_col1" class="data row3 col1" >0.268</td>
#       <td id="T_7fe61_row3_col2" class="data row3 col2" >0.318</td>
#       <td id="T_7fe61_row3_col3" class="data row3 col3" >0.485</td>
#       <td id="T_7fe61_row3_col4" class="data row3 col4" >0.689</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_7fe61_row4_col0" class="data row4 col0" >0.140</td>
#       <td id="T_7fe61_row4_col1" class="data row4 col1" >0.275</td>
#       <td id="T_7fe61_row4_col2" class="data row4 col2" >0.339</td>
#       <td id="T_7fe61_row4_col3" class="data row4 col3" >0.462</td>
#       <td id="T_7fe61_row4_col4" class="data row4 col4" >0.715</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_7fe61_row5_col0" class="data row5 col0" >0.125</td>
#       <td id="T_7fe61_row5_col1" class="data row5 col1" >0.270</td>
#       <td id="T_7fe61_row5_col2" class="data row5 col2" >0.337</td>
#       <td id="T_7fe61_row5_col3" class="data row5 col3" >0.460</td>
#       <td id="T_7fe61_row5_col4" class="data row5 col4" >0.715</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_7fe61_row6_col0" class="data row6 col0" >0.126</td>
#       <td id="T_7fe61_row6_col1" class="data row6 col1" >0.277</td>
#       <td id="T_7fe61_row6_col2" class="data row6 col2" >0.327</td>
#       <td id="T_7fe61_row6_col3" class="data row6 col3" >0.476</td>
#       <td id="T_7fe61_row6_col4" class="data row6 col4" >0.729</td>
#     </tr>
#     <tr>
#       <th id="T_7fe61_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_7fe61_row7_col0" class="data row7 col0" >0.128</td>
#       <td id="T_7fe61_row7_col1" class="data row7 col1" >0.272</td>
#       <td id="T_7fe61_row7_col2" class="data row7 col2" >0.334</td>
#       <td id="T_7fe61_row7_col3" class="data row7 col3" >0.456</td>
#       <td id="T_7fe61_row7_col4" class="data row7 col4" >0.718</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k7} & {ACC-P1-k7} & {ACC-P2-k7} & {ACC-P3-k7} & {ACC-P4-k7} \\
# \texttt{LogReg} & 0.119 & \color{white} {\cellcolor{darkblue}} 0.312 & 0.330 & 0.403 & 0.547 \\
# \texttt{RETAIN} & \color{white} {\cellcolor{darkblue}} 0.142 & 0.267 & \color{white} {\cellcolor{darkblue}} 0.353 & 0.450 & 0.709 \\
# \texttt{GRU} & 0.141 & 0.265 & 0.318 & 0.470 & 0.673 \\
# \texttt{GRU/G} & 0.125 & 0.268 & 0.318 & \color{white} {\cellcolor{darkblue}} 0.485 & 0.689 \\
# \texttt{ICE-NODE} & 0.140 & 0.275 & 0.339 & 0.462 & 0.715 \\
# \texttt{ICE-NODE/G} & 0.125 & 0.270 & 0.337 & 0.460 & 0.715 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.126 & 0.277 & 0.327 & 0.476 & \color{white} {\cellcolor{darkblue}} 0.729 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.128 & 0.272 & 0.334 & 0.456 & 0.718 \\
# \end{tabular}
# <style type="text/css">
# #T_1bdc1_row0_col1, #T_1bdc1_row1_col2, #T_1bdc1_row1_col4, #T_1bdc1_row4_col0, #T_1bdc1_row6_col3 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_1bdc1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k10</th>
#       <th class="col_heading level0 col1" >ACC-P1-k10</th>
#       <th class="col_heading level0 col2" >ACC-P2-k10</th>
#       <th class="col_heading level0 col3" >ACC-P3-k10</th>
#       <th class="col_heading level0 col4" >ACC-P4-k10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bdc1_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_1bdc1_row0_col0" class="data row0 col0" >0.141</td>
#       <td id="T_1bdc1_row0_col1" class="data row0 col1" >0.385</td>
#       <td id="T_1bdc1_row0_col2" class="data row0 col2" >0.419</td>
#       <td id="T_1bdc1_row0_col3" class="data row0 col3" >0.500</td>
#       <td id="T_1bdc1_row0_col4" class="data row0 col4" >0.661</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_1bdc1_row1_col0" class="data row1 col0" >0.168</td>
#       <td id="T_1bdc1_row1_col1" class="data row1 col1" >0.336</td>
#       <td id="T_1bdc1_row1_col2" class="data row1 col2" >0.444</td>
#       <td id="T_1bdc1_row1_col3" class="data row1 col3" >0.607</td>
#       <td id="T_1bdc1_row1_col4" class="data row1 col4" >0.823</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_1bdc1_row2_col0" class="data row2 col0" >0.165</td>
#       <td id="T_1bdc1_row2_col1" class="data row2 col1" >0.317</td>
#       <td id="T_1bdc1_row2_col2" class="data row2 col2" >0.423</td>
#       <td id="T_1bdc1_row2_col3" class="data row2 col3" >0.613</td>
#       <td id="T_1bdc1_row2_col4" class="data row2 col4" >0.789</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_1bdc1_row3_col0" class="data row3 col0" >0.156</td>
#       <td id="T_1bdc1_row3_col1" class="data row3 col1" >0.326</td>
#       <td id="T_1bdc1_row3_col2" class="data row3 col2" >0.422</td>
#       <td id="T_1bdc1_row3_col3" class="data row3 col3" >0.620</td>
#       <td id="T_1bdc1_row3_col4" class="data row3 col4" >0.805</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_1bdc1_row4_col0" class="data row4 col0" >0.175</td>
#       <td id="T_1bdc1_row4_col1" class="data row4 col1" >0.342</td>
#       <td id="T_1bdc1_row4_col2" class="data row4 col2" >0.442</td>
#       <td id="T_1bdc1_row4_col3" class="data row4 col3" >0.627</td>
#       <td id="T_1bdc1_row4_col4" class="data row4 col4" >0.811</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_1bdc1_row5_col0" class="data row5 col0" >0.159</td>
#       <td id="T_1bdc1_row5_col1" class="data row5 col1" >0.334</td>
#       <td id="T_1bdc1_row5_col2" class="data row5 col2" >0.436</td>
#       <td id="T_1bdc1_row5_col3" class="data row5 col3" >0.618</td>
#       <td id="T_1bdc1_row5_col4" class="data row5 col4" >0.813</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_1bdc1_row6_col0" class="data row6 col0" >0.166</td>
#       <td id="T_1bdc1_row6_col1" class="data row6 col1" >0.341</td>
#       <td id="T_1bdc1_row6_col2" class="data row6 col2" >0.432</td>
#       <td id="T_1bdc1_row6_col3" class="data row6 col3" >0.633</td>
#       <td id="T_1bdc1_row6_col4" class="data row6 col4" >0.818</td>
#     </tr>
#     <tr>
#       <th id="T_1bdc1_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_1bdc1_row7_col0" class="data row7 col0" >0.161</td>
#       <td id="T_1bdc1_row7_col1" class="data row7 col1" >0.333</td>
#       <td id="T_1bdc1_row7_col2" class="data row7 col2" >0.432</td>
#       <td id="T_1bdc1_row7_col3" class="data row7 col3" >0.618</td>
#       <td id="T_1bdc1_row7_col4" class="data row7 col4" >0.812</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k10} & {ACC-P1-k10} & {ACC-P2-k10} & {ACC-P3-k10} & {ACC-P4-k10} \\
# \texttt{LogReg} & 0.141 & \color{white} {\cellcolor{darkblue}} 0.385 & 0.419 & 0.500 & 0.661 \\
# \texttt{RETAIN} & 0.168 & 0.336 & \color{white} {\cellcolor{darkblue}} 0.444 & 0.607 & \color{white} {\cellcolor{darkblue}} 0.823 \\
# \texttt{GRU} & 0.165 & 0.317 & 0.423 & 0.613 & 0.789 \\
# \texttt{GRU/G} & 0.156 & 0.326 & 0.422 & 0.620 & 0.805 \\
# \texttt{ICE-NODE} & \color{white} {\cellcolor{darkblue}} 0.175 & 0.342 & 0.442 & 0.627 & 0.811 \\
# \texttt{ICE-NODE/G} & 0.159 & 0.334 & 0.436 & 0.618 & 0.813 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.166 & 0.341 & 0.432 & \color{white} {\cellcolor{darkblue}} 0.633 & 0.818 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.161 & 0.333 & 0.432 & 0.618 & 0.812 \\
# \end{tabular}
# <style type="text/css">
# #T_7ff50_row0_col1, #T_7ff50_row1_col2, #T_7ff50_row1_col4, #T_7ff50_row4_col0, #T_7ff50_row6_col3 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_7ff50_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k15</th>
#       <th class="col_heading level0 col1" >ACC-P1-k15</th>
#       <th class="col_heading level0 col2" >ACC-P2-k15</th>
#       <th class="col_heading level0 col3" >ACC-P3-k15</th>
#       <th class="col_heading level0 col4" >ACC-P4-k15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ff50_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_7ff50_row0_col0" class="data row0 col0" >0.164</td>
#       <td id="T_7ff50_row0_col1" class="data row0 col1" >0.454</td>
#       <td id="T_7ff50_row0_col2" class="data row0 col2" >0.544</td>
#       <td id="T_7ff50_row0_col3" class="data row0 col3" >0.683</td>
#       <td id="T_7ff50_row0_col4" class="data row0 col4" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_7ff50_row1_col0" class="data row1 col0" >0.208</td>
#       <td id="T_7ff50_row1_col1" class="data row1 col1" >0.415</td>
#       <td id="T_7ff50_row1_col2" class="data row1 col2" >0.579</td>
#       <td id="T_7ff50_row1_col3" class="data row1 col3" >0.778</td>
#       <td id="T_7ff50_row1_col4" class="data row1 col4" >0.926</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_7ff50_row2_col0" class="data row2 col0" >0.214</td>
#       <td id="T_7ff50_row2_col1" class="data row2 col1" >0.400</td>
#       <td id="T_7ff50_row2_col2" class="data row2 col2" >0.556</td>
#       <td id="T_7ff50_row2_col3" class="data row2 col3" >0.768</td>
#       <td id="T_7ff50_row2_col4" class="data row2 col4" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_7ff50_row3_col0" class="data row3 col0" >0.204</td>
#       <td id="T_7ff50_row3_col1" class="data row3 col1" >0.403</td>
#       <td id="T_7ff50_row3_col2" class="data row3 col2" >0.546</td>
#       <td id="T_7ff50_row3_col3" class="data row3 col3" >0.778</td>
#       <td id="T_7ff50_row3_col4" class="data row3 col4" >0.906</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_7ff50_row4_col0" class="data row4 col0" >0.220</td>
#       <td id="T_7ff50_row4_col1" class="data row4 col1" >0.425</td>
#       <td id="T_7ff50_row4_col2" class="data row4 col2" >0.578</td>
#       <td id="T_7ff50_row4_col3" class="data row4 col3" >0.782</td>
#       <td id="T_7ff50_row4_col4" class="data row4 col4" >0.902</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_7ff50_row5_col0" class="data row5 col0" >0.205</td>
#       <td id="T_7ff50_row5_col1" class="data row5 col1" >0.421</td>
#       <td id="T_7ff50_row5_col2" class="data row5 col2" >0.569</td>
#       <td id="T_7ff50_row5_col3" class="data row5 col3" >0.782</td>
#       <td id="T_7ff50_row5_col4" class="data row5 col4" >0.907</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_7ff50_row6_col0" class="data row6 col0" >0.211</td>
#       <td id="T_7ff50_row6_col1" class="data row6 col1" >0.422</td>
#       <td id="T_7ff50_row6_col2" class="data row6 col2" >0.566</td>
#       <td id="T_7ff50_row6_col3" class="data row6 col3" >0.786</td>
#       <td id="T_7ff50_row6_col4" class="data row6 col4" >0.909</td>
#     </tr>
#     <tr>
#       <th id="T_7ff50_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_7ff50_row7_col0" class="data row7 col0" >0.206</td>
#       <td id="T_7ff50_row7_col1" class="data row7 col1" >0.419</td>
#       <td id="T_7ff50_row7_col2" class="data row7 col2" >0.565</td>
#       <td id="T_7ff50_row7_col3" class="data row7 col3" >0.782</td>
#       <td id="T_7ff50_row7_col4" class="data row7 col4" >0.907</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k15} & {ACC-P1-k15} & {ACC-P2-k15} & {ACC-P3-k15} & {ACC-P4-k15} \\
# \texttt{LogReg} & 0.164 & \color{white} {\cellcolor{darkblue}} 0.454 & 0.544 & 0.683 & 0.777 \\
# \texttt{RETAIN} & 0.208 & 0.415 & \color{white} {\cellcolor{darkblue}} 0.579 & 0.778 & \color{white} {\cellcolor{darkblue}} 0.926 \\
# \texttt{GRU} & 0.214 & 0.400 & 0.556 & 0.768 & 0.900 \\
# \texttt{GRU/G} & 0.204 & 0.403 & 0.546 & 0.778 & 0.906 \\
# \texttt{ICE-NODE} & \color{white} {\cellcolor{darkblue}} 0.220 & 0.425 & 0.578 & 0.782 & 0.902 \\
# \texttt{ICE-NODE/G} & 0.205 & 0.421 & 0.569 & 0.782 & 0.907 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.211 & 0.422 & 0.566 & \color{white} {\cellcolor{darkblue}} 0.786 & 0.909 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.206 & 0.419 & 0.565 & 0.782 & 0.907 \\
# \end{tabular}
# <style type="text/css">
# #T_ed785_row0_col1, #T_ed785_row1_col2, #T_ed785_row1_col3, #T_ed785_row1_col4, #T_ed785_row4_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_ed785_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k20</th>
#       <th class="col_heading level0 col1" >ACC-P1-k20</th>
#       <th class="col_heading level0 col2" >ACC-P2-k20</th>
#       <th class="col_heading level0 col3" >ACC-P3-k20</th>
#       <th class="col_heading level0 col4" >ACC-P4-k20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed785_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_ed785_row0_col0" class="data row0 col0" >0.184</td>
#       <td id="T_ed785_row0_col1" class="data row0 col1" >0.525</td>
#       <td id="T_ed785_row0_col2" class="data row0 col2" >0.647</td>
#       <td id="T_ed785_row0_col3" class="data row0 col3" >0.798</td>
#       <td id="T_ed785_row0_col4" class="data row0 col4" >0.848</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_ed785_row1_col0" class="data row1 col0" >0.245</td>
#       <td id="T_ed785_row1_col1" class="data row1 col1" >0.487</td>
#       <td id="T_ed785_row1_col2" class="data row1 col2" >0.690</td>
#       <td id="T_ed785_row1_col3" class="data row1 col3" >0.877</td>
#       <td id="T_ed785_row1_col4" class="data row1 col4" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_ed785_row2_col0" class="data row2 col0" >0.248</td>
#       <td id="T_ed785_row2_col1" class="data row2 col1" >0.478</td>
#       <td id="T_ed785_row2_col2" class="data row2 col2" >0.660</td>
#       <td id="T_ed785_row2_col3" class="data row2 col3" >0.859</td>
#       <td id="T_ed785_row2_col4" class="data row2 col4" >0.954</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_ed785_row3_col0" class="data row3 col0" >0.236</td>
#       <td id="T_ed785_row3_col1" class="data row3 col1" >0.465</td>
#       <td id="T_ed785_row3_col2" class="data row3 col2" >0.663</td>
#       <td id="T_ed785_row3_col3" class="data row3 col3" >0.864</td>
#       <td id="T_ed785_row3_col4" class="data row3 col4" >0.953</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_ed785_row4_col0" class="data row4 col0" >0.265</td>
#       <td id="T_ed785_row4_col1" class="data row4 col1" >0.504</td>
#       <td id="T_ed785_row4_col2" class="data row4 col2" >0.675</td>
#       <td id="T_ed785_row4_col3" class="data row4 col3" >0.854</td>
#       <td id="T_ed785_row4_col4" class="data row4 col4" >0.943</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_ed785_row5_col0" class="data row5 col0" >0.244</td>
#       <td id="T_ed785_row5_col1" class="data row5 col1" >0.501</td>
#       <td id="T_ed785_row5_col2" class="data row5 col2" >0.673</td>
#       <td id="T_ed785_row5_col3" class="data row5 col3" >0.858</td>
#       <td id="T_ed785_row5_col4" class="data row5 col4" >0.944</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_ed785_row6_col0" class="data row6 col0" >0.258</td>
#       <td id="T_ed785_row6_col1" class="data row6 col1" >0.506</td>
#       <td id="T_ed785_row6_col2" class="data row6 col2" >0.670</td>
#       <td id="T_ed785_row6_col3" class="data row6 col3" >0.861</td>
#       <td id="T_ed785_row6_col4" class="data row6 col4" >0.945</td>
#     </tr>
#     <tr>
#       <th id="T_ed785_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_ed785_row7_col0" class="data row7 col0" >0.244</td>
#       <td id="T_ed785_row7_col1" class="data row7 col1" >0.501</td>
#       <td id="T_ed785_row7_col2" class="data row7 col2" >0.677</td>
#       <td id="T_ed785_row7_col3" class="data row7 col3" >0.859</td>
#       <td id="T_ed785_row7_col4" class="data row7 col4" >0.944</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k20} & {ACC-P1-k20} & {ACC-P2-k20} & {ACC-P3-k20} & {ACC-P4-k20} \\
# \texttt{LogReg} & 0.184 & \color{white} {\cellcolor{darkblue}} 0.525 & 0.647 & 0.798 & 0.848 \\
# \texttt{RETAIN} & 0.245 & 0.487 & \color{white} {\cellcolor{darkblue}} 0.690 & \color{white} {\cellcolor{darkblue}} 0.877 & \color{white} {\cellcolor{darkblue}} 0.967 \\
# \texttt{GRU} & 0.248 & 0.478 & 0.660 & 0.859 & 0.954 \\
# \texttt{GRU/G} & 0.236 & 0.465 & 0.663 & 0.864 & 0.953 \\
# \texttt{ICE-NODE} & \color{white} {\cellcolor{darkblue}} 0.265 & 0.504 & 0.675 & 0.854 & 0.943 \\
# \texttt{ICE-NODE/G} & 0.244 & 0.501 & 0.673 & 0.858 & 0.944 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.258 & 0.506 & 0.670 & 0.861 & 0.945 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.244 & 0.501 & 0.677 & 0.859 & 0.944 \\
# \end{tabular}

# %%
competing_tests_df = auctests_m3[auctests_m3.CODE_INDEX.isin(upsetindicator_m3[upsetindicator_m3.sum(axis=1)<7].index)]
competing_tests_df.loc[:, [col for col in competing_tests_df.columns if col[:2]=='P0']]
# Out:
#     P0(AUC_GRU==AUC_GRU/G)  P0(AUC_GRU==AUC_ICE-NODE)  \
# 22                0.005275                   0.111913
# 27                0.686031                   0.001518
# 58                0.060002                   0.026403
#
#     P0(AUC_GRU==AUC_ICE-NODE/G)  P0(AUC_GRU==AUC_ICE-NODE_UNIFORM)  \
# 22                     0.191310                       1.455551e-01
# 27                     0.048301                       1.620022e-11
# 58                     0.187143                       2.291409e-02
#
#     P0(AUC_GRU==AUC_ICE-NODE_UNIFORM/G)  P0(AUC_GRU==AUC_LogReg)  \
# 22                             0.218248                 0.214184
# 27                             0.088708                 0.026993
# 58                             0.203661                 0.937029
#
#     P0(AUC_GRU==AUC_RETAIN)  P0(AUC_GRU/G==AUC_ICE-NODE)  \
# 22                 0.390987                     0.181925
# 27                 0.028061                     0.000005
# 58                 0.006715                     0.826127
#
#     P0(AUC_GRU/G==AUC_ICE-NODE/G)  P0(AUC_GRU/G==AUC_ICE-NODE_UNIFORM)  ...  \
# 22                       0.292019                         2.199667e-01  ...
# 27                       0.012688                         4.930445e-29  ...
# 58                       0.632954                         7.831739e-01  ...
#
#     P0(AUC_ICE-NODE/G==AUC_ICE-NODE_UNIFORM)  \
# 22                                  0.006210
# 27                                  0.123397
# 58                                  0.062330
#
#     P0(AUC_ICE-NODE/G==AUC_ICE-NODE_UNIFORM/G)  \
# 22                                    0.504463
# 27                                    0.048516
# 58                                    0.692232
#
#     P0(AUC_ICE-NODE/G==AUC_LogReg)  P0(AUC_ICE-NODE/G==AUC_RETAIN)  \
# 22                        0.195942                        0.005608
# 27                        0.882508                        0.189615
# 58                        0.269323                        0.070004
#
#     P0(AUC_ICE-NODE_UNIFORM==AUC_ICE-NODE_UNIFORM/G)  \
# 22                                          0.005791
# 27                                          0.099743
# 58                                          0.057222
#
#     P0(AUC_ICE-NODE_UNIFORM==AUC_LogReg)  \
# 22                              0.160807
# 27                              0.629203
# 58                              0.067758
#
#     P0(AUC_ICE-NODE_UNIFORM==AUC_RETAIN)  \
# 22                              0.000725
# 27                              0.319440
# 58                              0.435180
#
#     P0(AUC_ICE-NODE_UNIFORM/G==AUC_LogReg)  \
# 22                                0.215851
# 27                                0.821793
# 58                                0.291041
#
#     P0(AUC_ICE-NODE_UNIFORM/G==AUC_RETAIN)  P0(AUC_LogReg==AUC_RETAIN)
# 22                                0.022190                    0.325138
# 27                                0.031248                    0.995856
# 58                                0.069678                    0.053831
#
# [3 rows x 28 columns]

# %%
upset_clfs = ['ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg',
              'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G']

ax = A.selected_auc_barplot(upset_clfs, competing_tests_df,  horizontal=True)
ax.legend(fontsize=22, title_fontsize=32,
          bbox_to_anchor=(-0.02, 1), ncol=2)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

current_figure = plt.gcf()
w, h = 4, 4
wi, hi = current_figure.get_size_inches()
current_figure.set_size_inches(hi*(w/h), hi)

current_figure.savefig("icenode_m3.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# <a name="sec3"></a>
#
# ## 3 Relative AUC Performance on MIMIC-IV (Test Set) [^](#outline)

# %%
m4_clfs =  ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg',
                'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G')
m4_predictors = {clf: cross_predictor(clf, 'M4', 'M4') for clf in m4_clfs}

# %%
test_res_m4 = {clf: C.eval2_(model, m4_test_ids) for clf, model in m4_predictors.items()}

# %%
auctests_m4 = A.codes_auc_pairwise_tests({k: v['risk_prediction'] for k, v in test_res_m4.items()}, fast=True)
# Out:
#  46%|██████████████████▉                      | 112/242 [07:39<08:38,  3.99s/it]WARNING:absl:Indeterminate test
# 100%|█████████████████████████████████████████| 242/242 [16:27<00:00,  4.08s/it]

# %%
upset_clfs = ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg',)
#                 'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G')

upsetcontents_m4, upsetindicator_m4, data_m4,  _, compete_codesm4 = A.relative_performance_upset(auctests_m4, 
                                                                                               upset_clfs, 
                                                                                               **relative_auc_config)

upset_ctx = lambda : sns.plotting_context("paper",  font_scale=1.5, rc={"font.family": "Loma", 
                                                                        'axes.labelsize': 'medium',
                                                                       'ytick.labelsize': 'medium'})
with sns.axes_style("darkgrid"), upset_ctx():
    upset_format = from_indicators(upsetindicator_m4, data=data_m4)
    upset_object = UpSet(upset_format, subset_size='count', show_counts=True)
    upset_object.style_subsets(present=['ICE-NODE'], absent=('ICE-NODE_UNIFORM', 'GRU', 'RETAIN'),
                               edgecolor="red", linewidth=3, facecolor="red")
    g = upset_object.plot()
    plt.show()
    current_figure = plt.gcf()
#     w, h = 5, 3
#     wi, hi = current_figure.get_size_inches()
#     current_figure.set_size_inches(hi*(w/h), hi)

    current_figure.savefig(f"upset_M4.pdf", bbox_inches='tight')
# Out:
# 85 codes predicted an AUC higher than 0.9 by at least one model.
# 84 codes predicted an AUC higher than 0.9 by at least one model, with valid tests.

# %%
results_m4_eval, _ = A.evaluation_table(test_res_m4, m4_train_percentiles, top_k_list=top_k_list)

# %%
table_clfs = (#'LogReg', 
              'RETAIN',
              'GRU',
              'GRU/G',
              'ICE-NODE', 
              'ICE-NODE/G',
              'ICE-NODE_UNIFORM',
              'ICE-NODE_UNIFORM/G'
              )
results_m4_tables = A.top_k_tables(table_clfs, results_m4_eval, top_k_list=top_k_list, 
                                   n_percentiles=n_percentiles, out_prefix=f'{output_dir}/M4')
# Out:
# <style type="text/css">
# #T_7a165_row0_col1, #T_7a165_row1_col2, #T_7a165_row2_col2, #T_7a165_row2_col3, #T_7a165_row3_col4, #T_7a165_row5_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_7a165_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k1</th>
#       <th class="col_heading level0 col1" >ACC-P1-k1</th>
#       <th class="col_heading level0 col2" >ACC-P2-k1</th>
#       <th class="col_heading level0 col3" >ACC-P3-k1</th>
#       <th class="col_heading level0 col4" >ACC-P4-k1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a165_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_7a165_row0_col0" class="data row0 col0" >0.079</td>
#       <td id="T_7a165_row0_col1" class="data row0 col1" >0.084</td>
#       <td id="T_7a165_row0_col2" class="data row0 col2" >0.078</td>
#       <td id="T_7a165_row0_col3" class="data row0 col3" >0.078</td>
#       <td id="T_7a165_row0_col4" class="data row0 col4" >0.142</td>
#     </tr>
#     <tr>
#       <th id="T_7a165_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_7a165_row1_col0" class="data row1 col0" >0.081</td>
#       <td id="T_7a165_row1_col1" class="data row1 col1" >0.079</td>
#       <td id="T_7a165_row1_col2" class="data row1 col2" >0.083</td>
#       <td id="T_7a165_row1_col3" class="data row1 col3" >0.078</td>
#       <td id="T_7a165_row1_col4" class="data row1 col4" >0.142</td>
#     </tr>
#     <tr>
#       <th id="T_7a165_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_7a165_row2_col0" class="data row2 col0" >0.077</td>
#       <td id="T_7a165_row2_col1" class="data row2 col1" >0.078</td>
#       <td id="T_7a165_row2_col2" class="data row2 col2" >0.083</td>
#       <td id="T_7a165_row2_col3" class="data row2 col3" >0.082</td>
#       <td id="T_7a165_row2_col4" class="data row2 col4" >0.144</td>
#     </tr>
#     <tr>
#       <th id="T_7a165_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_7a165_row3_col0" class="data row3 col0" >0.077</td>
#       <td id="T_7a165_row3_col1" class="data row3 col1" >0.079</td>
#       <td id="T_7a165_row3_col2" class="data row3 col2" >0.081</td>
#       <td id="T_7a165_row3_col3" class="data row3 col3" >0.072</td>
#       <td id="T_7a165_row3_col4" class="data row3 col4" >0.156</td>
#     </tr>
#     <tr>
#       <th id="T_7a165_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_7a165_row4_col0" class="data row4 col0" >0.076</td>
#       <td id="T_7a165_row4_col1" class="data row4 col1" >0.077</td>
#       <td id="T_7a165_row4_col2" class="data row4 col2" >0.082</td>
#       <td id="T_7a165_row4_col3" class="data row4 col3" >0.076</td>
#       <td id="T_7a165_row4_col4" class="data row4 col4" >0.155</td>
#     </tr>
#     <tr>
#       <th id="T_7a165_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_7a165_row5_col0" class="data row5 col0" >0.084</td>
#       <td id="T_7a165_row5_col1" class="data row5 col1" >0.077</td>
#       <td id="T_7a165_row5_col2" class="data row5 col2" >0.080</td>
#       <td id="T_7a165_row5_col3" class="data row5 col3" >0.074</td>
#       <td id="T_7a165_row5_col4" class="data row5 col4" >0.148</td>
#     </tr>
#     <tr>
#       <th id="T_7a165_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_7a165_row6_col0" class="data row6 col0" >0.075</td>
#       <td id="T_7a165_row6_col1" class="data row6 col1" >0.078</td>
#       <td id="T_7a165_row6_col2" class="data row6 col2" >0.081</td>
#       <td id="T_7a165_row6_col3" class="data row6 col3" >0.078</td>
#       <td id="T_7a165_row6_col4" class="data row6 col4" >0.152</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k1} & {ACC-P1-k1} & {ACC-P2-k1} & {ACC-P3-k1} & {ACC-P4-k1} \\
# \texttt{RETAIN} & 0.079 & \color{white} {\cellcolor{darkblue}} 0.084 & 0.078 & 0.078 & 0.142 \\
# \texttt{GRU} & 0.081 & 0.079 & \color{white} {\cellcolor{darkblue}} 0.083 & 0.078 & 0.142 \\
# \texttt{GRU/G} & 0.077 & 0.078 & \color{white} {\cellcolor{darkblue}} 0.083 & \color{white} {\cellcolor{darkblue}} 0.082 & 0.144 \\
# \texttt{ICE-NODE} & 0.077 & 0.079 & 0.081 & 0.072 & \color{white} {\cellcolor{darkblue}} 0.156 \\
# \texttt{ICE-NODE/G} & 0.076 & 0.077 & 0.082 & 0.076 & 0.155 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.084 & 0.077 & 0.080 & 0.074 & 0.148 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.075 & 0.078 & 0.081 & 0.078 & 0.152 \\
# \end{tabular}
# <style type="text/css">
# #T_d173c_row0_col1, #T_d173c_row1_col2, #T_d173c_row1_col3, #T_d173c_row2_col3, #T_d173c_row4_col4, #T_d173c_row5_col0, #T_d173c_row6_col3 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_d173c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k2</th>
#       <th class="col_heading level0 col1" >ACC-P1-k2</th>
#       <th class="col_heading level0 col2" >ACC-P2-k2</th>
#       <th class="col_heading level0 col3" >ACC-P3-k2</th>
#       <th class="col_heading level0 col4" >ACC-P4-k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d173c_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_d173c_row0_col0" class="data row0 col0" >0.124</td>
#       <td id="T_d173c_row0_col1" class="data row0 col1" >0.150</td>
#       <td id="T_d173c_row0_col2" class="data row0 col2" >0.136</td>
#       <td id="T_d173c_row0_col3" class="data row0 col3" >0.156</td>
#       <td id="T_d173c_row0_col4" class="data row0 col4" >0.300</td>
#     </tr>
#     <tr>
#       <th id="T_d173c_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_d173c_row1_col0" class="data row1 col0" >0.123</td>
#       <td id="T_d173c_row1_col1" class="data row1 col1" >0.143</td>
#       <td id="T_d173c_row1_col2" class="data row1 col2" >0.142</td>
#       <td id="T_d173c_row1_col3" class="data row1 col3" >0.161</td>
#       <td id="T_d173c_row1_col4" class="data row1 col4" >0.302</td>
#     </tr>
#     <tr>
#       <th id="T_d173c_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_d173c_row2_col0" class="data row2 col0" >0.118</td>
#       <td id="T_d173c_row2_col1" class="data row2 col1" >0.141</td>
#       <td id="T_d173c_row2_col2" class="data row2 col2" >0.141</td>
#       <td id="T_d173c_row2_col3" class="data row2 col3" >0.161</td>
#       <td id="T_d173c_row2_col4" class="data row2 col4" >0.306</td>
#     </tr>
#     <tr>
#       <th id="T_d173c_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_d173c_row3_col0" class="data row3 col0" >0.129</td>
#       <td id="T_d173c_row3_col1" class="data row3 col1" >0.143</td>
#       <td id="T_d173c_row3_col2" class="data row3 col2" >0.132</td>
#       <td id="T_d173c_row3_col3" class="data row3 col3" >0.154</td>
#       <td id="T_d173c_row3_col4" class="data row3 col4" >0.307</td>
#     </tr>
#     <tr>
#       <th id="T_d173c_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_d173c_row4_col0" class="data row4 col0" >0.126</td>
#       <td id="T_d173c_row4_col1" class="data row4 col1" >0.139</td>
#       <td id="T_d173c_row4_col2" class="data row4 col2" >0.132</td>
#       <td id="T_d173c_row4_col3" class="data row4 col3" >0.157</td>
#       <td id="T_d173c_row4_col4" class="data row4 col4" >0.310</td>
#     </tr>
#     <tr>
#       <th id="T_d173c_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_d173c_row5_col0" class="data row5 col0" >0.135</td>
#       <td id="T_d173c_row5_col1" class="data row5 col1" >0.140</td>
#       <td id="T_d173c_row5_col2" class="data row5 col2" >0.130</td>
#       <td id="T_d173c_row5_col3" class="data row5 col3" >0.157</td>
#       <td id="T_d173c_row5_col4" class="data row5 col4" >0.299</td>
#     </tr>
#     <tr>
#       <th id="T_d173c_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_d173c_row6_col0" class="data row6 col0" >0.125</td>
#       <td id="T_d173c_row6_col1" class="data row6 col1" >0.139</td>
#       <td id="T_d173c_row6_col2" class="data row6 col2" >0.129</td>
#       <td id="T_d173c_row6_col3" class="data row6 col3" >0.161</td>
#       <td id="T_d173c_row6_col4" class="data row6 col4" >0.306</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k2} & {ACC-P1-k2} & {ACC-P2-k2} & {ACC-P3-k2} & {ACC-P4-k2} \\
# \texttt{RETAIN} & 0.124 & \color{white} {\cellcolor{darkblue}} 0.150 & 0.136 & 0.156 & 0.300 \\
# \texttt{GRU} & 0.123 & 0.143 & \color{white} {\cellcolor{darkblue}} 0.142 & \color{white} {\cellcolor{darkblue}} 0.161 & 0.302 \\
# \texttt{GRU/G} & 0.118 & 0.141 & 0.141 & \color{white} {\cellcolor{darkblue}} 0.161 & 0.306 \\
# \texttt{ICE-NODE} & 0.129 & 0.143 & 0.132 & 0.154 & 0.307 \\
# \texttt{ICE-NODE/G} & 0.126 & 0.139 & 0.132 & 0.157 & \color{white} {\cellcolor{darkblue}} 0.310 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.135 & 0.140 & 0.130 & 0.157 & 0.299 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.125 & 0.139 & 0.129 & \color{white} {\cellcolor{darkblue}} 0.161 & 0.306 \\
# \end{tabular}
# <style type="text/css">
# #T_ac106_row0_col1, #T_ac106_row1_col2, #T_ac106_row1_col3, #T_ac106_row2_col2, #T_ac106_row2_col4, #T_ac106_row5_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_ac106_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k3</th>
#       <th class="col_heading level0 col1" >ACC-P1-k3</th>
#       <th class="col_heading level0 col2" >ACC-P2-k3</th>
#       <th class="col_heading level0 col3" >ACC-P3-k3</th>
#       <th class="col_heading level0 col4" >ACC-P4-k3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac106_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_ac106_row0_col0" class="data row0 col0" >0.158</td>
#       <td id="T_ac106_row0_col1" class="data row0 col1" >0.205</td>
#       <td id="T_ac106_row0_col2" class="data row0 col2" >0.188</td>
#       <td id="T_ac106_row0_col3" class="data row0 col3" >0.236</td>
#       <td id="T_ac106_row0_col4" class="data row0 col4" >0.442</td>
#     </tr>
#     <tr>
#       <th id="T_ac106_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_ac106_row1_col0" class="data row1 col0" >0.154</td>
#       <td id="T_ac106_row1_col1" class="data row1 col1" >0.199</td>
#       <td id="T_ac106_row1_col2" class="data row1 col2" >0.197</td>
#       <td id="T_ac106_row1_col3" class="data row1 col3" >0.244</td>
#       <td id="T_ac106_row1_col4" class="data row1 col4" >0.439</td>
#     </tr>
#     <tr>
#       <th id="T_ac106_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_ac106_row2_col0" class="data row2 col0" >0.149</td>
#       <td id="T_ac106_row2_col1" class="data row2 col1" >0.196</td>
#       <td id="T_ac106_row2_col2" class="data row2 col2" >0.197</td>
#       <td id="T_ac106_row2_col3" class="data row2 col3" >0.242</td>
#       <td id="T_ac106_row2_col4" class="data row2 col4" >0.446</td>
#     </tr>
#     <tr>
#       <th id="T_ac106_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_ac106_row3_col0" class="data row3 col0" >0.163</td>
#       <td id="T_ac106_row3_col1" class="data row3 col1" >0.201</td>
#       <td id="T_ac106_row3_col2" class="data row3 col2" >0.182</td>
#       <td id="T_ac106_row3_col3" class="data row3 col3" >0.232</td>
#       <td id="T_ac106_row3_col4" class="data row3 col4" >0.439</td>
#     </tr>
#     <tr>
#       <th id="T_ac106_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_ac106_row4_col0" class="data row4 col0" >0.162</td>
#       <td id="T_ac106_row4_col1" class="data row4 col1" >0.197</td>
#       <td id="T_ac106_row4_col2" class="data row4 col2" >0.181</td>
#       <td id="T_ac106_row4_col3" class="data row4 col3" >0.235</td>
#       <td id="T_ac106_row4_col4" class="data row4 col4" >0.444</td>
#     </tr>
#     <tr>
#       <th id="T_ac106_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_ac106_row5_col0" class="data row5 col0" >0.168</td>
#       <td id="T_ac106_row5_col1" class="data row5 col1" >0.197</td>
#       <td id="T_ac106_row5_col2" class="data row5 col2" >0.179</td>
#       <td id="T_ac106_row5_col3" class="data row5 col3" >0.234</td>
#       <td id="T_ac106_row5_col4" class="data row5 col4" >0.432</td>
#     </tr>
#     <tr>
#       <th id="T_ac106_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_ac106_row6_col0" class="data row6 col0" >0.159</td>
#       <td id="T_ac106_row6_col1" class="data row6 col1" >0.197</td>
#       <td id="T_ac106_row6_col2" class="data row6 col2" >0.176</td>
#       <td id="T_ac106_row6_col3" class="data row6 col3" >0.239</td>
#       <td id="T_ac106_row6_col4" class="data row6 col4" >0.439</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k3} & {ACC-P1-k3} & {ACC-P2-k3} & {ACC-P3-k3} & {ACC-P4-k3} \\
# \texttt{RETAIN} & 0.158 & \color{white} {\cellcolor{darkblue}} 0.205 & 0.188 & 0.236 & 0.442 \\
# \texttt{GRU} & 0.154 & 0.199 & \color{white} {\cellcolor{darkblue}} 0.197 & \color{white} {\cellcolor{darkblue}} 0.244 & 0.439 \\
# \texttt{GRU/G} & 0.149 & 0.196 & \color{white} {\cellcolor{darkblue}} 0.197 & 0.242 & \color{white} {\cellcolor{darkblue}} 0.446 \\
# \texttt{ICE-NODE} & 0.163 & 0.201 & 0.182 & 0.232 & 0.439 \\
# \texttt{ICE-NODE/G} & 0.162 & 0.197 & 0.181 & 0.235 & 0.444 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.168 & 0.197 & 0.179 & 0.234 & 0.432 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.159 & 0.197 & 0.176 & 0.239 & 0.439 \\
# \end{tabular}
# <style type="text/css">
# #T_cd13f_row1_col2, #T_cd13f_row2_col3, #T_cd13f_row2_col4, #T_cd13f_row3_col1, #T_cd13f_row5_col0, #T_cd13f_row6_col1 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_cd13f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k5</th>
#       <th class="col_heading level0 col1" >ACC-P1-k5</th>
#       <th class="col_heading level0 col2" >ACC-P2-k5</th>
#       <th class="col_heading level0 col3" >ACC-P3-k5</th>
#       <th class="col_heading level0 col4" >ACC-P4-k5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd13f_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_cd13f_row0_col0" class="data row0 col0" >0.217</td>
#       <td id="T_cd13f_row0_col1" class="data row0 col1" >0.288</td>
#       <td id="T_cd13f_row0_col2" class="data row0 col2" >0.292</td>
#       <td id="T_cd13f_row0_col3" class="data row0 col3" >0.378</td>
#       <td id="T_cd13f_row0_col4" class="data row0 col4" >0.643</td>
#     </tr>
#     <tr>
#       <th id="T_cd13f_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_cd13f_row1_col0" class="data row1 col0" >0.208</td>
#       <td id="T_cd13f_row1_col1" class="data row1 col1" >0.283</td>
#       <td id="T_cd13f_row1_col2" class="data row1 col2" >0.302</td>
#       <td id="T_cd13f_row1_col3" class="data row1 col3" >0.387</td>
#       <td id="T_cd13f_row1_col4" class="data row1 col4" >0.642</td>
#     </tr>
#     <tr>
#       <th id="T_cd13f_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_cd13f_row2_col0" class="data row2 col0" >0.207</td>
#       <td id="T_cd13f_row2_col1" class="data row2 col1" >0.281</td>
#       <td id="T_cd13f_row2_col2" class="data row2 col2" >0.300</td>
#       <td id="T_cd13f_row2_col3" class="data row2 col3" >0.388</td>
#       <td id="T_cd13f_row2_col4" class="data row2 col4" >0.649</td>
#     </tr>
#     <tr>
#       <th id="T_cd13f_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_cd13f_row3_col0" class="data row3 col0" >0.227</td>
#       <td id="T_cd13f_row3_col1" class="data row3 col1" >0.289</td>
#       <td id="T_cd13f_row3_col2" class="data row3 col2" >0.282</td>
#       <td id="T_cd13f_row3_col3" class="data row3 col3" >0.367</td>
#       <td id="T_cd13f_row3_col4" class="data row3 col4" >0.627</td>
#     </tr>
#     <tr>
#       <th id="T_cd13f_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_cd13f_row4_col0" class="data row4 col0" >0.225</td>
#       <td id="T_cd13f_row4_col1" class="data row4 col1" >0.286</td>
#       <td id="T_cd13f_row4_col2" class="data row4 col2" >0.279</td>
#       <td id="T_cd13f_row4_col3" class="data row4 col3" >0.370</td>
#       <td id="T_cd13f_row4_col4" class="data row4 col4" >0.634</td>
#     </tr>
#     <tr>
#       <th id="T_cd13f_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_cd13f_row5_col0" class="data row5 col0" >0.231</td>
#       <td id="T_cd13f_row5_col1" class="data row5 col1" >0.286</td>
#       <td id="T_cd13f_row5_col2" class="data row5 col2" >0.277</td>
#       <td id="T_cd13f_row5_col3" class="data row5 col3" >0.369</td>
#       <td id="T_cd13f_row5_col4" class="data row5 col4" >0.621</td>
#     </tr>
#     <tr>
#       <th id="T_cd13f_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_cd13f_row6_col0" class="data row6 col0" >0.222</td>
#       <td id="T_cd13f_row6_col1" class="data row6 col1" >0.289</td>
#       <td id="T_cd13f_row6_col2" class="data row6 col2" >0.272</td>
#       <td id="T_cd13f_row6_col3" class="data row6 col3" >0.373</td>
#       <td id="T_cd13f_row6_col4" class="data row6 col4" >0.624</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k5} & {ACC-P1-k5} & {ACC-P2-k5} & {ACC-P3-k5} & {ACC-P4-k5} \\
# \texttt{RETAIN} & 0.217 & 0.288 & 0.292 & 0.378 & 0.643 \\
# \texttt{GRU} & 0.208 & 0.283 & \color{white} {\cellcolor{darkblue}} 0.302 & 0.387 & 0.642 \\
# \texttt{GRU/G} & 0.207 & 0.281 & 0.300 & \color{white} {\cellcolor{darkblue}} 0.388 & \color{white} {\cellcolor{darkblue}} 0.649 \\
# \texttt{ICE-NODE} & 0.227 & \color{white} {\cellcolor{darkblue}} 0.289 & 0.282 & 0.367 & 0.627 \\
# \texttt{ICE-NODE/G} & 0.225 & 0.286 & 0.279 & 0.370 & 0.634 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.231 & 0.286 & 0.277 & 0.369 & 0.621 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.222 & \color{white} {\cellcolor{darkblue}} 0.289 & 0.272 & 0.373 & 0.624 \\
# \end{tabular}
# <style type="text/css">
# #T_47815_row1_col2, #T_47815_row1_col3, #T_47815_row2_col3, #T_47815_row2_col4, #T_47815_row3_col1, #T_47815_row5_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_47815_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k7</th>
#       <th class="col_heading level0 col1" >ACC-P1-k7</th>
#       <th class="col_heading level0 col2" >ACC-P2-k7</th>
#       <th class="col_heading level0 col3" >ACC-P3-k7</th>
#       <th class="col_heading level0 col4" >ACC-P4-k7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47815_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_47815_row0_col0" class="data row0 col0" >0.265</td>
#       <td id="T_47815_row0_col1" class="data row0 col1" >0.346</td>
#       <td id="T_47815_row0_col2" class="data row0 col2" >0.383</td>
#       <td id="T_47815_row0_col3" class="data row0 col3" >0.497</td>
#       <td id="T_47815_row0_col4" class="data row0 col4" >0.759</td>
#     </tr>
#     <tr>
#       <th id="T_47815_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_47815_row1_col0" class="data row1 col0" >0.252</td>
#       <td id="T_47815_row1_col1" class="data row1 col1" >0.345</td>
#       <td id="T_47815_row1_col2" class="data row1 col2" >0.393</td>
#       <td id="T_47815_row1_col3" class="data row1 col3" >0.509</td>
#       <td id="T_47815_row1_col4" class="data row1 col4" >0.756</td>
#     </tr>
#     <tr>
#       <th id="T_47815_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_47815_row2_col0" class="data row2 col0" >0.253</td>
#       <td id="T_47815_row2_col1" class="data row2 col1" >0.342</td>
#       <td id="T_47815_row2_col2" class="data row2 col2" >0.390</td>
#       <td id="T_47815_row2_col3" class="data row2 col3" >0.509</td>
#       <td id="T_47815_row2_col4" class="data row2 col4" >0.764</td>
#     </tr>
#     <tr>
#       <th id="T_47815_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_47815_row3_col0" class="data row3 col0" >0.277</td>
#       <td id="T_47815_row3_col1" class="data row3 col1" >0.355</td>
#       <td id="T_47815_row3_col2" class="data row3 col2" >0.371</td>
#       <td id="T_47815_row3_col3" class="data row3 col3" >0.477</td>
#       <td id="T_47815_row3_col4" class="data row3 col4" >0.739</td>
#     </tr>
#     <tr>
#       <th id="T_47815_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_47815_row4_col0" class="data row4 col0" >0.276</td>
#       <td id="T_47815_row4_col1" class="data row4 col1" >0.352</td>
#       <td id="T_47815_row4_col2" class="data row4 col2" >0.368</td>
#       <td id="T_47815_row4_col3" class="data row4 col3" >0.480</td>
#       <td id="T_47815_row4_col4" class="data row4 col4" >0.745</td>
#     </tr>
#     <tr>
#       <th id="T_47815_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_47815_row5_col0" class="data row5 col0" >0.279</td>
#       <td id="T_47815_row5_col1" class="data row5 col1" >0.350</td>
#       <td id="T_47815_row5_col2" class="data row5 col2" >0.365</td>
#       <td id="T_47815_row5_col3" class="data row5 col3" >0.477</td>
#       <td id="T_47815_row5_col4" class="data row5 col4" >0.735</td>
#     </tr>
#     <tr>
#       <th id="T_47815_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_47815_row6_col0" class="data row6 col0" >0.271</td>
#       <td id="T_47815_row6_col1" class="data row6 col1" >0.351</td>
#       <td id="T_47815_row6_col2" class="data row6 col2" >0.361</td>
#       <td id="T_47815_row6_col3" class="data row6 col3" >0.481</td>
#       <td id="T_47815_row6_col4" class="data row6 col4" >0.735</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k7} & {ACC-P1-k7} & {ACC-P2-k7} & {ACC-P3-k7} & {ACC-P4-k7} \\
# \texttt{RETAIN} & 0.265 & 0.346 & 0.383 & 0.497 & 0.759 \\
# \texttt{GRU} & 0.252 & 0.345 & \color{white} {\cellcolor{darkblue}} 0.393 & \color{white} {\cellcolor{darkblue}} 0.509 & 0.756 \\
# \texttt{GRU/G} & 0.253 & 0.342 & 0.390 & \color{white} {\cellcolor{darkblue}} 0.509 & \color{white} {\cellcolor{darkblue}} 0.764 \\
# \texttt{ICE-NODE} & 0.277 & \color{white} {\cellcolor{darkblue}} 0.355 & 0.371 & 0.477 & 0.739 \\
# \texttt{ICE-NODE/G} & 0.276 & 0.352 & 0.368 & 0.480 & 0.745 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.279 & 0.350 & 0.365 & 0.477 & 0.735 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.271 & 0.351 & 0.361 & 0.481 & 0.735 \\
# \end{tabular}
# <style type="text/css">
# #T_15314_row1_col2, #T_15314_row1_col3, #T_15314_row2_col4, #T_15314_row3_col1, #T_15314_row4_col1, #T_15314_row5_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_15314_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k10</th>
#       <th class="col_heading level0 col1" >ACC-P1-k10</th>
#       <th class="col_heading level0 col2" >ACC-P2-k10</th>
#       <th class="col_heading level0 col3" >ACC-P3-k10</th>
#       <th class="col_heading level0 col4" >ACC-P4-k10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15314_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_15314_row0_col0" class="data row0 col0" >0.312</td>
#       <td id="T_15314_row0_col1" class="data row0 col1" >0.409</td>
#       <td id="T_15314_row0_col2" class="data row0 col2" >0.491</td>
#       <td id="T_15314_row0_col3" class="data row0 col3" >0.640</td>
#       <td id="T_15314_row0_col4" class="data row0 col4" >0.856</td>
#     </tr>
#     <tr>
#       <th id="T_15314_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_15314_row1_col0" class="data row1 col0" >0.300</td>
#       <td id="T_15314_row1_col1" class="data row1 col1" >0.411</td>
#       <td id="T_15314_row1_col2" class="data row1 col2" >0.500</td>
#       <td id="T_15314_row1_col3" class="data row1 col3" >0.652</td>
#       <td id="T_15314_row1_col4" class="data row1 col4" >0.849</td>
#     </tr>
#     <tr>
#       <th id="T_15314_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_15314_row2_col0" class="data row2 col0" >0.303</td>
#       <td id="T_15314_row2_col1" class="data row2 col1" >0.410</td>
#       <td id="T_15314_row2_col2" class="data row2 col2" >0.497</td>
#       <td id="T_15314_row2_col3" class="data row2 col3" >0.651</td>
#       <td id="T_15314_row2_col4" class="data row2 col4" >0.857</td>
#     </tr>
#     <tr>
#       <th id="T_15314_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_15314_row3_col0" class="data row3 col0" >0.327</td>
#       <td id="T_15314_row3_col1" class="data row3 col1" >0.421</td>
#       <td id="T_15314_row3_col2" class="data row3 col2" >0.478</td>
#       <td id="T_15314_row3_col3" class="data row3 col3" >0.615</td>
#       <td id="T_15314_row3_col4" class="data row3 col4" >0.832</td>
#     </tr>
#     <tr>
#       <th id="T_15314_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_15314_row4_col0" class="data row4 col0" >0.326</td>
#       <td id="T_15314_row4_col1" class="data row4 col1" >0.421</td>
#       <td id="T_15314_row4_col2" class="data row4 col2" >0.474</td>
#       <td id="T_15314_row4_col3" class="data row4 col3" >0.614</td>
#       <td id="T_15314_row4_col4" class="data row4 col4" >0.835</td>
#     </tr>
#     <tr>
#       <th id="T_15314_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_15314_row5_col0" class="data row5 col0" >0.328</td>
#       <td id="T_15314_row5_col1" class="data row5 col1" >0.417</td>
#       <td id="T_15314_row5_col2" class="data row5 col2" >0.471</td>
#       <td id="T_15314_row5_col3" class="data row5 col3" >0.612</td>
#       <td id="T_15314_row5_col4" class="data row5 col4" >0.828</td>
#     </tr>
#     <tr>
#       <th id="T_15314_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_15314_row6_col0" class="data row6 col0" >0.321</td>
#       <td id="T_15314_row6_col1" class="data row6 col1" >0.416</td>
#       <td id="T_15314_row6_col2" class="data row6 col2" >0.467</td>
#       <td id="T_15314_row6_col3" class="data row6 col3" >0.616</td>
#       <td id="T_15314_row6_col4" class="data row6 col4" >0.828</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k10} & {ACC-P1-k10} & {ACC-P2-k10} & {ACC-P3-k10} & {ACC-P4-k10} \\
# \texttt{RETAIN} & 0.312 & 0.409 & 0.491 & 0.640 & 0.856 \\
# \texttt{GRU} & 0.300 & 0.411 & \color{white} {\cellcolor{darkblue}} 0.500 & \color{white} {\cellcolor{darkblue}} 0.652 & 0.849 \\
# \texttt{GRU/G} & 0.303 & 0.410 & 0.497 & 0.651 & \color{white} {\cellcolor{darkblue}} 0.857 \\
# \texttt{ICE-NODE} & 0.327 & \color{white} {\cellcolor{darkblue}} 0.421 & 0.478 & 0.615 & 0.832 \\
# \texttt{ICE-NODE/G} & 0.326 & \color{white} {\cellcolor{darkblue}} 0.421 & 0.474 & 0.614 & 0.835 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.328 & 0.417 & 0.471 & 0.612 & 0.828 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.321 & 0.416 & 0.467 & 0.616 & 0.828 \\
# \end{tabular}
# <style type="text/css">
# #T_a005a_row0_col4, #T_a005a_row1_col2, #T_a005a_row2_col3, #T_a005a_row3_col1, #T_a005a_row5_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_a005a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k15</th>
#       <th class="col_heading level0 col1" >ACC-P1-k15</th>
#       <th class="col_heading level0 col2" >ACC-P2-k15</th>
#       <th class="col_heading level0 col3" >ACC-P3-k15</th>
#       <th class="col_heading level0 col4" >ACC-P4-k15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a005a_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_a005a_row0_col0" class="data row0 col0" >0.362</td>
#       <td id="T_a005a_row0_col1" class="data row0 col1" >0.483</td>
#       <td id="T_a005a_row0_col2" class="data row0 col2" >0.621</td>
#       <td id="T_a005a_row0_col3" class="data row0 col3" >0.806</td>
#       <td id="T_a005a_row0_col4" class="data row0 col4" >0.928</td>
#     </tr>
#     <tr>
#       <th id="T_a005a_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_a005a_row1_col0" class="data row1 col0" >0.355</td>
#       <td id="T_a005a_row1_col1" class="data row1 col1" >0.491</td>
#       <td id="T_a005a_row1_col2" class="data row1 col2" >0.633</td>
#       <td id="T_a005a_row1_col3" class="data row1 col3" >0.808</td>
#       <td id="T_a005a_row1_col4" class="data row1 col4" >0.917</td>
#     </tr>
#     <tr>
#       <th id="T_a005a_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_a005a_row2_col0" class="data row2 col0" >0.357</td>
#       <td id="T_a005a_row2_col1" class="data row2 col1" >0.491</td>
#       <td id="T_a005a_row2_col2" class="data row2 col2" >0.628</td>
#       <td id="T_a005a_row2_col3" class="data row2 col3" >0.809</td>
#       <td id="T_a005a_row2_col4" class="data row2 col4" >0.921</td>
#     </tr>
#     <tr>
#       <th id="T_a005a_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_a005a_row3_col0" class="data row3 col0" >0.375</td>
#       <td id="T_a005a_row3_col1" class="data row3 col1" >0.493</td>
#       <td id="T_a005a_row3_col2" class="data row3 col2" >0.605</td>
#       <td id="T_a005a_row3_col3" class="data row3 col3" >0.774</td>
#       <td id="T_a005a_row3_col4" class="data row3 col4" >0.904</td>
#     </tr>
#     <tr>
#       <th id="T_a005a_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_a005a_row4_col0" class="data row4 col0" >0.374</td>
#       <td id="T_a005a_row4_col1" class="data row4 col1" >0.491</td>
#       <td id="T_a005a_row4_col2" class="data row4 col2" >0.601</td>
#       <td id="T_a005a_row4_col3" class="data row4 col3" >0.776</td>
#       <td id="T_a005a_row4_col4" class="data row4 col4" >0.906</td>
#     </tr>
#     <tr>
#       <th id="T_a005a_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_a005a_row5_col0" class="data row5 col0" >0.376</td>
#       <td id="T_a005a_row5_col1" class="data row5 col1" >0.486</td>
#       <td id="T_a005a_row5_col2" class="data row5 col2" >0.598</td>
#       <td id="T_a005a_row5_col3" class="data row5 col3" >0.773</td>
#       <td id="T_a005a_row5_col4" class="data row5 col4" >0.904</td>
#     </tr>
#     <tr>
#       <th id="T_a005a_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_a005a_row6_col0" class="data row6 col0" >0.370</td>
#       <td id="T_a005a_row6_col1" class="data row6 col1" >0.485</td>
#       <td id="T_a005a_row6_col2" class="data row6 col2" >0.593</td>
#       <td id="T_a005a_row6_col3" class="data row6 col3" >0.779</td>
#       <td id="T_a005a_row6_col4" class="data row6 col4" >0.903</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k15} & {ACC-P1-k15} & {ACC-P2-k15} & {ACC-P3-k15} & {ACC-P4-k15} \\
# \texttt{RETAIN} & 0.362 & 0.483 & 0.621 & 0.806 & \color{white} {\cellcolor{darkblue}} 0.928 \\
# \texttt{GRU} & 0.355 & 0.491 & \color{white} {\cellcolor{darkblue}} 0.633 & 0.808 & 0.917 \\
# \texttt{GRU/G} & 0.357 & 0.491 & 0.628 & \color{white} {\cellcolor{darkblue}} 0.809 & 0.921 \\
# \texttt{ICE-NODE} & 0.375 & \color{white} {\cellcolor{darkblue}} 0.493 & 0.605 & 0.774 & 0.904 \\
# \texttt{ICE-NODE/G} & 0.374 & 0.491 & 0.601 & 0.776 & 0.906 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.376 & 0.486 & 0.598 & 0.773 & 0.904 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.370 & 0.485 & 0.593 & 0.779 & 0.903 \\
# \end{tabular}
# <style type="text/css">
# #T_925ed_row0_col3, #T_925ed_row0_col4, #T_925ed_row1_col1, #T_925ed_row1_col2, #T_925ed_row2_col1, #T_925ed_row2_col3, #T_925ed_row3_col0, #T_925ed_row4_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_925ed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k20</th>
#       <th class="col_heading level0 col1" >ACC-P1-k20</th>
#       <th class="col_heading level0 col2" >ACC-P2-k20</th>
#       <th class="col_heading level0 col3" >ACC-P3-k20</th>
#       <th class="col_heading level0 col4" >ACC-P4-k20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_925ed_level0_row0" class="row_heading level0 row0" >RETAIN</th>
#       <td id="T_925ed_row0_col0" class="data row0 col0" >0.398</td>
#       <td id="T_925ed_row0_col1" class="data row0 col1" >0.544</td>
#       <td id="T_925ed_row0_col2" class="data row0 col2" >0.725</td>
#       <td id="T_925ed_row0_col3" class="data row0 col3" >0.898</td>
#       <td id="T_925ed_row0_col4" class="data row0 col4" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_925ed_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_925ed_row1_col0" class="data row1 col0" >0.396</td>
#       <td id="T_925ed_row1_col1" class="data row1 col1" >0.558</td>
#       <td id="T_925ed_row1_col2" class="data row1 col2" >0.733</td>
#       <td id="T_925ed_row1_col3" class="data row1 col3" >0.896</td>
#       <td id="T_925ed_row1_col4" class="data row1 col4" >0.950</td>
#     </tr>
#     <tr>
#       <th id="T_925ed_level0_row2" class="row_heading level0 row2" >GRU/G</th>
#       <td id="T_925ed_row2_col0" class="data row2 col0" >0.399</td>
#       <td id="T_925ed_row2_col1" class="data row2 col1" >0.558</td>
#       <td id="T_925ed_row2_col2" class="data row2 col2" >0.725</td>
#       <td id="T_925ed_row2_col3" class="data row2 col3" >0.898</td>
#       <td id="T_925ed_row2_col4" class="data row2 col4" >0.953</td>
#     </tr>
#     <tr>
#       <th id="T_925ed_level0_row3" class="row_heading level0 row3" >ICE-NODE</th>
#       <td id="T_925ed_row3_col0" class="data row3 col0" >0.406</td>
#       <td id="T_925ed_row3_col1" class="data row3 col1" >0.548</td>
#       <td id="T_925ed_row3_col2" class="data row3 col2" >0.704</td>
#       <td id="T_925ed_row3_col3" class="data row3 col3" >0.869</td>
#       <td id="T_925ed_row3_col4" class="data row3 col4" >0.942</td>
#     </tr>
#     <tr>
#       <th id="T_925ed_level0_row4" class="row_heading level0 row4" >ICE-NODE/G</th>
#       <td id="T_925ed_row4_col0" class="data row4 col0" >0.406</td>
#       <td id="T_925ed_row4_col1" class="data row4 col1" >0.546</td>
#       <td id="T_925ed_row4_col2" class="data row4 col2" >0.700</td>
#       <td id="T_925ed_row4_col3" class="data row4 col3" >0.872</td>
#       <td id="T_925ed_row4_col4" class="data row4 col4" >0.944</td>
#     </tr>
#     <tr>
#       <th id="T_925ed_level0_row5" class="row_heading level0 row5" >ICE-NODE_UNIFORM</th>
#       <td id="T_925ed_row5_col0" class="data row5 col0" >0.405</td>
#       <td id="T_925ed_row5_col1" class="data row5 col1" >0.540</td>
#       <td id="T_925ed_row5_col2" class="data row5 col2" >0.694</td>
#       <td id="T_925ed_row5_col3" class="data row5 col3" >0.870</td>
#       <td id="T_925ed_row5_col4" class="data row5 col4" >0.944</td>
#     </tr>
#     <tr>
#       <th id="T_925ed_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_925ed_row6_col0" class="data row6 col0" >0.401</td>
#       <td id="T_925ed_row6_col1" class="data row6 col1" >0.540</td>
#       <td id="T_925ed_row6_col2" class="data row6 col2" >0.692</td>
#       <td id="T_925ed_row6_col3" class="data row6 col3" >0.874</td>
#       <td id="T_925ed_row6_col4" class="data row6 col4" >0.944</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k20} & {ACC-P1-k20} & {ACC-P2-k20} & {ACC-P3-k20} & {ACC-P4-k20} \\
# \texttt{RETAIN} & 0.398 & 0.544 & 0.725 & \color{white} {\cellcolor{darkblue}} 0.898 & \color{white} {\cellcolor{darkblue}} 0.963 \\
# \texttt{GRU} & 0.396 & \color{white} {\cellcolor{darkblue}} 0.558 & \color{white} {\cellcolor{darkblue}} 0.733 & 0.896 & 0.950 \\
# \texttt{GRU/G} & 0.399 & \color{white} {\cellcolor{darkblue}} 0.558 & 0.725 & \color{white} {\cellcolor{darkblue}} 0.898 & 0.953 \\
# \texttt{ICE-NODE} & \color{white} {\cellcolor{darkblue}} 0.406 & 0.548 & 0.704 & 0.869 & 0.942 \\
# \texttt{ICE-NODE/G} & \color{white} {\cellcolor{darkblue}} 0.406 & 0.546 & 0.700 & 0.872 & 0.944 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.405 & 0.540 & 0.694 & 0.870 & 0.944 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.401 & 0.540 & 0.692 & 0.874 & 0.944 \\
# \end{tabular}

# %%
icenode_m4_excl = upsetcontents_m4['ICE-NODE'] - set.union(*list(upsetcontents_m4[clf] for clf in ('RETAIN', 'GRU', 'ICE-NODE_UNIFORM')))
icenode_m4_excl = compete_codesm4[compete_codesm4['CODE_INDEX'].isin(icenode_m4_excl)]
icenode_m4_excl
# Out:
#      CODE_INDEX  N_POSITIVE_CODES  AUC(GRU)  AUC(GRU/G)  AUC(ICE-NODE)  \
# 6             6            2063.0  0.898773    0.901010       0.916554
# 94           94             129.0  0.958869    0.960223       0.969153
# 105         105            1040.0  0.980632    0.981246       0.984216
# 236         236            8394.0  0.888173    0.881420       0.912473
#
#      AUC(ICE-NODE/G)  AUC(ICE-NODE_UNIFORM)  AUC(ICE-NODE_UNIFORM/G)  \
# 6           0.914781               0.891652                 0.891849
# 94          0.971112               0.959539                 0.958659
# 105         0.985411               0.979006                 0.979229
# 236         0.912957               0.885894                 0.885070
#
#      AUC(LogReg)  AUC(RETAIN)  ...  \
# 6       0.891644     0.899441  ...
# 94      0.926404     0.961009  ...
# 105     0.970260     0.979885  ...
# 236     0.870362     0.889942  ...
#
#      P0(AUC_ICE-NODE/G==AUC_ICE-NODE_UNIFORM/G)  \
# 6                                  5.137430e-24
# 94                                 7.254342e-05
# 105                                2.062637e-12
# 236                                1.173301e-92
#
#      P0(AUC_ICE-NODE/G==AUC_LogReg)  P0(AUC_ICE-NODE/G==AUC_RETAIN)  \
# 6                      9.136617e-15                    2.731682e-09
# 94                     8.039842e-11                    2.701504e-03
# 105                    1.412118e-25                    9.219148e-11
# 236                    3.733929e-99                    2.285283e-45
#
#      P0(AUC_ICE-NODE_UNIFORM==AUC_ICE-NODE_UNIFORM/G)  \
# 6                                            0.793588
# 94                                           0.445563
# 105                                          0.370566
# 236                                          0.026476
#
#      P0(AUC_ICE-NODE_UNIFORM==AUC_LogReg)  \
# 6                            9.974125e-01
# 94                           2.418600e-07
# 105                          3.887371e-09
# 236                          1.358596e-17
#
#      P0(AUC_ICE-NODE_UNIFORM==AUC_RETAIN)  \
# 6                                0.000081
# 94                               0.468452
# 105                              0.225686
# 236                              0.001825
#
#      P0(AUC_ICE-NODE_UNIFORM/G==AUC_LogReg)  \
# 6                              9.344225e-01
# 94                             4.617092e-07
# 105                            4.004246e-10
# 236                            4.540009e-16
#
#      P0(AUC_ICE-NODE_UNIFORM/G==AUC_RETAIN)  P0(AUC_LogReg==AUC_RETAIN)  \
# 6                                  0.000092                7.964975e-05
# 94                                 0.281498                3.944136e-09
# 105                                0.330494                1.512013e-15
# 236                                0.000179                3.532560e-36
#
#              DESC
# 6    Pulm hart dx
# 94    Early labor
# 105   Forceps del
# 236  Other ear dx
#
# [4 rows x 47 columns]

# %%
# icenode_ratain_gru_m4 = upsetcontents_m4['ICE-NODE']
# icenode_ratain_gru_m4 = compete_codesm4[compete_codesm4['CODE_INDEX'].isin(icenode_ratain_gru_m4)]
# icenode_ratain_gru_m4.sort_values('AUC(ICE-NODE)', ascending=False)[['CODE_INDEX', 'N_POSITIVE_CODES', 'DESC', 'AUC(ICE-NODE)']]

# %%
upset_clfs = ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg')
w, h = 4, 3
ax = A.selected_auc_barplot(upset_clfs, icenode_m4_excl, horizontal=True)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
ax.legend(fontsize=22, title_fontsize=32,
          bbox_to_anchor=(-0.02, 1), ncol=2)
current_figure = plt.gcf()
w, h = 4, 4
wi, hi = current_figure.get_size_inches()
current_figure.set_size_inches(hi*(w/h), hi)

current_figure.savefig("icenode_m4.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# <a name="sec4"></a>
#
# ## 4 Relative AUC Performance From MIMIC-IV (Training Set) to MIMIC-III (All) [^](#outline)

# %%
m4m3_clfs =  ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg',
                'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G')

# clfs_ordered = ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN')
m3_subjects = list(m3_interface.subjects.keys())
m4m3_predictors = {clf: cross_predictor(clf, 'M4', 'M3') for clf in m4m3_clfs}

# %%
test_res_m4m3 = {clf: C.eval2_(model, m3_subjects) for clf, model in m4m3_predictors.items()}

# %%
auctests_m4m3 = A.codes_auc_pairwise_tests({k: v['risk_prediction'] for k, v in test_res_m4m3.items()}, fast=True)
# Out:
#  37%|███████████████▌                          | 90/242 [01:25<01:04,  2.37it/s]WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
#  57%|███████████████████████▍                 | 138/242 [01:54<01:16,  1.37it/s]WARNING:absl:Indeterminate test
#  69%|████████████████████████████             | 166/242 [02:23<01:16,  1.01s/it]WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# WARNING:absl:Indeterminate test
# 100%|█████████████████████████████████████████| 242/242 [03:37<00:00,  1.11it/s]

# %%
upset_clfs = ('ICE-NODE', 'ICE-NODE_UNIFORM', 'GRU', 'RETAIN', 'LogReg',)
#                 'ICE-NODE/G', 'ICE-NODE_UNIFORM/G', 'GRU/G')

upsetcontents_m4m3, upsetindicator_m4m3, data_m4m3,  _, compete_codesm4m3 = A.relative_performance_upset(auctests_m4m3, 
                                                                                                       upset_clfs, 
                                                                                                       **relative_auc_config)
upset_ctx = lambda : sns.plotting_context("paper", font_scale=1.5, rc={"font.family": "Loma", 
                                                                        'axes.labelsize': 'medium',
                                                                       'ytick.labelsize': 'medium'})
with sns.axes_style("darkgrid"), upset_ctx():
    upset_format = from_indicators(upsetindicator_m4m3, data=data_m4m3)
    upset_object = UpSet(upset_format, subset_size='count', show_counts=True)
    upset_object.style_subsets(present='ICE-NODE', absent=['ICE-NODE_UNIFORM', 'GRU', 'RETAIN'],
                              edgecolor="red", facecolor="red")
    g = upset_object.plot()
    plt.show()
    current_figure = plt.gcf()
    current_figure.savefig(f"upset_M4M3.pdf", bbox_inches='tight')
# Out:
# 53 codes predicted an AUC higher than 0.9 by at least one model.
# 50 codes predicted an AUC higher than 0.9 by at least one model, with valid tests.

# %%
results_m4m3_eval, _ = A.evaluation_table(test_res_m4m3, m4_train_percentiles, top_k_list=top_k_list)

# %%
table_clfs = ('LogReg', 
              'RETAIN',
              'GRU',
              'GRU/G',
              'ICE-NODE', 
              'ICE-NODE/G',
              'ICE-NODE_UNIFORM',
              'ICE-NODE_UNIFORM/G'
              )

results_m4m3_tables = A.top_k_tables(table_clfs, results_m4m3_eval, top_k_list=top_k_list, 
                                     n_percentiles=n_percentiles, out_prefix=f'{output_dir}/M4M3')
# Out:
# <style type="text/css">
# #T_61d78_row0_col3, #T_61d78_row0_col4, #T_61d78_row1_col1, #T_61d78_row2_col0, #T_61d78_row5_col2 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_61d78_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k1</th>
#       <th class="col_heading level0 col1" >ACC-P1-k1</th>
#       <th class="col_heading level0 col2" >ACC-P2-k1</th>
#       <th class="col_heading level0 col3" >ACC-P3-k1</th>
#       <th class="col_heading level0 col4" >ACC-P4-k1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61d78_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_61d78_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_61d78_row0_col1" class="data row0 col1" >0.005</td>
#       <td id="T_61d78_row0_col2" class="data row0 col2" >0.038</td>
#       <td id="T_61d78_row0_col3" class="data row0 col3" >0.105</td>
#       <td id="T_61d78_row0_col4" class="data row0 col4" >0.236</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_61d78_row1_col0" class="data row1 col0" >0.076</td>
#       <td id="T_61d78_row1_col1" class="data row1 col1" >0.054</td>
#       <td id="T_61d78_row1_col2" class="data row1 col2" >0.080</td>
#       <td id="T_61d78_row1_col3" class="data row1 col3" >0.077</td>
#       <td id="T_61d78_row1_col4" class="data row1 col4" >0.141</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_61d78_row2_col0" class="data row2 col0" >0.079</td>
#       <td id="T_61d78_row2_col1" class="data row2 col1" >0.052</td>
#       <td id="T_61d78_row2_col2" class="data row2 col2" >0.076</td>
#       <td id="T_61d78_row2_col3" class="data row2 col3" >0.077</td>
#       <td id="T_61d78_row2_col4" class="data row2 col4" >0.151</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_61d78_row3_col0" class="data row3 col0" >0.075</td>
#       <td id="T_61d78_row3_col1" class="data row3 col1" >0.049</td>
#       <td id="T_61d78_row3_col2" class="data row3 col2" >0.078</td>
#       <td id="T_61d78_row3_col3" class="data row3 col3" >0.084</td>
#       <td id="T_61d78_row3_col4" class="data row3 col4" >0.143</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_61d78_row4_col0" class="data row4 col0" >0.069</td>
#       <td id="T_61d78_row4_col1" class="data row4 col1" >0.044</td>
#       <td id="T_61d78_row4_col2" class="data row4 col2" >0.082</td>
#       <td id="T_61d78_row4_col3" class="data row4 col3" >0.082</td>
#       <td id="T_61d78_row4_col4" class="data row4 col4" >0.161</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_61d78_row5_col0" class="data row5 col0" >0.068</td>
#       <td id="T_61d78_row5_col1" class="data row5 col1" >0.043</td>
#       <td id="T_61d78_row5_col2" class="data row5 col2" >0.083</td>
#       <td id="T_61d78_row5_col3" class="data row5 col3" >0.086</td>
#       <td id="T_61d78_row5_col4" class="data row5 col4" >0.154</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_61d78_row6_col0" class="data row6 col0" >0.072</td>
#       <td id="T_61d78_row6_col1" class="data row6 col1" >0.044</td>
#       <td id="T_61d78_row6_col2" class="data row6 col2" >0.079</td>
#       <td id="T_61d78_row6_col3" class="data row6 col3" >0.085</td>
#       <td id="T_61d78_row6_col4" class="data row6 col4" >0.155</td>
#     </tr>
#     <tr>
#       <th id="T_61d78_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_61d78_row7_col0" class="data row7 col0" >0.065</td>
#       <td id="T_61d78_row7_col1" class="data row7 col1" >0.045</td>
#       <td id="T_61d78_row7_col2" class="data row7 col2" >0.080</td>
#       <td id="T_61d78_row7_col3" class="data row7 col3" >0.089</td>
#       <td id="T_61d78_row7_col4" class="data row7 col4" >0.156</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k1} & {ACC-P1-k1} & {ACC-P2-k1} & {ACC-P3-k1} & {ACC-P4-k1} \\
# \texttt{LogReg} & 0.000 & 0.005 & 0.038 & \color{white} {\cellcolor{darkblue}} 0.105 & \color{white} {\cellcolor{darkblue}} 0.236 \\
# \texttt{RETAIN} & 0.076 & \color{white} {\cellcolor{darkblue}} 0.054 & 0.080 & 0.077 & 0.141 \\
# \texttt{GRU} & \color{white} {\cellcolor{darkblue}} 0.079 & 0.052 & 0.076 & 0.077 & 0.151 \\
# \texttt{GRU/G} & 0.075 & 0.049 & 0.078 & 0.084 & 0.143 \\
# \texttt{ICE-NODE} & 0.069 & 0.044 & 0.082 & 0.082 & 0.161 \\
# \texttt{ICE-NODE/G} & 0.068 & 0.043 & \color{white} {\cellcolor{darkblue}} 0.083 & 0.086 & 0.154 \\
# \texttt{ICE-NODE\_UNIFORM} & 0.072 & 0.044 & 0.079 & 0.085 & 0.155 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.065 & 0.045 & 0.080 & 0.089 & 0.156 \\
# \end{tabular}
# <style type="text/css">
# #T_1b9a9_row0_col3, #T_1b9a9_row0_col4, #T_1b9a9_row1_col1, #T_1b9a9_row2_col2, #T_1b9a9_row6_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_1b9a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k2</th>
#       <th class="col_heading level0 col1" >ACC-P1-k2</th>
#       <th class="col_heading level0 col2" >ACC-P2-k2</th>
#       <th class="col_heading level0 col3" >ACC-P3-k2</th>
#       <th class="col_heading level0 col4" >ACC-P4-k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b9a9_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_1b9a9_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_1b9a9_row0_col1" class="data row0 col1" >0.015</td>
#       <td id="T_1b9a9_row0_col2" class="data row0 col2" >0.075</td>
#       <td id="T_1b9a9_row0_col3" class="data row0 col3" >0.218</td>
#       <td id="T_1b9a9_row0_col4" class="data row0 col4" >0.415</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_1b9a9_row1_col0" class="data row1 col0" >0.119</td>
#       <td id="T_1b9a9_row1_col1" class="data row1 col1" >0.103</td>
#       <td id="T_1b9a9_row1_col2" class="data row1 col2" >0.140</td>
#       <td id="T_1b9a9_row1_col3" class="data row1 col3" >0.161</td>
#       <td id="T_1b9a9_row1_col4" class="data row1 col4" >0.283</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_1b9a9_row2_col0" class="data row2 col0" >0.117</td>
#       <td id="T_1b9a9_row2_col1" class="data row2 col1" >0.095</td>
#       <td id="T_1b9a9_row2_col2" class="data row2 col2" >0.145</td>
#       <td id="T_1b9a9_row2_col3" class="data row2 col3" >0.167</td>
#       <td id="T_1b9a9_row2_col4" class="data row2 col4" >0.292</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_1b9a9_row3_col0" class="data row3 col0" >0.114</td>
#       <td id="T_1b9a9_row3_col1" class="data row3 col1" >0.095</td>
#       <td id="T_1b9a9_row3_col2" class="data row3 col2" >0.139</td>
#       <td id="T_1b9a9_row3_col3" class="data row3 col3" >0.171</td>
#       <td id="T_1b9a9_row3_col4" class="data row3 col4" >0.296</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_1b9a9_row4_col0" class="data row4 col0" >0.117</td>
#       <td id="T_1b9a9_row4_col1" class="data row4 col1" >0.092</td>
#       <td id="T_1b9a9_row4_col2" class="data row4 col2" >0.136</td>
#       <td id="T_1b9a9_row4_col3" class="data row4 col3" >0.174</td>
#       <td id="T_1b9a9_row4_col4" class="data row4 col4" >0.292</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_1b9a9_row5_col0" class="data row5 col0" >0.118</td>
#       <td id="T_1b9a9_row5_col1" class="data row5 col1" >0.091</td>
#       <td id="T_1b9a9_row5_col2" class="data row5 col2" >0.136</td>
#       <td id="T_1b9a9_row5_col3" class="data row5 col3" >0.175</td>
#       <td id="T_1b9a9_row5_col4" class="data row5 col4" >0.291</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_1b9a9_row6_col0" class="data row6 col0" >0.123</td>
#       <td id="T_1b9a9_row6_col1" class="data row6 col1" >0.092</td>
#       <td id="T_1b9a9_row6_col2" class="data row6 col2" >0.135</td>
#       <td id="T_1b9a9_row6_col3" class="data row6 col3" >0.177</td>
#       <td id="T_1b9a9_row6_col4" class="data row6 col4" >0.282</td>
#     </tr>
#     <tr>
#       <th id="T_1b9a9_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_1b9a9_row7_col0" class="data row7 col0" >0.115</td>
#       <td id="T_1b9a9_row7_col1" class="data row7 col1" >0.093</td>
#       <td id="T_1b9a9_row7_col2" class="data row7 col2" >0.129</td>
#       <td id="T_1b9a9_row7_col3" class="data row7 col3" >0.180</td>
#       <td id="T_1b9a9_row7_col4" class="data row7 col4" >0.291</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k2} & {ACC-P1-k2} & {ACC-P2-k2} & {ACC-P3-k2} & {ACC-P4-k2} \\
# \texttt{LogReg} & 0.000 & 0.015 & 0.075 & \color{white} {\cellcolor{darkblue}} 0.218 & \color{white} {\cellcolor{darkblue}} 0.415 \\
# \texttt{RETAIN} & 0.119 & \color{white} {\cellcolor{darkblue}} 0.103 & 0.140 & 0.161 & 0.283 \\
# \texttt{GRU} & 0.117 & 0.095 & \color{white} {\cellcolor{darkblue}} 0.145 & 0.167 & 0.292 \\
# \texttt{GRU/G} & 0.114 & 0.095 & 0.139 & 0.171 & 0.296 \\
# \texttt{ICE-NODE} & 0.117 & 0.092 & 0.136 & 0.174 & 0.292 \\
# \texttt{ICE-NODE/G} & 0.118 & 0.091 & 0.136 & 0.175 & 0.291 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.123 & 0.092 & 0.135 & 0.177 & 0.282 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.115 & 0.093 & 0.129 & 0.180 & 0.291 \\
# \end{tabular}
# <style type="text/css">
# #T_198dd_row0_col3, #T_198dd_row0_col4, #T_198dd_row1_col1, #T_198dd_row3_col2, #T_198dd_row6_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_198dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k3</th>
#       <th class="col_heading level0 col1" >ACC-P1-k3</th>
#       <th class="col_heading level0 col2" >ACC-P2-k3</th>
#       <th class="col_heading level0 col3" >ACC-P3-k3</th>
#       <th class="col_heading level0 col4" >ACC-P4-k3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_198dd_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_198dd_row0_col0" class="data row0 col0" >0.001</td>
#       <td id="T_198dd_row0_col1" class="data row0 col1" >0.028</td>
#       <td id="T_198dd_row0_col2" class="data row0 col2" >0.110</td>
#       <td id="T_198dd_row0_col3" class="data row0 col3" >0.322</td>
#       <td id="T_198dd_row0_col4" class="data row0 col4" >0.552</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_198dd_row1_col0" class="data row1 col0" >0.155</td>
#       <td id="T_198dd_row1_col1" class="data row1 col1" >0.143</td>
#       <td id="T_198dd_row1_col2" class="data row1 col2" >0.194</td>
#       <td id="T_198dd_row1_col3" class="data row1 col3" >0.249</td>
#       <td id="T_198dd_row1_col4" class="data row1 col4" >0.406</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_198dd_row2_col0" class="data row2 col0" >0.149</td>
#       <td id="T_198dd_row2_col1" class="data row2 col1" >0.135</td>
#       <td id="T_198dd_row2_col2" class="data row2 col2" >0.194</td>
#       <td id="T_198dd_row2_col3" class="data row2 col3" >0.257</td>
#       <td id="T_198dd_row2_col4" class="data row2 col4" >0.426</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_198dd_row3_col0" class="data row3 col0" >0.146</td>
#       <td id="T_198dd_row3_col1" class="data row3 col1" >0.134</td>
#       <td id="T_198dd_row3_col2" class="data row3 col2" >0.195</td>
#       <td id="T_198dd_row3_col3" class="data row3 col3" >0.259</td>
#       <td id="T_198dd_row3_col4" class="data row3 col4" >0.423</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_198dd_row4_col0" class="data row4 col0" >0.154</td>
#       <td id="T_198dd_row4_col1" class="data row4 col1" >0.134</td>
#       <td id="T_198dd_row4_col2" class="data row4 col2" >0.187</td>
#       <td id="T_198dd_row4_col3" class="data row4 col3" >0.254</td>
#       <td id="T_198dd_row4_col4" class="data row4 col4" >0.413</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_198dd_row5_col0" class="data row5 col0" >0.152</td>
#       <td id="T_198dd_row5_col1" class="data row5 col1" >0.131</td>
#       <td id="T_198dd_row5_col2" class="data row5 col2" >0.186</td>
#       <td id="T_198dd_row5_col3" class="data row5 col3" >0.256</td>
#       <td id="T_198dd_row5_col4" class="data row5 col4" >0.419</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_198dd_row6_col0" class="data row6 col0" >0.159</td>
#       <td id="T_198dd_row6_col1" class="data row6 col1" >0.132</td>
#       <td id="T_198dd_row6_col2" class="data row6 col2" >0.186</td>
#       <td id="T_198dd_row6_col3" class="data row6 col3" >0.258</td>
#       <td id="T_198dd_row6_col4" class="data row6 col4" >0.407</td>
#     </tr>
#     <tr>
#       <th id="T_198dd_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_198dd_row7_col0" class="data row7 col0" >0.149</td>
#       <td id="T_198dd_row7_col1" class="data row7 col1" >0.135</td>
#       <td id="T_198dd_row7_col2" class="data row7 col2" >0.176</td>
#       <td id="T_198dd_row7_col3" class="data row7 col3" >0.264</td>
#       <td id="T_198dd_row7_col4" class="data row7 col4" >0.415</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k3} & {ACC-P1-k3} & {ACC-P2-k3} & {ACC-P3-k3} & {ACC-P4-k3} \\
# \texttt{LogReg} & 0.001 & 0.028 & 0.110 & \color{white} {\cellcolor{darkblue}} 0.322 & \color{white} {\cellcolor{darkblue}} 0.552 \\
# \texttt{RETAIN} & 0.155 & \color{white} {\cellcolor{darkblue}} 0.143 & 0.194 & 0.249 & 0.406 \\
# \texttt{GRU} & 0.149 & 0.135 & 0.194 & 0.257 & 0.426 \\
# \texttt{GRU/G} & 0.146 & 0.134 & \color{white} {\cellcolor{darkblue}} 0.195 & 0.259 & 0.423 \\
# \texttt{ICE-NODE} & 0.154 & 0.134 & 0.187 & 0.254 & 0.413 \\
# \texttt{ICE-NODE/G} & 0.152 & 0.131 & 0.186 & 0.256 & 0.419 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.159 & 0.132 & 0.186 & 0.258 & 0.407 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.149 & 0.135 & 0.176 & 0.264 & 0.415 \\
# \end{tabular}
# <style type="text/css">
# #T_de630_row0_col3, #T_de630_row0_col4, #T_de630_row1_col1, #T_de630_row2_col2, #T_de630_row6_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_de630_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k5</th>
#       <th class="col_heading level0 col1" >ACC-P1-k5</th>
#       <th class="col_heading level0 col2" >ACC-P2-k5</th>
#       <th class="col_heading level0 col3" >ACC-P3-k5</th>
#       <th class="col_heading level0 col4" >ACC-P4-k5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de630_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_de630_row0_col0" class="data row0 col0" >0.003</td>
#       <td id="T_de630_row0_col1" class="data row0 col1" >0.061</td>
#       <td id="T_de630_row0_col2" class="data row0 col2" >0.193</td>
#       <td id="T_de630_row0_col3" class="data row0 col3" >0.481</td>
#       <td id="T_de630_row0_col4" class="data row0 col4" >0.718</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_de630_row1_col0" class="data row1 col0" >0.214</td>
#       <td id="T_de630_row1_col1" class="data row1 col1" >0.210</td>
#       <td id="T_de630_row1_col2" class="data row1 col2" >0.291</td>
#       <td id="T_de630_row1_col3" class="data row1 col3" >0.395</td>
#       <td id="T_de630_row1_col4" class="data row1 col4" >0.593</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_de630_row2_col0" class="data row2 col0" >0.200</td>
#       <td id="T_de630_row2_col1" class="data row2 col1" >0.199</td>
#       <td id="T_de630_row2_col2" class="data row2 col2" >0.296</td>
#       <td id="T_de630_row2_col3" class="data row2 col3" >0.405</td>
#       <td id="T_de630_row2_col4" class="data row2 col4" >0.609</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_de630_row3_col0" class="data row3 col0" >0.197</td>
#       <td id="T_de630_row3_col1" class="data row3 col1" >0.198</td>
#       <td id="T_de630_row3_col2" class="data row3 col2" >0.292</td>
#       <td id="T_de630_row3_col3" class="data row3 col3" >0.408</td>
#       <td id="T_de630_row3_col4" class="data row3 col4" >0.608</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_de630_row4_col0" class="data row4 col0" >0.216</td>
#       <td id="T_de630_row4_col1" class="data row4 col1" >0.203</td>
#       <td id="T_de630_row4_col2" class="data row4 col2" >0.275</td>
#       <td id="T_de630_row4_col3" class="data row4 col3" >0.391</td>
#       <td id="T_de630_row4_col4" class="data row4 col4" >0.596</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_de630_row5_col0" class="data row5 col0" >0.214</td>
#       <td id="T_de630_row5_col1" class="data row5 col1" >0.202</td>
#       <td id="T_de630_row5_col2" class="data row5 col2" >0.275</td>
#       <td id="T_de630_row5_col3" class="data row5 col3" >0.390</td>
#       <td id="T_de630_row5_col4" class="data row5 col4" >0.601</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_de630_row6_col0" class="data row6 col0" >0.221</td>
#       <td id="T_de630_row6_col1" class="data row6 col1" >0.204</td>
#       <td id="T_de630_row6_col2" class="data row6 col2" >0.273</td>
#       <td id="T_de630_row6_col3" class="data row6 col3" >0.393</td>
#       <td id="T_de630_row6_col4" class="data row6 col4" >0.593</td>
#     </tr>
#     <tr>
#       <th id="T_de630_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_de630_row7_col0" class="data row7 col0" >0.210</td>
#       <td id="T_de630_row7_col1" class="data row7 col1" >0.206</td>
#       <td id="T_de630_row7_col2" class="data row7 col2" >0.268</td>
#       <td id="T_de630_row7_col3" class="data row7 col3" >0.398</td>
#       <td id="T_de630_row7_col4" class="data row7 col4" >0.598</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k5} & {ACC-P1-k5} & {ACC-P2-k5} & {ACC-P3-k5} & {ACC-P4-k5} \\
# \texttt{LogReg} & 0.003 & 0.061 & 0.193 & \color{white} {\cellcolor{darkblue}} 0.481 & \color{white} {\cellcolor{darkblue}} 0.718 \\
# \texttt{RETAIN} & 0.214 & \color{white} {\cellcolor{darkblue}} 0.210 & 0.291 & 0.395 & 0.593 \\
# \texttt{GRU} & 0.200 & 0.199 & \color{white} {\cellcolor{darkblue}} 0.296 & 0.405 & 0.609 \\
# \texttt{GRU/G} & 0.197 & 0.198 & 0.292 & 0.408 & 0.608 \\
# \texttt{ICE-NODE} & 0.216 & 0.203 & 0.275 & 0.391 & 0.596 \\
# \texttt{ICE-NODE/G} & 0.214 & 0.202 & 0.275 & 0.390 & 0.601 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.221 & 0.204 & 0.273 & 0.393 & 0.593 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.210 & 0.206 & 0.268 & 0.398 & 0.598 \\
# \end{tabular}
# <style type="text/css">
# #T_5204f_row0_col3, #T_5204f_row0_col4, #T_5204f_row1_col1, #T_5204f_row1_col2, #T_5204f_row2_col2, #T_5204f_row4_col1, #T_5204f_row6_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_5204f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k7</th>
#       <th class="col_heading level0 col1" >ACC-P1-k7</th>
#       <th class="col_heading level0 col2" >ACC-P2-k7</th>
#       <th class="col_heading level0 col3" >ACC-P3-k7</th>
#       <th class="col_heading level0 col4" >ACC-P4-k7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5204f_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_5204f_row0_col0" class="data row0 col0" >0.007</td>
#       <td id="T_5204f_row0_col1" class="data row0 col1" >0.095</td>
#       <td id="T_5204f_row0_col2" class="data row0 col2" >0.285</td>
#       <td id="T_5204f_row0_col3" class="data row0 col3" >0.601</td>
#       <td id="T_5204f_row0_col4" class="data row0 col4" >0.799</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_5204f_row1_col0" class="data row1 col0" >0.257</td>
#       <td id="T_5204f_row1_col1" class="data row1 col1" >0.259</td>
#       <td id="T_5204f_row1_col2" class="data row1 col2" >0.373</td>
#       <td id="T_5204f_row1_col3" class="data row1 col3" >0.510</td>
#       <td id="T_5204f_row1_col4" class="data row1 col4" >0.712</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_5204f_row2_col0" class="data row2 col0" >0.240</td>
#       <td id="T_5204f_row2_col1" class="data row2 col1" >0.249</td>
#       <td id="T_5204f_row2_col2" class="data row2 col2" >0.373</td>
#       <td id="T_5204f_row2_col3" class="data row2 col3" >0.526</td>
#       <td id="T_5204f_row2_col4" class="data row2 col4" >0.721</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_5204f_row3_col0" class="data row3 col0" >0.241</td>
#       <td id="T_5204f_row3_col1" class="data row3 col1" >0.249</td>
#       <td id="T_5204f_row3_col2" class="data row3 col2" >0.368</td>
#       <td id="T_5204f_row3_col3" class="data row3 col3" >0.522</td>
#       <td id="T_5204f_row3_col4" class="data row3 col4" >0.726</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_5204f_row4_col0" class="data row4 col0" >0.264</td>
#       <td id="T_5204f_row4_col1" class="data row4 col1" >0.259</td>
#       <td id="T_5204f_row4_col2" class="data row4 col2" >0.354</td>
#       <td id="T_5204f_row4_col3" class="data row4 col3" >0.494</td>
#       <td id="T_5204f_row4_col4" class="data row4 col4" >0.716</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_5204f_row5_col0" class="data row5 col0" >0.263</td>
#       <td id="T_5204f_row5_col1" class="data row5 col1" >0.256</td>
#       <td id="T_5204f_row5_col2" class="data row5 col2" >0.354</td>
#       <td id="T_5204f_row5_col3" class="data row5 col3" >0.494</td>
#       <td id="T_5204f_row5_col4" class="data row5 col4" >0.719</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_5204f_row6_col0" class="data row6 col0" >0.267</td>
#       <td id="T_5204f_row6_col1" class="data row6 col1" >0.258</td>
#       <td id="T_5204f_row6_col2" class="data row6 col2" >0.351</td>
#       <td id="T_5204f_row6_col3" class="data row6 col3" >0.500</td>
#       <td id="T_5204f_row6_col4" class="data row6 col4" >0.712</td>
#     </tr>
#     <tr>
#       <th id="T_5204f_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_5204f_row7_col0" class="data row7 col0" >0.258</td>
#       <td id="T_5204f_row7_col1" class="data row7 col1" >0.258</td>
#       <td id="T_5204f_row7_col2" class="data row7 col2" >0.347</td>
#       <td id="T_5204f_row7_col3" class="data row7 col3" >0.503</td>
#       <td id="T_5204f_row7_col4" class="data row7 col4" >0.713</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k7} & {ACC-P1-k7} & {ACC-P2-k7} & {ACC-P3-k7} & {ACC-P4-k7} \\
# \texttt{LogReg} & 0.007 & 0.095 & 0.285 & \color{white} {\cellcolor{darkblue}} 0.601 & \color{white} {\cellcolor{darkblue}} 0.799 \\
# \texttt{RETAIN} & 0.257 & \color{white} {\cellcolor{darkblue}} 0.259 & \color{white} {\cellcolor{darkblue}} 0.373 & 0.510 & 0.712 \\
# \texttt{GRU} & 0.240 & 0.249 & \color{white} {\cellcolor{darkblue}} 0.373 & 0.526 & 0.721 \\
# \texttt{GRU/G} & 0.241 & 0.249 & 0.368 & 0.522 & 0.726 \\
# \texttt{ICE-NODE} & 0.264 & \color{white} {\cellcolor{darkblue}} 0.259 & 0.354 & 0.494 & 0.716 \\
# \texttt{ICE-NODE/G} & 0.263 & 0.256 & 0.354 & 0.494 & 0.719 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.267 & 0.258 & 0.351 & 0.500 & 0.712 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.258 & 0.258 & 0.347 & 0.503 & 0.713 \\
# \end{tabular}
# <style type="text/css">
# #T_6216d_row0_col3, #T_6216d_row0_col4, #T_6216d_row2_col2, #T_6216d_row6_col0, #T_6216d_row6_col1 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_6216d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k10</th>
#       <th class="col_heading level0 col1" >ACC-P1-k10</th>
#       <th class="col_heading level0 col2" >ACC-P2-k10</th>
#       <th class="col_heading level0 col3" >ACC-P3-k10</th>
#       <th class="col_heading level0 col4" >ACC-P4-k10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6216d_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_6216d_row0_col0" class="data row0 col0" >0.014</td>
#       <td id="T_6216d_row0_col1" class="data row0 col1" >0.152</td>
#       <td id="T_6216d_row0_col2" class="data row0 col2" >0.384</td>
#       <td id="T_6216d_row0_col3" class="data row0 col3" >0.744</td>
#       <td id="T_6216d_row0_col4" class="data row0 col4" >0.866</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_6216d_row1_col0" class="data row1 col0" >0.301</td>
#       <td id="T_6216d_row1_col1" class="data row1 col1" >0.314</td>
#       <td id="T_6216d_row1_col2" class="data row1 col2" >0.474</td>
#       <td id="T_6216d_row1_col3" class="data row1 col3" >0.647</td>
#       <td id="T_6216d_row1_col4" class="data row1 col4" >0.820</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_6216d_row2_col0" class="data row2 col0" >0.282</td>
#       <td id="T_6216d_row2_col1" class="data row2 col1" >0.310</td>
#       <td id="T_6216d_row2_col2" class="data row2 col2" >0.475</td>
#       <td id="T_6216d_row2_col3" class="data row2 col3" >0.672</td>
#       <td id="T_6216d_row2_col4" class="data row2 col4" >0.818</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_6216d_row3_col0" class="data row3 col0" >0.286</td>
#       <td id="T_6216d_row3_col1" class="data row3 col1" >0.309</td>
#       <td id="T_6216d_row3_col2" class="data row3 col2" >0.470</td>
#       <td id="T_6216d_row3_col3" class="data row3 col3" >0.664</td>
#       <td id="T_6216d_row3_col4" class="data row3 col4" >0.825</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_6216d_row4_col0" class="data row4 col0" >0.311</td>
#       <td id="T_6216d_row4_col1" class="data row4 col1" >0.316</td>
#       <td id="T_6216d_row4_col2" class="data row4 col2" >0.459</td>
#       <td id="T_6216d_row4_col3" class="data row4 col3" >0.627</td>
#       <td id="T_6216d_row4_col4" class="data row4 col4" >0.811</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_6216d_row5_col0" class="data row5 col0" >0.311</td>
#       <td id="T_6216d_row5_col1" class="data row5 col1" >0.317</td>
#       <td id="T_6216d_row5_col2" class="data row5 col2" >0.455</td>
#       <td id="T_6216d_row5_col3" class="data row5 col3" >0.625</td>
#       <td id="T_6216d_row5_col4" class="data row5 col4" >0.817</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_6216d_row6_col0" class="data row6 col0" >0.316</td>
#       <td id="T_6216d_row6_col1" class="data row6 col1" >0.320</td>
#       <td id="T_6216d_row6_col2" class="data row6 col2" >0.453</td>
#       <td id="T_6216d_row6_col3" class="data row6 col3" >0.626</td>
#       <td id="T_6216d_row6_col4" class="data row6 col4" >0.807</td>
#     </tr>
#     <tr>
#       <th id="T_6216d_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_6216d_row7_col0" class="data row7 col0" >0.306</td>
#       <td id="T_6216d_row7_col1" class="data row7 col1" >0.316</td>
#       <td id="T_6216d_row7_col2" class="data row7 col2" >0.451</td>
#       <td id="T_6216d_row7_col3" class="data row7 col3" >0.632</td>
#       <td id="T_6216d_row7_col4" class="data row7 col4" >0.811</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k10} & {ACC-P1-k10} & {ACC-P2-k10} & {ACC-P3-k10} & {ACC-P4-k10} \\
# \texttt{LogReg} & 0.014 & 0.152 & 0.384 & \color{white} {\cellcolor{darkblue}} 0.744 & \color{white} {\cellcolor{darkblue}} 0.866 \\
# \texttt{RETAIN} & 0.301 & 0.314 & 0.474 & 0.647 & 0.820 \\
# \texttt{GRU} & 0.282 & 0.310 & \color{white} {\cellcolor{darkblue}} 0.475 & 0.672 & 0.818 \\
# \texttt{GRU/G} & 0.286 & 0.309 & 0.470 & 0.664 & 0.825 \\
# \texttt{ICE-NODE} & 0.311 & 0.316 & 0.459 & 0.627 & 0.811 \\
# \texttt{ICE-NODE/G} & 0.311 & 0.317 & 0.455 & 0.625 & 0.817 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.316 & \color{white} {\cellcolor{darkblue}} 0.320 & 0.453 & 0.626 & 0.807 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.306 & 0.316 & 0.451 & 0.632 & 0.811 \\
# \end{tabular}
# <style type="text/css">
# #T_d84b1_row0_col3, #T_d84b1_row0_col4, #T_d84b1_row2_col1, #T_d84b1_row2_col2, #T_d84b1_row3_col1, #T_d84b1_row6_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_d84b1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k15</th>
#       <th class="col_heading level0 col1" >ACC-P1-k15</th>
#       <th class="col_heading level0 col2" >ACC-P2-k15</th>
#       <th class="col_heading level0 col3" >ACC-P3-k15</th>
#       <th class="col_heading level0 col4" >ACC-P4-k15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d84b1_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_d84b1_row0_col0" class="data row0 col0" >0.027</td>
#       <td id="T_d84b1_row0_col1" class="data row0 col1" >0.240</td>
#       <td id="T_d84b1_row0_col2" class="data row0 col2" >0.543</td>
#       <td id="T_d84b1_row0_col3" class="data row0 col3" >0.858</td>
#       <td id="T_d84b1_row0_col4" class="data row0 col4" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_d84b1_row1_col0" class="data row1 col0" >0.351</td>
#       <td id="T_d84b1_row1_col1" class="data row1 col1" >0.385</td>
#       <td id="T_d84b1_row1_col2" class="data row1 col2" >0.602</td>
#       <td id="T_d84b1_row1_col3" class="data row1 col3" >0.805</td>
#       <td id="T_d84b1_row1_col4" class="data row1 col4" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_d84b1_row2_col0" class="data row2 col0" >0.332</td>
#       <td id="T_d84b1_row2_col1" class="data row2 col1" >0.392</td>
#       <td id="T_d84b1_row2_col2" class="data row2 col2" >0.610</td>
#       <td id="T_d84b1_row2_col3" class="data row2 col3" >0.819</td>
#       <td id="T_d84b1_row2_col4" class="data row2 col4" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_d84b1_row3_col0" class="data row3 col0" >0.335</td>
#       <td id="T_d84b1_row3_col1" class="data row3 col1" >0.392</td>
#       <td id="T_d84b1_row3_col2" class="data row3 col2" >0.604</td>
#       <td id="T_d84b1_row3_col3" class="data row3 col3" >0.820</td>
#       <td id="T_d84b1_row3_col4" class="data row3 col4" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_d84b1_row4_col0" class="data row4 col0" >0.361</td>
#       <td id="T_d84b1_row4_col1" class="data row4 col1" >0.389</td>
#       <td id="T_d84b1_row4_col2" class="data row4 col2" >0.584</td>
#       <td id="T_d84b1_row4_col3" class="data row4 col3" >0.780</td>
#       <td id="T_d84b1_row4_col4" class="data row4 col4" >0.894</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_d84b1_row5_col0" class="data row5 col0" >0.360</td>
#       <td id="T_d84b1_row5_col1" class="data row5 col1" >0.386</td>
#       <td id="T_d84b1_row5_col2" class="data row5 col2" >0.584</td>
#       <td id="T_d84b1_row5_col3" class="data row5 col3" >0.780</td>
#       <td id="T_d84b1_row5_col4" class="data row5 col4" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_d84b1_row6_col0" class="data row6 col0" >0.363</td>
#       <td id="T_d84b1_row6_col1" class="data row6 col1" >0.391</td>
#       <td id="T_d84b1_row6_col2" class="data row6 col2" >0.581</td>
#       <td id="T_d84b1_row6_col3" class="data row6 col3" >0.779</td>
#       <td id="T_d84b1_row6_col4" class="data row6 col4" >0.890</td>
#     </tr>
#     <tr>
#       <th id="T_d84b1_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_d84b1_row7_col0" class="data row7 col0" >0.357</td>
#       <td id="T_d84b1_row7_col1" class="data row7 col1" >0.385</td>
#       <td id="T_d84b1_row7_col2" class="data row7 col2" >0.578</td>
#       <td id="T_d84b1_row7_col3" class="data row7 col3" >0.786</td>
#       <td id="T_d84b1_row7_col4" class="data row7 col4" >0.892</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k15} & {ACC-P1-k15} & {ACC-P2-k15} & {ACC-P3-k15} & {ACC-P4-k15} \\
# \texttt{LogReg} & 0.027 & 0.240 & 0.543 & \color{white} {\cellcolor{darkblue}} 0.858 & \color{white} {\cellcolor{darkblue}} 0.939 \\
# \texttt{RETAIN} & 0.351 & 0.385 & 0.602 & 0.805 & 0.905 \\
# \texttt{GRU} & 0.332 & \color{white} {\cellcolor{darkblue}} 0.392 & \color{white} {\cellcolor{darkblue}} 0.610 & 0.819 & 0.896 \\
# \texttt{GRU/G} & 0.335 & \color{white} {\cellcolor{darkblue}} 0.392 & 0.604 & 0.820 & 0.900 \\
# \texttt{ICE-NODE} & 0.361 & 0.389 & 0.584 & 0.780 & 0.894 \\
# \texttt{ICE-NODE/G} & 0.360 & 0.386 & 0.584 & 0.780 & 0.896 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.363 & 0.391 & 0.581 & 0.779 & 0.890 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.357 & 0.385 & 0.578 & 0.786 & 0.892 \\
# \end{tabular}
# <style type="text/css">
# #T_c5641_row0_col3, #T_c5641_row0_col4, #T_c5641_row2_col2, #T_c5641_row3_col1, #T_c5641_row6_col0 {
#   bfseries: ;
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_c5641_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ACC-P0-k20</th>
#       <th class="col_heading level0 col1" >ACC-P1-k20</th>
#       <th class="col_heading level0 col2" >ACC-P2-k20</th>
#       <th class="col_heading level0 col3" >ACC-P3-k20</th>
#       <th class="col_heading level0 col4" >ACC-P4-k20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5641_level0_row0" class="row_heading level0 row0" >LogReg</th>
#       <td id="T_c5641_row0_col0" class="data row0 col0" >0.042</td>
#       <td id="T_c5641_row0_col1" class="data row0 col1" >0.317</td>
#       <td id="T_c5641_row0_col2" class="data row0 col2" >0.701</td>
#       <td id="T_c5641_row0_col3" class="data row0 col3" >0.910</td>
#       <td id="T_c5641_row0_col4" class="data row0 col4" >0.971</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row1" class="row_heading level0 row1" >RETAIN</th>
#       <td id="T_c5641_row1_col0" class="data row1 col0" >0.383</td>
#       <td id="T_c5641_row1_col1" class="data row1 col1" >0.449</td>
#       <td id="T_c5641_row1_col2" class="data row1 col2" >0.706</td>
#       <td id="T_c5641_row1_col3" class="data row1 col3" >0.886</td>
#       <td id="T_c5641_row1_col4" class="data row1 col4" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row2" class="row_heading level0 row2" >GRU</th>
#       <td id="T_c5641_row2_col0" class="data row2 col0" >0.374</td>
#       <td id="T_c5641_row2_col1" class="data row2 col1" >0.461</td>
#       <td id="T_c5641_row2_col2" class="data row2 col2" >0.722</td>
#       <td id="T_c5641_row2_col3" class="data row2 col3" >0.892</td>
#       <td id="T_c5641_row2_col4" class="data row2 col4" >0.935</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row3" class="row_heading level0 row3" >GRU/G</th>
#       <td id="T_c5641_row3_col0" class="data row3 col0" >0.375</td>
#       <td id="T_c5641_row3_col1" class="data row3 col1" >0.462</td>
#       <td id="T_c5641_row3_col2" class="data row3 col2" >0.711</td>
#       <td id="T_c5641_row3_col3" class="data row3 col3" >0.897</td>
#       <td id="T_c5641_row3_col4" class="data row3 col4" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row4" class="row_heading level0 row4" >ICE-NODE</th>
#       <td id="T_c5641_row4_col0" class="data row4 col0" >0.392</td>
#       <td id="T_c5641_row4_col1" class="data row4 col1" >0.450</td>
#       <td id="T_c5641_row4_col2" class="data row4 col2" >0.687</td>
#       <td id="T_c5641_row4_col3" class="data row4 col3" >0.870</td>
#       <td id="T_c5641_row4_col4" class="data row4 col4" >0.938</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row5" class="row_heading level0 row5" >ICE-NODE/G</th>
#       <td id="T_c5641_row5_col0" class="data row5 col0" >0.392</td>
#       <td id="T_c5641_row5_col1" class="data row5 col1" >0.444</td>
#       <td id="T_c5641_row5_col2" class="data row5 col2" >0.683</td>
#       <td id="T_c5641_row5_col3" class="data row5 col3" >0.872</td>
#       <td id="T_c5641_row5_col4" class="data row5 col4" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row6" class="row_heading level0 row6" >ICE-NODE_UNIFORM</th>
#       <td id="T_c5641_row6_col0" class="data row6 col0" >0.393</td>
#       <td id="T_c5641_row6_col1" class="data row6 col1" >0.449</td>
#       <td id="T_c5641_row6_col2" class="data row6 col2" >0.683</td>
#       <td id="T_c5641_row6_col3" class="data row6 col3" >0.870</td>
#       <td id="T_c5641_row6_col4" class="data row6 col4" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_c5641_level0_row7" class="row_heading level0 row7" >ICE-NODE_UNIFORM/G</th>
#       <td id="T_c5641_row7_col0" class="data row7 col0" >0.389</td>
#       <td id="T_c5641_row7_col1" class="data row7 col1" >0.443</td>
#       <td id="T_c5641_row7_col2" class="data row7 col2" >0.681</td>
#       <td id="T_c5641_row7_col3" class="data row7 col3" >0.875</td>
#       <td id="T_c5641_row7_col4" class="data row7 col4" >0.940</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
# {} & {ACC-P0-k20} & {ACC-P1-k20} & {ACC-P2-k20} & {ACC-P3-k20} & {ACC-P4-k20} \\
# \texttt{LogReg} & 0.042 & 0.317 & 0.701 & \color{white} {\cellcolor{darkblue}} 0.910 & \color{white} {\cellcolor{darkblue}} 0.971 \\
# \texttt{RETAIN} & 0.383 & 0.449 & 0.706 & 0.886 & 0.947 \\
# \texttt{GRU} & 0.374 & 0.461 & \color{white} {\cellcolor{darkblue}} 0.722 & 0.892 & 0.935 \\
# \texttt{GRU/G} & 0.375 & \color{white} {\cellcolor{darkblue}} 0.462 & 0.711 & 0.897 & 0.939 \\
# \texttt{ICE-NODE} & 0.392 & 0.450 & 0.687 & 0.870 & 0.938 \\
# \texttt{ICE-NODE/G} & 0.392 & 0.444 & 0.683 & 0.872 & 0.939 \\
# \texttt{ICE-NODE\_UNIFORM} & \color{white} {\cellcolor{darkblue}} 0.393 & 0.449 & 0.683 & 0.870 & 0.939 \\
# \texttt{ICE-NODE\_UNIFORM/G} & 0.389 & 0.443 & 0.681 & 0.875 & 0.940 \\
# \end{tabular}

# %%
icenode_m4m3_excl = upsetcontents_m4m3['ICE-NODE'] - set.union(*list(upsetcontents_m4m3[clf] for clf in ('RETAIN', 'GRU', 'ICE-NODE_UNIFORM')))
icenode_m4m3_excl = compete_codesm4m3[compete_codesm4m3['CODE_INDEX'].isin(icenode_m4m3_excl)]
icenode_m4m3_excl
# Out:
#     CODE_INDEX  N_POSITIVE_CODES  AUC(GRU)  AUC(GRU/G)  AUC(ICE-NODE)  \
# 64          64            1489.0  0.899104    0.895756       0.911772
#
#     AUC(ICE-NODE/G)  AUC(ICE-NODE_UNIFORM)  AUC(ICE-NODE_UNIFORM/G)  \
# 64         0.910852               0.894193                 0.894601
#
#     AUC(LogReg)  AUC(RETAIN)  ...  P0(AUC_ICE-NODE/G==AUC_ICE-NODE_UNIFORM/G)  \
# 64     0.876729     0.888024  ...                                2.834346e-19
#
#     P0(AUC_ICE-NODE/G==AUC_LogReg)  P0(AUC_ICE-NODE/G==AUC_RETAIN)  \
# 64                    1.696130e-14                    5.580744e-16
#
#     P0(AUC_ICE-NODE_UNIFORM==AUC_ICE-NODE_UNIFORM/G)  \
# 64                                          0.722663
#
#     P0(AUC_ICE-NODE_UNIFORM==AUC_LogReg)  \
# 64                              0.000041
#
#     P0(AUC_ICE-NODE_UNIFORM==AUC_RETAIN)  \
# 64                              0.017283
#
#     P0(AUC_ICE-NODE_UNIFORM/G==AUC_LogReg)  \
# 64                                0.000023
#
#     P0(AUC_ICE-NODE_UNIFORM/G==AUC_RETAIN)  P0(AUC_LogReg==AUC_RETAIN)  \
# 64                                0.007806                    0.013917
#
#             DESC
# 64  Ac renl fail
#
# [1 rows x 47 columns]

# %%
ax = A.selected_auc_barplot(upset_clfs, icenode_m4m3_excl, horizontal=True)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
# ax.legend(fontsize=22, title_fontsize=32,
#           bbox_to_anchor=(0.02, 1), ncol=2)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
ax.legend(fontsize=22, title_fontsize=32,
          bbox_to_anchor=(1, 1.17), ncol=2)

current_figure = plt.gcf()
current_figure.savefig("icenode_m4m3.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Trajectories for Patients with CCS codes best predicted with ICENODE

# %% [markdown]
# ### Analyse AUC for Each Admission in the Test Partition

# %%
def admissions_auc_scores(model, test_ids):
    model, state = model
    return model.admissions_auc_scores(state, test_ids)

# %%
m4_icenode_visit_auc_df = admissions_auc_scores(m4_predictors['ICE-NODE'], m4_test_ids)
m4_icenode_visit_auc_df['N_VISITS'] = m4_icenode_visit_auc_df['SUBJECT_ID'].apply(lambda i: (m4_icenode_visit_auc_df['SUBJECT_ID'] == i).sum())

# %%
m4_visit_auc_subject = m4_icenode_visit_auc_df.groupby('SUBJECT_ID').agg(
    {'AUC': 'mean', 
     'N_VISITS': 'max', 
     'N_CODES': ['min', 'max', 'mean', 'median'], 
     'INTERVALS': ['mean', 'max', 'min'] })

# %%
m4m3_icenode_visit_auc_df = admissions_auc_scores(m4m3_predictors['ICE-NODE'], m3_interface.subjects.keys())
m4m3_icenode_visit_auc_df['N_VISITS'] = m4m3_icenode_visit_auc_df['SUBJECT_ID'].apply(lambda i: (m4m3_icenode_visit_auc_df['SUBJECT_ID'] == i).sum())
m4m3_visit_auc_subject = m4m3_icenode_visit_auc_df.groupby('SUBJECT_ID').agg(
    {'AUC': 'mean', 
     'N_VISITS': 'max', 
     'N_CODES': ['min', 'max', 'mean', 'median'], 
     'INTERVALS': ['mean', 'max', 'min']
    })

# %%
m4_best_visit_auc_subjects =  m4_visit_auc_subject[(m4_visit_auc_subject.N_VISITS['max'] > 2) & (m4_visit_auc_subject.INTERVALS['max'] < 150)]
m4m3_best_visit_auc_subjects =  m4m3_visit_auc_subject[(m4m3_visit_auc_subject.N_VISITS['max'] > 1) & (m4m3_visit_auc_subject.INTERVALS['max'] < 150)]

# %%
len(m4_best_visit_auc_subjects), len(m4m3_best_visit_auc_subjects)
# Out:
# (365, 220)

# %%
m4_ccs_history = {i: m4_interface.dx_flatccs_history(i) for i in m4_best_visit_auc_subjects.index}
m4m3_ccs_history = {i: m3_interface.dx_flatccs_history(i) for i in m4m3_best_visit_auc_subjects.index}

m4_ccs_idx_frequency = m4_interface.dx_flatccs_frequency(list(m4_best_visit_auc_subjects.index))
m3_ccs_idx_frequency = m3_interface.dx_flatccs_frequency(list(m4m3_best_visit_auc_subjects.index))

# %%
m4_history_all_ccs_codes = set(map(C.ccs_dag.dx_flatccs_idx.get, set.union(*[set(h.keys()) for h in m4_ccs_history.values()])))
m3_history_all_ccs_codes = set(map(C.ccs_dag.dx_flatccs_idx.get, set.union(*[set(h.keys()) for h in m4m3_ccs_history.values()])))
m4_history_all_ccs_codes = {idx for idx in m4_history_all_ccs_codes if m4_ccs_idx_frequency[idx] < 10}
m3_history_all_ccs_codes = {idx for idx in m3_history_all_ccs_codes if m3_ccs_idx_frequency[idx] < 10}

len(m4_history_all_ccs_codes), len(m3_history_all_ccs_codes)
# Out:
# (51, 74)

# %%
icenode_m4_competent = upsetcontents_m4['ICE-NODE'] 
icenode_m4_competent = auctests_m4[auctests_m4['CODE_INDEX'].isin(icenode_m4_competent)]
icenode_m4_competent = icenode_m4_competent[['N_POSITIVE_CODES', 'AUC(ICE-NODE)', 'DESC']].sort_values('N_POSITIVE_CODES',ascending=False)
# icenode_m4_competent.head(50)
trajectory_ccs_codes_level2 = [
    173, 168, 169, 156, 165, 216, 171, 100, 167
]
icenode_m4_competent[icenode_m4_competent.index.isin(trajectory_ccs_codes_level2)]
# Out:
#      N_POSITIVE_CODES  AUC(ICE-NODE)          DESC
# 173            1790.0       0.941892  Non-Hodg lym
# 168             520.0       0.951321  Kidny/rnl ca
# 216             244.0       0.974325    Meningitis
# 169             181.0       0.942847  Uriny org ca
# 156             148.0       0.965231  Uterus cancr
# 165             146.0       0.957154  Testis cancr
# 171              89.0       0.940833  Thyroid cncr
# 100              84.0       0.952710  Brnch/lng ca
# 167              67.0       0.957488  Bladder cncr

# %%
trajectory_ccs_codes_level1 = [
    64, #renal fail 
    6, # pulm heart dx
    236, # ear dx 
]

# %%
m4_ccs_history_level1 = {i: history for i, history in m4_ccs_history.items() 
                         if len(set(map(A.dx_flatccs_idx2code.get, trajectory_ccs_codes_level1)) & set(history.keys())) > 0}
m4m3_ccs_history_level1 = {i: history for i, history in m4m3_ccs_history.items() 
                         if len(set(map(A.dx_flatccs_idx2code.get, trajectory_ccs_codes_level1)) & set(history.keys())) > 0}

m4_ccs_history_level2 = {i: history for i, history in m4_ccs_history.items() 
                         if len(set(map(A.dx_flatccs_idx2code.get, trajectory_ccs_codes_level2)) & set(history.keys())) > 0}
m4m3_ccs_history_level2 = {i: history for i, history in m4m3_ccs_history.items() 
                         if len(set(map(A.dx_flatccs_idx2code.get, trajectory_ccs_codes_level2)) & set(history.keys())) > 0}

# %%
len(m4_ccs_history_level1), len(m4m3_ccs_history_level1), len(m4_ccs_history_level2), len(m4m3_ccs_history_level2)
# Out:
# (180, 115, 68, 35)

# %%
m4_cases = set(m4_ccs_history_level1.keys()) | set(m4_ccs_history_level2.keys())
m4m3_cases = set(m4m3_ccs_history_level1.keys()) | set(m4m3_ccs_history_level2.keys())
len(m4_cases), len(m4m3_cases)
# Out:
# (206, 131)

# %%
m4_icenode, m4_icenode_state = m4_predictors['ICE-NODE']
m4_trajectory = m4_icenode.sample_trajectory(m4_icenode_state, m4_cases, 1)
# Out:
#   0%|                                                    | 0/22 [00:00<?, ?it/s]/home/asem/GP/ICENODE/notebooks/../icenode/ehr_predictive/dx_icenode_tl.py:412: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pos[[top10_idx]] = 1
# 100%|███████████████████████████████████████████| 22/22 [34:49<00:00, 94.97s/it]

# %%
m4m3_icenode, m4m3_icenode_state = m4m3_predictors['ICE-NODE']
m4m3_trajectory = m4m3_icenode.sample_trajectory(m4m3_icenode_state, m4m3_cases, 1)
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [12:57<00:00, 86.38s/it]

# %%
# m4_selected_subjects = [
#     13798593, #acute-renal
#     13965528, #acute-renal
#     11907876, #pulmonary heart dx
#     13557547, #ear dx
#     10139504, #acute renal fail
#     12367864, #pulomonary-heart dx
# ]

# m4_selected_trajectory = {i: m4_trajectory[i] for i in m4_selected_subjects}

# m3_selected_subjects = [
#     50093 #pulmonary-heart dx
# ]

# m3_selected_trajectory = {i: m4m3_trajectory[i] for i in m3_selected_subjects}

# %%
import random

trajectory_ccs_codes_level1 = [
    64, #renal fail 
    6, # pulm heart dx
    236, # ear dx 
    # Others
    100, # Brnch/lng ca
    168, # Kidney/rnl ca
    194, # Immunity dx
]



# icenode_m4_competent.head(50)
trajectory_ccs_codes_level2 = [
    173, 168, 169, 156, 165, 216, 171, 100, 167
]

random.seed(42)
ccs_color = {
    6: 'blue',
    64: 'purple',
    236: 'orange',
    # Others
    100: 'salmon', # Brnch/lng ca
    168: 'navy', # Kidney/rnl ca
    194: 'pink', # Immunity dx
    **{idx: "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
                   for idx in trajectory_ccs_codes_level2}
}


plt.rcParams['figure.figsize'] = (10, 7)

# %%
plt.close('all')
for data_label, interface, trajectory_set in zip(["M4", "M3"], [m4_interface, m3_interface], [m4_trajectory, m4m3_trajectory]):
    for indices_label, ccs_indices in zip(["L1", "L2", "L1UL2"], [trajectory_ccs_codes_level1, trajectory_ccs_codes_level2, trajectory_ccs_codes_level1 + trajectory_ccs_codes_level2]):
        out_dir = f'{output_dir}/trajectories/{data_label}_{indices_label}' 
        Path(out_dir).mkdir(parents=True, exist_ok=True)
        A.plot_trajectory(trajectories=trajectory_set, 
                          interface=interface, 
                          flatccs_selection=ccs_indices, 
                          ccs_color=ccs_color,
                          out_dir=out_dir)
# Out:
# /home/asem/GP/ICENODE/notebooks/analysis.py:443: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(i)
