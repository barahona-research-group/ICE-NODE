# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
import glob
import random
from collections import defaultdict
from pathlib import Path

from IPython.display import display

import pandas as pd
import dask

from tqdm import tqdm
import jax
jax.config.update('jax_platform_name', 'cpu')
# jax.config.update('jax_log_compiles', True)
# jax.config.update("jax_debug_nans", True)
# jax.config.update("jax_enable_x64", True)

# %%
sys.path.append("../..")

from lib import utils as U
from lib.ehr import load_dataset, load_dataset_scheme, load_dataset_config, Dataset
from lib.ehr.interface import Patients, InterfaceConfig
from lib.ehr.concepts import DemographicVectorConfig

# %%
import logging
logging.root.level = logging.DEBUG

# %%
tag = 'M4'
PATH = f'{os.environ.get("HOME")}/GP/ehr-data/mimic4-cohort'
sample = 100
cache =  f'cached_inteface/patients_{tag}_{sample or ""}'
dataset_config = load_dataset_config(tag, 
                                     sample=sample,
                                     path=PATH)

# %% [markdown]
# ##### Possible Interface Scheme Configurations

# %%
import json
dataset_scheme = load_dataset_scheme(tag)
interface_schem_options = dataset_scheme.supported_target_scheme_options
print(json.dumps(interface_schem_options, sort_keys=True, indent=4))
# Out:
# DEBUG:root:Constructing mimic4_eth32 (<class 'lib.ehr.coding_scheme.MIMIC4Eth32'>) scheme
# DEBUG:root:Constructing gender (<class 'lib.ehr.coding_scheme.Gender'>) scheme
# DEBUG:root:Constructing dx_icd10 (<class 'lib.ehr.coding_scheme.DxICD10'>) scheme
# DEBUG:root:Constructing dx_icd9 (<class 'lib.ehr.coding_scheme.DxICD9'>) scheme
# {
#     "dx": [
#         "DxICD10",
#         "DxCCS",
#         "DxICD9",
#         "DxFlatCCS"
#     ],
#     "ethnicity": [
#         "MIMIC4Eth32",
#         "MIMIC4Eth5"
#     ],
#     "gender": [
#         "Gender"
#     ],
#     "outcome": [
#         "dx_icd9_filter_v3_groups",
#         "dx_flatccs_mlhc_groups",
#         "dx_icd9_filter_v2_groups",
#         "dx_flatccs_filter_v1",
#         "dx_icd9_filter_v1"
#     ]
# }

# %%
interface_scheme = dataset_scheme.make_target_scheme_config(dx='DxICD9',
                                                            outcome='dx_icd9_filter_v3_groups',
                                                            ethnicity='MIMIC4Eth5')


# Demographic vector attributes
demographic_vector_conf = DemographicVectorConfig(
    age=False, 
    gender=False, 
    ethnicity=False
)
interface_config = InterfaceConfig(scheme=interface_scheme,
                                   dataset_scheme=dataset_scheme,
                                   demographic_vector=demographic_vector_conf,
                                   cache=cache)

# %%
from lib.ml import (ICENODE, ICENODEConfig, OutpatientEmbeddingConfig,  SplitConfig,
                    Trainer, TrainerConfig, TrainerReporting, OptimizerConfig, WarmupConfig, ReportingConfig)
from lib.metric import  (CodeAUC, UntilFirstCodeAUC, AdmissionAUC, CodeLevelMetricConfig, MetricLevelsConfig,
                         LossMetricConfig,
                      CodeGroupTopAlarmAccuracy, LossMetric, ObsCodeLevelLossMetric, CodeGroupTopAlarmAccuracyConfig)
from lib.ml import Experiment, ExperimentConfig, SplitConfig

import jax.random as jrandom

# %%
emb_dims = OutpatientEmbeddingConfig(dx=30, demo=0)
model_config = ICENODEConfig(mem=15, emb=emb_dims)
model_classname = ICENODE.__name__

# %%
trainer_config = TrainerConfig(optimizer=OptimizerConfig(opt='adam', lr=1e-3),
                          epochs=80,
                          batch_size=128,
                          dx_loss='balanced_focal_bce',
                          obs_loss='mse',
                          lead_loss='mse')

warmup = WarmupConfig(epochs=0.1, 
                      batch_size=8,
                      opt='adam', lr=1e-3, 
                      decay_rate=0.5)

# %%
dx_loss = ["softmax_bce", "balanced_focal_softmax_bce", "balanced_focal_bce",
          "allpairs_exp_rank", "allpairs_hard_rank", "allpairs_sigmoid_rank"]
obs_loss =  ["mse", "mae", "rms"]
                
metrics_conf = [
    (CodeAUC, CodeLevelMetricConfig(aggregate_level=True, code_level=True)),
    (AdmissionAUC, MetricLevelsConfig(admission=False, aggregate=True, subject_aggregate=False)),
    (CodeGroupTopAlarmAccuracy, CodeGroupTopAlarmAccuracyConfig(n_partitions=5, top_k_list=[3, 5, 10, 15, 20])),
    (LossMetric, LossMetricConfig(dx_loss=dx_loss))
]
metrics_conf = [m.export_module_class(c) for m, c in metrics_conf]

# %%
reporting_conf = ReportingConfig(output_dir='icenode',
                                 console=True,
                                 model_stats=False,
                                 parameter_snapshots=True,
                                 config_json=True)

# %%
expt_config = ExperimentConfig(dataset=dataset_config,
                              interface=interface_config,
                              split=SplitConfig(train=0.8, val=0.1, test=0.1, balanced='admissions'),
                              trainer=trainer_config,
                              metrics=metrics_conf,
                              reporting=reporting_conf,
                              model=model_config,
                              model_classname=model_classname,
                              n_evals=100,
                              continue_training=True,
                              warmup=None,
                              reg_hyperparams=None)

# %%
experiment = Experiment(expt_config)

# %%
expt_config
# Out:
# ExperimentConfig(
#   dataset=DatasetConfig(
#     path='/home/asem/GP/ehr-data/mimic4-cohort',
#     scheme=DatasetSchemeConfig(
#       dx={'10': 'DxICD10', '9': 'DxICD9'},
#       ethnicity='MIMIC4Eth32',
#       gender='Gender',
#       outcome=None
#     ),
#     scheme_classname='MIMIC4DatasetScheme',
#     colname={
#       'adm':
#       {
#         'admittime':
#         'admittime',
#         'dischtime':
#         'dischtime',
#         'index':
#         'hadm_id',
#         'subject_id':
#         'subject_id'
#       },
#       'dx':
#       {'admission_id': 'hadm_id', 'code': 'icd_code', 'version': 'icd_version'},
#       'static':
#       {
#         'anchor_age':
#         'anchor_age',
#         'anchor_year':
#         'anchor_year',
#         'ethnicity':
#         'race',
#         'gender':
#         'gender',
#         'index':
#         'subject_id'
#       }
#     },
#     files={
#       'adm':
#       'adm_df.csv.gz',
#       'dx':
#       'dx_df.csv.gz',
#       'static':
#       'static_df.csv.gz'
#     },
#     sample=100,
#     meta_fpath='',
#     tag='M4',
#     overlapping_admissions='merge'
#   ),
#   interface=InterfaceConfig(
#     demographic_vector=DemographicVectorConfig(
#       gender=False,
#       age=False,
#       ethnicity=False
#     ),
#     leading_observable=None,
#     scheme=DatasetSchemeConfig(
#       dx='DxICD9',
#       ethnicity='MIMIC4Eth5',
#       gender='Gender',
#       outcome='dx_icd9_filter_v3_groups'
#     ),
#     cache='cached_inteface/patients_M4_100'
#   ),
#   split=SplitConfig(train=0.8, val=0.1, test=0.1, balanced='admissions'),
#   trainer=TrainerConfig(
#     optimizer=OptimizerConfig(
#       opt='adam',
#       lr=0.001,
#       decay_rate=None,
#       reverse_schedule=False
#     ),
#     epochs=80,
#     batch_size=128,
#     dx_loss='balanced_focal_bce',
#     obs_loss='mse',
#     lead_loss='mse'
#   ),
#   model=ICENODEConfig(emb=OutpatientEmbeddingConfig(dx=30, demo=0), mem=15),
#   model_classname='ICENODE',
#   metrics=[
#     {
#       'config':
#       {
#         '_type':
#         'CodeLevelMetricConfig',
#         'aggregate_level':
#         True,
#         'code_level':
#         True
#       },
#       'classname':
#       'CodeAUC',
#       'external_argnames':
#       ['patients']
#     },
#     {
#       'config':
#       {
#         '_type':
#         'MetricLevelsConfig',
#         'admission':
#         False,
#         'aggregate':
#         True,
#         'subject_aggregate':
#         False
#       },
#       'classname':
#       'AdmissionAUC',
#       'external_argnames':
#       ['patients']
#     },
#     {
#       'config':
#       {
#         '_type':
#         'CodeGroupTopAlarmAccuracyConfig',
#         'n_partitions':
#         5,
#         'top_k_list':
#         [3, 5, 10, 15, 20]
#       },
#       'classname':
#       'CodeGroupTopAlarmAccuracy',
#       'external_argnames':
#       ('train_split', 'patients')
#     },
#     {
#       'config':
#       {
#         '_type':
#         'LossMetricConfig',
#         'dx_loss':
#         [
#           'softmax_bce',
#           'balanced_focal_softmax_bce',
#           'balanced_focal_bce',
#           'allpairs_exp_rank',
#           'allpairs_hard_rank',
#           'allpairs_sigmoid_rank'
#         ],
#         'lead_loss':
#         [],
#         'obs_loss':
#         []
#       },
#       'classname':
#       'LossMetric',
#       'external_argnames':
#       ['patients']
#     }
#   ],
#   reporting=ReportingConfig(
#     output_dir='icenode',
#     console=True,
#     parameter_snapshots=True,
#     config_json=True,
#     model_stats=False
#   ),
#   n_evals=100,
#   continue_training=True,
#   warmup=None,
#   reg_hyperparams=None
# )

# %%
result = experiment.run()
# Out:
# INFO:root:Cache does not match config, ignoring cache.
# INFO:root:Loading subjects from scratch.
# DEBUG:root:Constructing mimic4_eth32 (<class 'lib.ehr.coding_scheme.MIMIC4Eth32'>) scheme
# DEBUG:root:Constructing gender (<class 'lib.ehr.coding_scheme.Gender'>) scheme
# DEBUG:root:Constructing dx_icd10 (<class 'lib.ehr.coding_scheme.DxICD10'>) scheme
# DEBUG:root:Constructing dx_icd9 (<class 'lib.ehr.coding_scheme.DxICD9'>) scheme
# DEBUG:root:Loading dataframe files
# /home/asem/GP/env/icenode-dev/lib/python3.9/site-packages/dask/dataframe/io/csv.py:544: UserWarning: Warning gzip compression does not support breaking apart files
# Please ensure that each individual file can fit in memory and
# use the keyword ``blocksize=None to remove this message``
# Setting ``blocksize=None``
#   warn(
# DEBUG:fsspec.local:open file: /home/asem/GP/ehr-data/mimic4-cohort/adm_df.csv.gz
# /home/asem/GP/env/icenode-dev/lib/python3.9/site-packages/dask/dataframe/io/csv.py:544: UserWarning: Warning gzip compression does not support breaking apart files
# Please ensure that each individual file can fit in memory and
# use the keyword ``blocksize=None to remove this message``
# Setting ``blocksize=None``
#   warn(
# DEBUG:fsspec.local:open file: /home/asem/GP/ehr-data/mimic4-cohort/dx_df.csv.gz
# /home/asem/GP/env/icenode-dev/lib/python3.9/site-packages/dask/dataframe/io/csv.py:544: UserWarning: Warning gzip compression does not support breaking apart files
# Please ensure that each individual file can fit in memory and
# use the keyword ``blocksize=None to remove this message``
# Setting ``blocksize=None``
#   warn(
# DEBUG:fsspec.local:open file: /home/asem/GP/ehr-data/mimic4-cohort/static_df.csv.gz
# DEBUG:root:[DONE] Loading dataframe files
# DEBUG:root:Preprocess admissions
# DEBUG:root:Removing subjects by matching demographic(-79435)and admissions(-0)tables
# DEBUG:root:Removing subjects with at least one negative adm_interval: 0
# DEBUG:root:adm: Merging overlapping admissions
# DEBUG:root:adm: Merged 2 overlapping admissions
# DEBUG:root:[DONE] Preprocess admissions
# DEBUG:root:Matching admission_id
# DEBUG:root:[DONE] Matching admission_id
# DEBUG:root:Dataframes validation and time conversion
# DEBUG:root:Unrecognised ICD v['10'] codes: 62 (9.28%)
# DEBUG:root:Unrecognised <class 'lib.ehr.coding_scheme.DxICD10'> codes (62) to be removed (first 30): ['E11.3593', 'M1A.9XX0', 'O69.81X0', 'S00.10XA', 'S00.12XA', 'S00.531A', 'S00.83XA', 'S01.01XA', 'S05.02XA', 'S06.5X0A', 'S06.890S', 'S06.9X0S', 'S09.8XXA', 'S09.90XA', 'S14.109D', 'S14.109S', 'S14.159D', 'S22.32XA', 'S30.0XXA', 'S30.1XXA', 'S30.812A', 'S30.813A', 'S50.11XA', 'S50.12XA', 'S51.812A', 'S61.451A', 'T14.8XXS', 'T23.231A', 'T25.022A', 'T37.8X5A']
# DEBUG:root:Unrecognised ICD v['9'] codes: 12 (1.51%)
# DEBUG:root:Unrecognised <class 'lib.ehr.coding_scheme.DxICD9'> codes (12) to be removed (first 30): ['041.49', '282.43', '284.19', '365.70', '539.09', '596.89', '793.11', '793.19', '795.51', '997.49', '999.32', 'V12.55']
# DEBUG:root:Removing subjects by matching demographic(-0)and admissions(-0)tables
# DEBUG:root:[DONE] Dataframes validation and time conversion
# DEBUG:root:Constructing dx_icd9 (<class 'lib.ehr.coding_scheme.DxICD9'>) scheme
# DEBUG:root:Constructing dx_icd9 (<class 'lib.ehr.coding_scheme.DxICD9'>) scheme
# DEBUG:root:Constructing dx_icd9_filter_v3_groups (<class 'lib.ehr.coding_scheme.OutcomeExtractor'>) scheme
# DEBUG:root:Constructing dx_icd9 (<class 'lib.ehr.coding_scheme.DxICD9'>) scheme
# DEBUG:root:Constructing mimic4_eth5 (<class 'lib.ehr.coding_scheme.MIMIC4Eth5'>) scheme
# DEBUG:root:Constructing gender (<class 'lib.ehr.coding_scheme.Gender'>) scheme
# DEBUG:root:Constructing mimic4_eth32 (<class 'lib.ehr.coding_scheme.MIMIC4Eth32'>) scheme
# DEBUG:root:Constructing mimic4_eth5 (<class 'lib.ehr.coding_scheme.MIMIC4Eth5'>) scheme
# DEBUG:root:Constructing dx_icd10 (<class 'lib.ehr.coding_scheme.DxICD10'>) scheme
# DEBUG:root:Constructing dx_icd9 (<class 'lib.ehr.coding_scheme.DxICD9'>) scheme
# DEBUG:root:
#                             dx_icd10->dx_icd9 Unrecognised t_codes
#                             (169):
#                             ['041.41', '041.42', '041.43', '041.49', '173.00', '173.01', '173.02', '173.09', '173.10', '173.11', '173.12', '173.19', '173.20', '173.21', '173.22', '173.29', '173.30', '173.31', '173.32', '173.39']...
# DEBUG:root:
#                             dx_icd10->dx_icd9 Unrecognised s_codes
#                             (49910):
#                             ['E08.3211', 'E08.3212', 'E08.3213', 'E08.3219', 'E08.3291', 'E08.3292', 'E08.3293', 'E08.3299', 'E08.3311', 'E08.3312', 'E08.3313', 'E08.3319', 'E08.3391', 'E08.3392', 'E08.3393', 'E08.3399', 'E08.3411', 'E08.3412', 'E08.3413', 'E08.3419']...
# DEBUG:root:
#                             dx_icd10->dx_icd9 Unrecognised t_codes
#                             (169):
#                             ['041.41', '041.42', '041.43', '041.49', '173.00', '173.01', '173.02', '173.09', '173.10', '173.11', '173.12', '173.19', '173.20', '173.21', '173.22', '173.29', '173.30', '173.31', '173.32', '173.39']...
# DEBUG:root:
#                             dx_icd10->dx_icd9 Unrecognised s_codes
#                             (49910):
#                             ['E08.3211', 'E08.3212', 'E08.3213', 'E08.3219', 'E08.3291', 'E08.3292', 'E08.3293', 'E08.3299', 'E08.3311', 'E08.3312', 'E08.3313', 'E08.3319', 'E08.3391', 'E08.3392', 'E08.3393', 'E08.3399', 'E08.3411', 'E08.3412', 'E08.3413', 'E08.3419']...
# DEBUG:root:Source discrepancy
# DEBUG:root:M: dx_icd10->dx_icd9
#
# Mapping converts codes that are not supported by the source scheme.|M-domain - S|=0; |M-domain - S|/|M-domain|=0.00); first5(M-domain - S)=[]
#
# Source codes that not covered by the mapping. |S - M-domain|=24464; |S - M-domain|/|S|=0.53; first5(S - M-domain)=['A00', 'A01', 'A01.0', 'A02', 'A02.2']
#
# |M-domain|=21405; first5(M-domain) ['A00.0', 'A00.1', 'A00.9', 'A01.00', 'A01.01'].
#
# |S|=45869; first5(S)=['A00', 'A00.0', 'A00.1', 'A00.9', 'A01']
#
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/ehr/ds_mimic4.py:255: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized.
#   dob = anchor_date + anchor_age
# DEBUG:root:Extracting dx codes...
# ERROR:root:Code '5952' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01', ' ...
# ERROR:root:Code '5990' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01', ' ...
# ERROR:root:Code '42731' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01',  ...
# ERROR:root:Code '5569' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01', ' ...
# ERROR:root:Code '1970' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01', ' ...
# ERROR:root:Code 'V5811' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01',  ...
# ERROR:root:Code '43311' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01',  ...
# ERROR:root:Code '80702' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01',  ...
# ERROR:root:Code '7802' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01', ' ...
# ERROR:root:Code '42731' is missing. Accepted keys: dict_keys(['001', '001.0', '001.1', '001.9', '002', '002.0', '002.1', '002.2', '002.3', '002.9', '003', '003.0', '003.1', '003.2', '003.20', '003.21', '003.22', '003.23', '003.24', '003.29', '003.8', '003.9', '004', '004.0', '004.1', '004.2', '004.3', '004.8', '004.9', '005', '005.0', '005.1', '005.2', '005.3', '005.4', '005.8', '005.81', '005.89', '005.9', '006', '006.0', '006.1', '006.2', '006.3', '006.4', '006.5', '006.6', '006.8', '006.9', '007', '007.0', '007.1', '007.2', '007.3', '007.4', '007.5', '007.8', '007.9', '008', '008.0', '008.00', '008.01', '008.02', '008.03', '008.04', '008.09', '008.1', '008.2', '008.3', '008.4', '008.41', '008.42', '008.43', '008.44', '008.45', '008.46', '008.47', '008.49', '008.5', '008.6', '008.61', '008.62', '008.63', '008.64', '008.65', '008.66', '008.67', '008.69', '008.8', '009', '009.0', '009.1', '009.2', '009.3', '010', '010.0', '010.00', '010.01', '010.02', '010.03', '010.04', '010.05', '010.06', '010.1', '010.10', '010.11', '010.12', '010.13', '010.14', '010.15', '010.16', '010.8', '010.80', '010.81', '010.82', '010.83', '010.84', '010.85', '010.86', '010.9', '010.90', '010.91', '010.92', '010.93', '010.94', '010.95', '010.96', '011', '011.0', '011.00', '011.01', '011.02', '011.03', '011.04', '011.05', '011.06', '011.1', '011.10', '011.11', '011.12', '011.13', '011.14', '011.15', '011.16', '011.2', '011.20', '011.21', '011.22', '011.23', '011.24', '011.25', '011.26', '011.3', '011.30', '011.31', '011.32', '011.33', '011.34', '011.35', '011.36', '011.4', '011.40', '011.41', '011.42', '011.43', '011.44', '011.45', '011.46', '011.5', '011.50', '011.51', '011.52', '011.53', '011.54', '011.55', '011.56', '011.6', '011.60', '011.61', '011.62', '011.63', '011.64', '011.65', '011.66', '011.7', '011.70', '011.71', '011.72', '011.73', '011.74', '011.75', '011.76', '011.8', '011.80', '011.81', '011.82', '011.83', '011.84', '011.85', '011.86', '011.9', '011.90', '011.91', '011.92', '011.93', '011.94', '011.95', '011.96', '012', '012.0', '012.00', '012.01', '012.02', '012.03', '012.04', '012.05', '012.06', '012.1', '012.10', '012.11', '012.12', '012.13', '012.14', '012.15', '012.16', '012.2', '012.20', '012.21', '012.22', '012.23', '012.24', '012.25', '012.26', '012.3', '012.30', '012.31', '012.32', '012.33', '012.34', '012.35', '012.36', '012.8', '012.80', '012.81', '012.82', '012.83', '012.84', '012.85', '012.86', '013', '013.0', '013.00', '013.01', '013.02', '013.03', '013.04', '013.05', '013.06', '013.1', '013.10', '013.11', '013.12', '013.13', '013.14', '013.15', '013.16', '013.2', '013.20', '013.21', '013.22', '013.23', '013.24', '013.25', '013.26', '013.3', '013.30', '013.31', '013.32', '013.33', '013.34', '013.35', '013.36', '013.4', '013.40', '013.41', '013.42', '013.43', '013.44', '013.45', '013.46', '013.5', '013.50', '013.51', '013.52', '013.53', '013.54', '013.55', '013.56', '013.6', '013.60', '013.61', '013.62', '013.63', '013.64', '013.65', '013.66', '013.8', '013.80', '013.81', '013.82', '013.83', '013.84', '013.85', '013.86', '013.9', '013.90', '013.91', '013.92', '013.93', '013.94', '013.95', '013.96', '014', '014.0', '014.00', '014.01', '014.02', '014.03', '014.04', '014.05', '014.06', '014.8', '014.80', '014.81', '014.82', '014.83', '014.84', '014.85', '014.86', '015', '015.0', '015.00', '015.01', '015.02', '015.03', '015.04', '015.05', '015.06', '015.1', '015.10', '015.11', '015.12', '015.13', '015.14', '015.15', '015.16', '015.2', '015.20', '015.21', '015.22', '015.23', '015.24', '015.25', '015.26', '015.5', '015.50', '015.51', '015.52', '015.53', '015.54', '015.55', '015.56', '015.6', '015.60', '015.61', '015.62', '015.63', '015.64', '015.65', '015.66', '015.7', '015.70', '015.71', '015.72', '015.73', '015.74', '015.75', '015.76', '015.8', '015.80', '015.81', '015.82', '015.83', '015.84', '015.85', '015.86', '015.9', '015.90', '015.91', '015.92', '015.93', '015.94', '015.95', '015.96', '016', '016.0', '016.00', '016.01',  ...
# ...
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
# Embedding:   0%|          | 0/10 [00:00<?, ?subject/s]
#   0%|          | 0.00/3016.61 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: Mean of empty slice
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return onp.nansum(A * weights, axis=axis) / (
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: All-NaN slice encountered
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
#   0%|          | 0/1 [00:00<?, ?Batch/s]
# Loading to device:   0%|          | 0/75 [00:00<?, ?subject/s]
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(integer_pow) in 0.00019073486328125 sec
# DEBUG:jax._src.interpreters.pxla:Compiling integer_pow for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.0022144317626953125 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.0057218074798583984 sec
#   0%|          | 0/1 [00:00<?, ?Batch/s]
# Loading to device:   0%|          | 0/75 [00:00<?, ?subject/s]
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(integer_pow) in 0.00018906593322753906 sec
# DEBUG:jax._src.interpreters.pxla:Compiling integer_pow for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.0022368431091308594 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.005879402160644531 sec
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
# Embedding:   0%|          | 0/10 [00:00<?, ?subject/s]
#   0%|          | 0.00/3016.61 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: Mean of empty slice
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return onp.nansum(A * weights, axis=axis) / (
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: All-NaN slice encountered
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
#   0%|          | 0/1 [00:00<?, ?Batch/s]
# Loading to device:   0%|          | 0/75 [00:00<?, ?subject/s]
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(integer_pow) in 0.00019097328186035156 sec
# DEBUG:jax._src.interpreters.pxla:Compiling integer_pow for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.0030777454376220703 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.00644683837890625 sec
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
# Embedding:   0%|          | 0/10 [00:00<?, ?subject/s]
#   0%|          | 0.00/3016.61 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: Mean of empty slice
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return onp.nansum(A * weights, axis=axis) / (
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: All-NaN slice encountered
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
#   0%|          | 0/1 [00:00<?, ?Batch/s]
# Loading to device:   0%|          | 0/75 [00:00<?, ?subject/s]
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(integer_pow) in 0.0001888275146484375 sec
# DEBUG:jax._src.interpreters.pxla:Compiling integer_pow for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.0022835731506347656 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.006182670593261719 sec
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
# Embedding:   0%|          | 0/10 [00:00<?, ?subject/s]
#   0%|          | 0.00/3016.61 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: Mean of empty slice
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return onp.nansum(A * weights, axis=axis) / (
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:368: RuntimeWarning: All-NaN slice encountered
#   row.append(agg_f(field_vals))
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
#   0%|          | 0/1 [00:00<?, ?Batch/s]
# Loading to device:   0%|          | 0/75 [00:00<?, ?subject/s]
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(integer_pow) in 0.0001933574676513672 sec
# DEBUG:jax._src.interpreters.pxla:Compiling integer_pow for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.0023446083068847656 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.005748271942138672 sec
#   0%|          | 0/1 [00:00<?, ?Batch/s]
# Loading to device:   0%|          | 0/75 [00:00<?, ?subject/s]
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(integer_pow) in 0.00019097328186035156 sec
# DEBUG:jax._src.interpreters.pxla:Compiling integer_pow for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.002249002456665039 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.006491899490356445 sec
# Embedding:   0%|          | 0/75 [00:00<?, ?subject/s]
#   0%|          | 0.00/58917.20 [00:00<?, ?longitudinal-days/s]
# /home/asem/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:784: RuntimeWarning: invalid value encountered in scalar divide
#   group_alarm_acc[k] = group_tp.sum() / group_true.sum()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 result = experiment.run()
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/ml/experiment.py:111, in Experiment.run(self)
#     107 trainer = self.load_trainer()
#     109 reporting = self.load_reporting(interface, splits)
# --> 111 return trainer(model=model,
#     112                patients=interface,
#     113                splits=splits,
#     114                reporting=reporting,
#     115                n_evals=self.config.n_evals,
#     116                continue_training=self.config.continue_training,
#     117                exported_config=self.config.to_dict(),
#     118                prng_seed=self.prng_seed)
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/ml/trainer.py:755, in Trainer.__call__(self, model, patients, splits, n_evals, reporting, warmup_config, continue_training, prng_seed, trial_terminate_time, exported_config)
#     752 for c in reporting.connections(signals):
#     753     stack.enter_context(c)
# --> 755 return self._train(model=model,
#     756                    patients=patients,
#     757                    splits=splits,
#     758                    n_evals=n_evals,
#     759                    continue_training=continue_training,
#     760                    prng_seed=prng_seed,
#     761                    trial_terminate_time=trial_terminate_time,
#     762                    history=reporting.new_training_history(),
#     763                    signals=signals,
#     764                    exported_config=exported_config)
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/ml/trainer.py:881, in Trainer._train(self, model, patients, splits, n_evals, continue_training, prng_seed, trial_terminate_time, history, signals, exported_config)
#     879 preds = model.batch_predict(batch, leave_pbar=False)
#     880 split_gen.set_description('Evaluating (Train) (B)...')
# --> 881 history.append_train_preds(step, preds)
#     883 if len(valid_ids) > 0:
#     884     split_gen.set_description('Evaluating (Val) (A)...')
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/ml/trainer.py:78, in TrainingHistory.append_train_preds(self, step, res)
#      77 def append_train_preds(self, step: int, res: Predictions):
# ---> 78     row_df = self.metrics.to_df(step, res)
#      79     row_df['date_time'] = pd.Timestamp('now')
#      80     self._train_df = self._concat(self._train_df, row_df)
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:830, in MetricsCollection.to_df(self, iteration, predictions, other_estimated_metrics)
#     825 def to_df(self,
#     826           iteration: int,
#     827           predictions: Predictions,
#     828           other_estimated_metrics: Dict[str, float] = None):
# --> 830     dfs = [m.to_df(iteration, predictions) for m in self.metrics]
#     831     return pd.concat(dfs, axis=1)
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:830, in <listcomp>(.0)
#     825 def to_df(self,
#     826           iteration: int,
#     827           predictions: Predictions,
#     828           other_estimated_metrics: Dict[str, float] = None):
# --> 830     dfs = [m.to_df(iteration, predictions) for m in self.metrics]
#     831     return pd.concat(dfs, axis=1)
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:126, in Metric.to_df(self, index, predictions)
#     125 def to_df(self, index: int, predictions: Predictions):
# --> 126     return pd.DataFrame(self.to_dict(predictions), index=[index])
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:122, in Metric.to_dict(self, predictions)
#     121 def to_dict(self, predictions: Predictions):
# --> 122     result = self(predictions)
#     123     return dict(zip(self.columns(), self.row(result)))
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:228, in LossMetric.__call__(self, predictions)
#     227 def __call__(self, predictions: Predictions):
# --> 228     return {
#     229         f'dx_{loss_key}': predictions.prediction_dx_loss(dx_loss=loss_f)
#     230         for loss_key, loss_f in self._dx_loss.items()
#     231     } | {
#     232         f'obs_{loss_key}': predictions.prediction_obs_loss(obs_loss=loss_f)
#     233         for loss_key, loss_f in self._obs_loss.items()
#     234     } | {
#     235         f'lead_{loss_key}':
#     236         predictions.prediction_lead_loss(lead_loss=loss_f)
#     237         for loss_key, loss_f in self._lead_loss.items()
#     238     }
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/metric/stat.py:229, in <dictcomp>(.0)
#     227 def __call__(self, predictions: Predictions):
#     228     return {
# --> 229         f'dx_{loss_key}': predictions.prediction_dx_loss(dx_loss=loss_f)
#     230         for loss_key, loss_f in self._dx_loss.items()
#     231     } | {
#     232         f'obs_{loss_key}': predictions.prediction_obs_loss(obs_loss=loss_f)
#     233         for loss_key, loss_f in self._obs_loss.items()
#     234     } | {
#     235         f'lead_{loss_key}':
#     236         predictions.prediction_lead_loss(lead_loss=loss_f)
#     237         for loss_key, loss_f in self._lead_loss.items()
#     238     }
#
# File ~/GP/ICENODE/notebooks/mimic4_dx/../../lib/ehr/interface.py:102, in Predictions.prediction_dx_loss(self, dx_loss)
#     100 l_pred = [p.outcome.vec for p in preds]
#     101 l_mask = [jnp.ones_like(a.outcome.vec, dtype=bool) for a in adms]
# --> 102 loss_v = jnp.array(list(map(dx_loss, l_outcome, l_pred, l_mask)))
#     103 loss_v = jnp.nanmean(loss_v)
#     104 return jnp.where(jnp.isnan(loss_v), 0., loss_v)
#
# File ~/GP/env/icenode-dev/lib/python3.9/site-packages/equinox/_jit.py:107, in _JitWrapper.__call__(self, *args, **kwargs)
#     106 def __call__(self, /, *args, **kwargs):
# --> 107     return self._call(False, args, kwargs)
#
# File ~/GP/env/icenode-dev/lib/python3.9/site-packages/equinox/_jit.py:103, in _JitWrapper._call(self, is_lower, args, kwargs)
#     101         out = self._cached(dynamic, static)
#     102 else:
# --> 103     out = self._cached(dynamic, static)
#     104 return _postprocess(out)
#
# File ~/GP/env/icenode-dev/lib/python3.9/site-packages/equinox/_module.py:307, in _unflatten_module(cls, aux, dynamic_field_values)
#     297     aux = _FlattenedData(
#     298         tuple(dynamic_field_names),
#     299         tuple(static_field_names),
#    (...)
#     302         tuple(wrapper_field_values),
#     303     )
#     304     return tuple(dynamic_field_values), aux
# --> 307 def _unflatten_module(cls: type["Module"], aux: _FlattenedData, dynamic_field_values):
#     308     module = object.__new__(cls)
#     309     for name, value in zip(aux.dynamic_field_names, dynamic_field_values):
#
# KeyboardInterrupt:

# %% [markdown]
# ######
