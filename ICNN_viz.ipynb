# %%
# surface plot for 2d objective function
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LightSource
from matplotlib import cbook, cm


        
# objective function
def objective(x, y):
 return (x - 10)**2.0 +  y**2.0 + 5
 
# define range for input
x_min, x_max = -5.0, 15.0
y_min, y_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = np.arange(x_min, x_max, 0.1)
yaxis = np.arange(y_min, y_max, 0.1)

r_opt = np.linspace(15, 0.0, 15)
theta_opt = np.linspace(-np.pi / 2 , np.pi / 2, 15)
x_opt = (r_opt) * np.sin(theta_opt) + 10
y_opt = r_opt * np.cos(theta_opt)
z_opt = objective(x_opt, y_opt)


# create a mesh from the axis
x, y = np.meshgrid(xaxis, yaxis)
# compute targets
z = objective(x, y)
# create a surface plot with the jet color scheme
figure = plt.figure()
axis = figure.add_subplot(projection='3d', computed_zorder=False)



ls = LightSource(azdeg=0, altdeg=45)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
rgb = ls.shade(z, cmap=cm.YlOrBr, vert_exag=0.1, blend_mode='soft')
axis.plot_surface(x, y, z,  #lw=0.5, rstride=50, cstride=50, 
                  # alpha=0.2, 
                  edgecolor='none',
                  facecolors=rgb,
                  antialiased=False,
                 zorder=-1000)
axis.plot(x_opt, y_opt, z_opt, 'b', linewidth=2, zorder=10)
axis.scatter(x_opt[-1], y_opt[-1], z_opt[-1], marker='o', zorder=1000, s=50, c='r', zdir='z', alpha=1.)
# axis.contourf(x, y, results, zdir='z', offset=0, cmap='coolwarm')
axis.set(xlabel=r'$z_1$', ylabel=r'$z_2$', zlabel=r'$E(z_1,z_2)$', xticklabels=[], yticklabels=[], zticklabels=[])
axis.grid(False)
# axis.view_init(40, 290)
axis.set_box_aspect(aspect=None, zoom=0.8)


# show the plot
plt.savefig('img.png', bbox_inches='tight');

plt.show()

# %%
# surface plot for 2d objective function
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LightSource
from matplotlib import cbook, cm


        
# objective function
def objective(x, y):
    return (x - 10)**2.0 +  y**2.0 + 5
 
# define range for input
x_min, x_max = -5.0, 15.0
y_min, y_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = np.arange(x_min, x_max, 0.1)
yaxis = np.arange(y_min, y_max, 0.1)

r_opt = np.linspace(15, 0.0, 15)
theta_opt = np.linspace(-np.pi / 2 , np.pi / 2, 15)
x_opt = (r_opt) * np.sin(theta_opt) + 10
y_opt = r_opt * np.cos(theta_opt)
z_opt = objective(x_opt, y_opt)


# create a mesh from the axis
x, y = np.meshgrid(xaxis, yaxis)
# compute targets
z = objective(x, y)
# create a surface plot with the jet color scheme
figure = plt.figure()
axis = figure.add_subplot(projection='3d', computed_zorder=False)



ls = LightSource(azdeg=0, altdeg=0)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
rgb = ls.shade(z, cmap=cm.Blues, vert_exag=0.1, blend_mode='soft')
axis.plot_surface(x, y, z,  #lw=0.5, rstride=50, cstride=50, 
                  # alpha=0.2, 
#                   edgecolor='none',
                  facecolors=rgb,
                  antialiased=True,
                  zorder=-1000)
axis.plot(x_opt, y_opt, z_opt, linestyle='dashed', c='b', linewidth=2, zorder=10)
axis.scatter(x_opt[-1], y_opt[-1], z_opt[-1], marker='o', zorder=1000, s=50, c='r', zdir='z', alpha=1.)
# axis.contourf(x, y, results, zdir='z', offset=0, cmap='coolwarm')
axis.set(xlabel=r'$z_1$', ylabel=r'$z_3$', zlabel=r'$E(z_1,z_3)$', xticklabels=[], yticklabels=[], zticklabels=[])
axis.xaxis.label.set_size(32)
axis.yaxis.label.set_size(32)
axis.zaxis.label.set_size(32)

axis.grid(False)
# axis.view_init(30, -100)
axis.set_box_aspect(aspect=None, zoom=0.75)


# show the plot
plt.savefig('energy_surface_z2z3.png', bbox_inches='tight');

plt.show()

# %%
# ?axis.set

# %%
z_opt
# Out:
# array([230.        , 199.00510204, 170.30612245, 143.90306122,
#        119.79591837,  97.98469388,  78.46938776,  61.25      ,
#         46.32653061,  33.69897959,  23.36734694,  15.33163265,
#          9.59183673,   6.14795918,   5.        ])

# %%
# ?cm
# Out:
# Type:        module
# String form: <module 'matplotlib.cm' from '/home/asem/GP/env/icenode-dev/lib/python3.11/site-packages/matplotlib/cm.py'>
# File:        ~/GP/env/icenode-dev/lib/python3.11/site-packages/matplotlib/cm.py
# Docstring:
# Builtin colormaps, colormap handling utilities, and the `ScalarMappable` mixin.
#
# .. seealso::
#
#   :doc:`/gallery/color/colormap_reference` for a list of builtin colormaps.
#
#   :ref:`colormap-manipulation` for examples of how to make
#   colormaps.
#
#   :ref:`colormaps` an in-depth discussion of choosing
#   colormaps.
#
#   :ref:`colormapnorms` for more details about data normalization.

# %%
dir(cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Grays',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
# ...
